# %%
pip install sunpy[all]
# Out:
# Collecting sunpy[all]
#   Downloading sunpy-7.0.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: astropy>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (7.1.0)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (25.0)
# Collecting parfive>=2.1.0 (from parfive[ftp]>=2.1.0->sunpy[all])
#   Downloading parfive-2.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2.0.1.5)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2.32.4)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2025.3.0)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.0->sunpy[all]) (0.2025.8.25.0.36.58)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.0->sunpy[all]) (6.0.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (3.12.15)
# Collecting aioftp>=0.17.1 (from parfive[ftp]>=2.1.0->sunpy[all])
#   Downloading aioftp-0.26.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->sunpy[all]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->sunpy[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->sunpy[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->sunpy[all]) (2025.8.3)
# Collecting asdf-astropy>=0.5.0 (from sunpy[all])
#   Downloading asdf_astropy-0.8.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting asdf>=3.0.0 (from sunpy[all])
#   Downloading asdf-4.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting glymur>=0.13.0 (from sunpy[all])
#   Downloading glymur-0.14.3-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: lxml!=5.0.0,>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (5.4.0)
# Requirement already satisfied: opencv-python>=4.8.0.74 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (4.12.0.88)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (0.25.2)
# Collecting spiceypy>=6.0.0 (from sunpy[all])
#   Downloading spiceypy-6.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting asdf-standard>=1.1.0 (from asdf>=3.0.0->sunpy[all])
#   Downloading asdf_standard-1.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting asdf-transform-schemas>=0.3 (from asdf>=3.0.0->sunpy[all])
#   Downloading asdf_transform_schemas-0.6.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting jmespath>=0.6.2 (from asdf>=3.0.0->sunpy[all])
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: semantic_version>=2.8 in /usr/local/lib/python3.12/dist-packages (from asdf>=3.0.0->sunpy[all]) (2.10.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from asdf>=3.0.0->sunpy[all]) (25.3.0)
# Collecting asdf-coordinates-schemas>=0.4 (from asdf-astropy>=0.5.0->sunpy[all])
#   Downloading asdf_coordinates_schemas-0.4.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from glymur>=0.13.0->sunpy[all]) (11.3.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->sunpy[all]) (1.16.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->sunpy[all]) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->sunpy[all]) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->sunpy[all]) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->sunpy[all]) (0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.20.1)
# Requirement already satisfied: contourpy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (1.3.3)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (3.10.0)
# Collecting mpl-animators>=1.2.0 (from sunpy[all])
#   Downloading mpl_animators-1.2.4-py3-none-any.whl.metadata (6.4 kB)
# Collecting reproject>=0.12.0 (from sunpy[all])
#   Downloading reproject-0.15.0-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (4.13.5)
# Collecting drms>=0.7.1 (from sunpy[all])
#   Downloading drms-0.9.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2.9.0.post0)
# Collecting zeep>=4.3.0 (from sunpy[all])
#   Downloading zeep-4.3.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting cdflib>=1.3.2 (from sunpy[all])
#   Downloading cdflib-1.3.6-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: h5netcdf>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (1.6.4)
# Requirement already satisfied: h5py>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (3.14.0)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[all]) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (4.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.0->sunpy[all]) (2.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->sunpy[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->sunpy[all]) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->sunpy[all]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->sunpy[all]) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.0->sunpy[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.0->sunpy[all]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->sunpy[all]) (1.17.0)
# Collecting astropy-healpix>=1.0 (from reproject>=0.12.0->sunpy[all])
#   Downloading astropy_healpix-1.1.2-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: dask>=2021.8 in /usr/local/lib/python3.12/dist-packages (from dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (2025.5.0)
# Collecting zarr>=2.11.0 (from reproject>=0.12.0->sunpy[all])
#   Downloading zarr-3.1.2-py3-none-any.whl.metadata (10 kB)
# Collecting pyavm>=0.9.6 (from reproject>=0.12.0->sunpy[all])
#   Downloading PyAVM-0.9.6-py3-none-any.whl.metadata (5.6 kB)
# Collecting isodate>=0.5.4 (from zeep>=4.3.0->sunpy[all])
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[all]) (4.3.8)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[all]) (1.0.0)
# Collecting requests-file>=1.5.1 (from zeep>=4.3.0->sunpy[all])
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (0.12.1)
# Collecting donfig>=0.8 (from zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Downloading numcodecs-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (1.0.0)
# Downloading parfive-2.2.0-py3-none-any.whl (34 kB)
# Downloading sunpy-7.0.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 27.5 MB/s eta 0:00:00
# Downloading aioftp-0.26.2-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.2 MB/s eta 0:00:00
# Downloading asdf-4.4.0-py3-none-any.whl (970 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.3/970.3 kB 29.0 MB/s eta 0:00:00
# Downloading asdf_astropy-0.8.0-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 6.7 MB/s eta 0:00:00
# Downloading glymur-0.14.3-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 63.9 MB/s eta 0:00:00
# Downloading spiceypy-6.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 52.5 MB/s eta 0:00:00
# Downloading asdf_coordinates_schemas-0.4.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 2.8 MB/s eta 0:00:00
# Downloading asdf_standard-1.4.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 7.0 MB/s eta 0:00:00
# Downloading asdf_transform_schemas-0.6.0-py3-none-any.whl (350 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.3/350.3 kB 21.3 MB/s eta 0:00:00
# Downloading cdflib-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.5 MB/s eta 0:00:00
# Downloading drms-0.9.0-py3-none-any.whl (37 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading mpl_animators-1.2.4-py3-none-any.whl (35 kB)
# Downloading reproject-0.15.0-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.0 MB/s eta 0:00:00
# Downloading zeep-4.3.1-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.2 MB/s eta 0:00:00
# Downloading astropy_healpix-1.1.2-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.2/195.2 kB 13.1 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading PyAVM-0.9.6-py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.9/378.9 kB 23.1 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading zarr-3.1.2-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 13.5 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 71.2 MB/s eta 0:00:00
# Downloading crc32c-2.7.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: spiceypy, pyavm, numcodecs, jmespath, isodate, glymur, donfig, crc32c, cdflib, asdf-standard, aioftp, requests-file, asdf-transform-schemas, zeep, zarr, parfive, mpl-animators, drms, astropy-healpix, asdf, reproject, asdf-coordinates-schemas, sunpy, asdf-astropy
# Successfully installed aioftp-0.26.2 asdf-4.4.0 asdf-astropy-0.8.0 asdf-coordinates-schemas-0.4.0 asdf-standard-1.4.0 asdf-transform-schemas-0.6.0 astropy-healpix-1.1.2 cdflib-1.3.6 crc32c-2.7.1 donfig-0.8.1.post1 drms-0.9.0 glymur-0.14.3 isodate-0.7.2 jmespath-1.0.1 mpl-animators-1.2.4 numcodecs-0.16.2 parfive-2.2.0 pyavm-0.9.6 reproject-0.15.0 requests-file-2.1.0 spiceypy-6.0.3 sunpy-7.0.1 zarr-3.1.2 zeep-4.3.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sunpy.net import Fido, attrs as a
from sunpy.time import TimeRange

from datetime import datetime
from datetime import timedelta
import requests

import warnings
warnings.filterwarnings('ignore')

# %%
# Fetching the data from DONKI
donki_flare = pd.read_json("https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/FLR?startDate=2010-01-01&endDate=2018-01-31")
donki_cme = pd.read_json("https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/CME?startDate=2010-01-01&endDate=2018-01-31")

# %%
print("Donki Flare data: \nShape",donki_flare.shape)
print("Columns:",donki_flare.columns)

print("\nDonki CME data: \nShape",donki_cme.shape)
print("Columns:",donki_cme.columns)
# Out:
# Donki Flare data:
# Shape (564, 15)
# Columns: Index(['flrID', 'catalog', 'instruments', 'beginTime', 'peakTime', 'endTime',
#        'classType', 'sourceLocation', 'activeRegionNum', 'note',
#        'submissionTime', 'versionId', 'link', 'linkedEvents',
#        'sentNotifications'],
#       dtype='object')
#
# Donki CME data:
# Shape (2758, 13)
# Columns: Index(['activityID', 'catalog', 'startTime', 'instruments', 'sourceLocation',
#        'activeRegionNum', 'note', 'submissionTime', 'versionId', 'link',
#        'cmeAnalyses', 'linkedEvents', 'sentNotifications'],
#       dtype='object')

# %%
# Extracting the important columns
donki_flare = donki_flare[['beginTime','peakTime','endTime','classType','activeRegionNum','linkedEvents']]
donki_cme = donki_cme[['startTime','sourceLocation','activeRegionNum','linkedEvents','cmeAnalyses']]

# %%
# Only Flares data
flares = donki_flare[donki_flare["linkedEvents"].isna()]
flares.reset_index(drop=True,inplace=True)
flares
# Out:
#              beginTime           peakTime            endTime classType  \
# 0    2010-06-12T00:30Z  2010-06-12T00:57Z  2010-06-12T01:02Z      M2.0
# 1    2010-08-07T17:55Z  2010-08-07T18:24Z  2010-08-07T18:47Z      M1.0
# 2    2010-10-16T19:07Z  2010-10-16T19:12Z  2010-10-16T19:15Z      M2.9
# 3    2011-01-28T00:44Z  2011-01-28T01:03Z  2011-01-28T01:10Z      M1.3
# 4    2011-02-09T01:23Z  2011-02-09T01:31Z  2011-02-09T01:35Z      M1.9
# ..                 ...                ...                ...       ...
# 362  2017-09-13T07:39Z  2017-09-13T07:48Z  2017-09-13T08:09Z      B1.4
# 363  2017-09-20T12:32Z  2017-09-20T12:43Z  2017-09-20T13:00Z      B5.4
# 364  2017-09-20T19:28Z  2017-09-20T19:32Z  2017-09-20T19:49Z      B8.4
# 365  2017-09-26T02:31Z  2017-09-26T02:34Z  2017-09-26T02:43Z      C1.8
# 366  2017-09-27T00:49Z  2017-09-27T01:00Z  2017-09-27T01:16Z      C1.7
#
#      activeRegionNum linkedEvents
# 0            11081.0         None
# 1            11093.0         None
# 2            11112.0         None
# 3            11149.0         None
# 4            11153.0         None
# ..               ...          ...
# 362          12680.0         None
# 363              NaN         None
# 364          12680.0         None
# 365          12683.0         None
# 366          12683.0         None
#
# [367 rows x 6 columns]

# %%
# Flare Associated with CME & SEP data
flare_linked = donki_flare[donki_flare["linkedEvents"].notna()]
flare_linked.reset_index(drop=True,inplace=True)
flare_linked
# Out:
#              beginTime           peakTime            endTime classType  \
# 0    2010-04-03T09:04Z  2010-04-03T09:54Z  2010-04-03T10:58Z      B7.4
# 1    2010-08-14T09:38Z  2010-08-14T10:05Z  2010-08-14T10:31Z      C4.4
# 2    2010-08-18T04:45Z  2010-08-18T05:48Z  2010-08-18T06:51Z      C4.5
# 3    2011-02-15T01:44Z  2011-02-15T01:56Z  2011-02-15T02:06Z      X2.2
# 4    2011-02-24T07:23Z  2011-02-24T07:35Z  2011-02-24T07:42Z      M3.5
# ..                 ...                ...                ...       ...
# 192  2017-09-08T07:40Z  2017-09-08T07:49Z  2017-09-08T07:58Z      M8.1
# 193  2017-09-10T15:35Z  2017-09-10T16:06Z  2017-09-10T16:31Z      X8.2
# 194  2017-09-12T07:23Z  2017-09-12T07:29Z  2017-09-12T07:48Z      C3.0
# 195  2017-09-12T19:03Z  2017-09-12T19:20Z  2017-09-12T19:28Z      C1.6
# 196  2017-10-20T23:10Z  2017-10-20T23:28Z  2017-10-21T23:37Z      M1.1
#
#      activeRegionNum                                       linkedEvents
# 0            11059.0    [{'activityID': '2010-04-03T09:54:00-CME-001'}]
# 1            11093.0    [{'activityID': '2010-08-14T12:30:00-SEP-001'}]
# 2            11099.0    [{'activityID': '2010-08-18T06:00:00-CME-001'}]
# 3            11158.0    [{'activityID': '2011-02-15T02:25:00-CME-001'}]
# 4            11163.0    [{'activityID': '2011-02-24T08:00:00-CME-001'}]
# ..               ...                                                ...
# 192          12673.0    [{'activityID': '2017-09-08T07:24:00-CME-001'}]
# 193          12673.0  [{'activityID': '2017-09-10T16:09:00-CME-001'}...
# 194          12680.0  [{'activityID': '2017-09-12T08:09:00-CME-001'}...
# 195          12680.0    [{'activityID': '2017-09-13T05:33:00-SEP-001'}]
# 196          12685.0    [{'activityID': '2017-10-21T00:12:00-CME-001'}]
#
# [197 rows x 6 columns]

# %%
# Only CME
cme = donki_cme[donki_cme["linkedEvents"].isna() & donki_cme["activeRegionNum"].notna()]
cme.reset_index(drop=True,inplace=True)
cme
# Out:
#              startTime sourceLocation  activeRegionNum linkedEvents  \
# 0    2010-11-11T17:00Z         S22E03          11123.0         None
# 1    2011-10-01T09:54Z                         11302.0         None
# 2    2011-10-01T10:24Z                         11305.0         None
# 3    2013-10-25T04:25Z         S07E76          11882.0         None
# 4    2013-11-05T08:36Z         S16E51          11890.0         None
# ..                 ...            ...              ...          ...
# 181  2017-10-07T08:48Z         N13W78          12683.0         None
# 182  2017-10-17T03:36Z                         12682.0         None
# 183  2017-11-16T14:54Z                         12687.0         None
# 184  2017-12-21T00:12Z                         12692.0         None
# 185  2018-01-22T03:12Z         S12W58          12696.0         None
#
#                                            cmeAnalyses
# 0    [{'isMostAccurate': True, 'time21_5': '2010-11...
# 1    [{'isMostAccurate': True, 'time21_5': '2011-10...
# 2    [{'isMostAccurate': True, 'time21_5': '2011-10...
# 3    [{'isMostAccurate': True, 'time21_5': '2013-10...
# 4    [{'isMostAccurate': True, 'time21_5': '2013-11...
# ..                                                 ...
# 181  [{'isMostAccurate': True, 'time21_5': '2017-10...
# 182  [{'isMostAccurate': True, 'time21_5': '2017-10...
# 183  [{'isMostAccurate': True, 'time21_5': '2017-11...
# 184  [{'isMostAccurate': True, 'time21_5': '2017-12...
# 185  [{'isMostAccurate': True, 'time21_5': '2018-01...
#
# [186 rows x 5 columns]

# %%
# Changing the peaktime to datetime format
from datetime import datetime

def convert_to_datetime(tstr):
    year = int(tstr[:4])
    month = int(tstr[5:7])
    day = int(tstr[8:10])
    hour = int(tstr[11:13])
    minute = int(tstr[14:16])
    return datetime(year, month, day, hour, minute)

for i in range(flares.shape[0]):
    flares['peakTime'].iloc[i] = convert_to_datetime(flares['peakTime'].iloc[i])
for i in range(cme.shape[0]):
    cme['startTime'].iloc[i] = convert_to_datetime(cme['startTime'].iloc[i])
for i in range(flare_linked.shape[0]):
    flare_linked['peakTime'].iloc[i] = convert_to_datetime(flare_linked['peakTime'].iloc[i])

# %% [markdown]
# ### Validation using GOES data

# %% [markdown]
# #### Flare Only

# %%
# Case 1: filling nan ARs
number_of_donki_mistakes = 0  # count the number of DONKI mistakes
# create an empty array to hold row numbers to drop at the end
flares_drops = []

for i in range(flares.shape[0]):
    if (np.isnan(flares.loc[i]['activeRegionNum'])):
        time = flares['peakTime'].iloc[i]
        time_range = TimeRange(time, time)
        listofresult = Fido.search(a.Time(time_range),a.hek.EventType("FL"),a.hek.OBS.Observatory == "GOES")

        if len(listofresult["hek"]) == 0:
            print(flares.loc[i]['classType'], "has no match in the GOES flare database ; dropping row.")
            flares_drops.append(i)
            number_of_donki_mistakes += 1
            continue
        else:
            if (listofresult[0]['ar_noaanum'] == 0):
                print(flares.loc[i]['activeRegionNum'], flares.loc[i]
                    ['classType'], "has no match in the GOES flare database ; dropping row.")
                flares_drops.append(i)
                number_of_donki_mistakes += 1
                continue
            else:
                print("Missing NOAA number:", flares['activeRegionNum'].iloc[i], flares['classType'].iloc[i],
                    flares['peakTime'].iloc[i], "should be", listofresult[0]['ar_noaanum'][0], "; changing now.")
                flares['activeRegionNum'].iloc[i] = listofresult[0]['ar_noaanum']
                number_of_donki_mistakes += 1

# Drop the rows for which there is no active region number in both the DONKI and GOES flare databases
flares = flares.drop(flares_drops)
flares = flares.reset_index(drop=True)
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Missing NOAA number: nan X1.5 2011-03-09 23:23:00 should be 11166 ; changing now.
# Missing NOAA number: nan M8.8 2011-09-25 04:50:00 should be 11302 ; changing now.
# Missing NOAA number: nan M5.7 2012-05-10 04:18:00 should be 11476 ; changing now.
# Missing NOAA number: nan M5.6 2012-07-02 10:52:00 should be 11515 ; changing now.
# Missing NOAA number: nan M5.3 2012-07-04 09:55:00 should be 11515 ; changing now.
# Missing NOAA number: nan M6.1 2012-07-05 11:44:00 should be 11515 ; changing now.
# Missing NOAA number: nan M5.5 2012-08-18 01:02:00 should be 11548 ; changing now.
# Missing NOAA number: nan M9.1 2012-10-20 18:14:00 should be 11598 ; changing now.
# Missing NOAA number: nan M6.0 2012-11-13 02:04:00 should be 11613 ; changing now.
# nan M1.7 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M5.7 2013-05-03 17:32:00 should be 11739 ; changing now.
# nan M1.1 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan C3.6 2014-04-22 05:47:00 should be 12038 ; changing now.
# C3.9 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan C5.0 2014-06-10 10:17:00 should be 12087 ; changing now.
# Missing NOAA number: nan M2.1 2014-09-11 15:25:00 should be 12166 ; changing now.
# Missing NOAA number: nan M1.4 2014-09-11 21:26:00 should be 12166 ; changing now.
# nan M1.1 has no match in the GOES flare database ; dropping row.
# nan M1.4 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M1.5 2014-12-13 05:20:00 should be 12241 ; changing now.
# Missing NOAA number: nan M1.6 2014-12-14 19:33:00 should be 12242 ; changing now.
# Missing NOAA number: nan M1.4 2015-01-22 04:52:00 should be 12268 ; changing now.
# Missing NOAA number: nan M1.0 2015-06-11 08:55:00 should be 12367 ; changing now.
# Missing NOAA number: nan C5.1 2016-07-07 07:56:00 should be 12561 ; changing now.
# nan M1.3 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan C5.1 2017-03-27 18:20:00 should be 12645 ; changing now.
# nan M1.3 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan C8.4 2017-07-13 20:05:00 should be 12667 ; changing now.
# Missing NOAA number: nan M1.2 2017-08-20 01:52:00 should be 12672 ; changing now.
# Missing NOAA number: nan B5.4 2017-09-20 12:43:00 should be 12681 ; changing now.
# There are 30 DONKI mistakes so far.

# %%
# Grab all the data from the GOES database
t_start = "2010-01-01"
t_end = "2018-12-31"
time_range = TimeRange(t_start, t_end)
listofresults = Fido.search(a.Time(time_range),a.hek.EventType("FL"),a.hek.OBS.Observatory == "GOES")
print('Grabbed all the GOES data; there are', len(listofresults["hek"]), 'events.')
# Out:
# Grabbed all the GOES data; there are 14896 events.

# %%
# Case 2: Updating Incorrect AR
peak_times_noaa = [item["event_peaktime"] for item in listofresults["hek"]]

for i in range(flares.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = flares['peakTime'].iloc[i]
    if peak_time_donki in peak_times_noaa:
        index = peak_times_noaa.index(peak_time_donki)
    else:
        continue
    # ignore NOAA active region numbers equal to zero
    if (listofresults["hek"][index]['ar_noaanum'] == 0):
        continue
    # if yes, check if the DONKI and NOAA active region numbers match up for this peak time
    # if they don't, flag this peak time and replace the DONKI number with the NOAA number
    if (listofresults["hek"][index]['ar_noaanum'] != int(flares['activeRegionNum'].iloc[i])):
        print('Messed up NOAA number:', int(flares['activeRegionNum'].iloc[i]), flares['classType'].iloc[i],
              flares['peakTime'].iloc[i], "should be", listofresults["hek"][index]['ar_noaanum'], "; changing now.")
        flares['activeRegionNum'].iloc[i] = listofresults["hek"][index]['ar_noaanum']
        number_of_donki_mistakes += 1
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Messed up NOAA number: 11968 M1.3 2014-02-02 14:06:00 should be 11967 ; changing now.
# Messed up NOAA number: 11967 M3.8 2014-02-04 01:23:00 should be 11968 ; changing now.
# Messed up NOAA number: 12237 M1.3 2014-12-19 09:44:00 should be 12242 ; changing now.
# Messed up NOAA number: 12322 M1.2 2015-04-21 22:01:00 should be 12325 ; changing now.
# Messed up NOAA number: 12304 M2.2 2015-08-22 13:23:00 should be 12403 ; changing now.
# Messed up NOAA number: 12304 M3.5 2015-08-22 21:24:00 should be 12403 ; changing now.
# Messed up NOAA number: 12415 M1.5 2015-09-20 05:03:00 should be 12420 ; changing now.
# Messed up NOAA number: 12423 M1.9 2015-09-27 10:40:00 should be 12422 ; changing now.
# Messed up NOAA number: 12423 M1.1 2015-09-29 03:43:00 should be 12422 ; changing now.
# Messed up NOAA number: 12423 C5.1 2015-09-29 04:46:00 should be 12428 ; changing now.
# Messed up NOAA number: 12423 M2.9 2015-09-29 05:16:00 should be 12422 ; changing now.
# Messed up NOAA number: 12565 M5.0 2016-07-23 02:11:00 should be 12567 ; changing now.
# Messed up NOAA number: 12674 B9.8 2017-09-11 10:10:00 should be 12673 ; changing now.
# There are 43 DONKI mistakes so far.

# %%
# Case 3: Updating flare peak time.

# create an empty array to hold row numbers to drop at the end
flares_drops = []

active_region_numbers_noaa = [item["ar_noaanum"]
                              for item in listofresults["hek"]]
flare_classes_noaa = [item["fl_goescls"] for item in listofresults["hek"]]

for i in range(flares.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = flares['peakTime'].iloc[i]
    if not peak_time_donki in peak_times_noaa:
        active_region_number_donki = int(
            flares['activeRegionNum'].iloc[i])
        flare_class_donki = flares['classType'].iloc[i]
        flare_class_indices = [i for i, x in enumerate(
            flare_classes_noaa) if x == flare_class_donki]
        active_region_indices = [i for i, x in enumerate(
            active_region_numbers_noaa) if x == active_region_number_donki]
        common_indices = list(
            set(flare_class_indices).intersection(active_region_indices))
        if common_indices:
            print("Messed up time:", int(flares['activeRegionNum'].iloc[i]), flares['classType'].iloc[i],
                  flares['peakTime'].iloc[i], "should be", peak_times_noaa[common_indices[0]], "; changing now.")
            flares['peakTime'].iloc[i] = peak_times_noaa[common_indices[0]]
            number_of_donki_mistakes += 1
        if not common_indices:
            print("DONKI flare peak time",
                  flares['peakTime'].iloc[i], "has no match; dropping row.")
            flares_drops.append(i)
            number_of_donki_mistakes += 1

# Drop the rows for which the NOAA active region number and flare class associated with
# the messed-up flare peak time in the DONKI database has no match in the GOES flare database
flares = flares.drop(flares_drops)
flares = flares.reset_index(drop=True)

# Create a list of corrected flare peak times
peak_times_donki = [flares['peakTime'].iloc[i]
                    for i in range(flares.shape[0])]
# Out:
# Messed up time: 11967 M2.1 2014-01-14 06:39:00 should be 2014-01-30 06:39:00.000 ; changing now.
# DONKI flare peak time 2014-01-28 15:26:00 has no match; dropping row.
# DONKI flare peak time 2014-02-02 16:36:00 has no match; dropping row.
# Messed up time: 11967 M3.1 2014-02-02 18:18:00 should be 2014-02-02 18:11:00.000 ; changing now.
# Messed up time: 11967 M1.3 2014-02-02 22:14:00 should be 2014-02-02 22:04:00.000 ; changing now.
# DONKI flare peak time 2014-02-04 03:06:00 has no match; dropping row.
# Messed up time: 11967 M1.5 2014-02-06 23:03:00 should be 2014-01-28 04:09:00.000 ; changing now.
# Messed up time: 11967 M2.0 2014-02-07 04:53:00 should be 2014-02-07 04:56:00.000 ; changing now.
# Messed up time: 11974 M2.3 2014-02-14 02:53:00 should be 2014-02-14 02:57:00.000 ; changing now.
# DONKI flare peak time 2014-06-10 07:00:00 has no match; dropping row.
# Messed up time: 12166 M2.1 2014-09-11 15:25:00 should be 2014-09-11 15:26:00.000 ; changing now.
# Messed up time: 12192 X1.1 2014-10-19 05:01:00 should be 2014-10-19 05:03:00.000 ; changing now.
# Messed up time: 12205 M2.7 2014-11-07 02:44:00 should be 2014-11-07 02:49:00.000 ; changing now.
# Messed up time: 12257 M2.2 2015-01-14 12:57:00 should be 2015-01-14 12:58:00.000 ; changing now.
# Messed up time: 12371 M1.0 2016-06-20 06:48:00 should be 2015-06-20 06:48:00.000 ; changing now.
# Messed up time: 12403 C3.4 2015-08-20 05:27:00 should be 2015-08-22 11:34:00.000 ; changing now.
# Messed up time: 12422 M1.1 2015-09-28 07:34:00 should be 2015-09-29 03:43:00.000 ; changing now.
# Messed up time: 12423 M1.3 2015-09-29 08:55:00 should be 2015-09-29 08:51:00.000 ; changing now.
# Messed up time: 12567 M1.0 2016-07-21 01:48:00 should be 2016-07-21 01:49:00.000 ; changing now.
# Messed up time: 12673 M1.1 2017-09-09 23:54:00 should be 2017-09-09 04:28:00.000 ; changing now.
# Messed up time: 12683 C1.7 2017-09-27 01:00:00 should be 2017-09-27 01:01:00.000 ; changing now.

# %%
flares
# Out:
#              beginTime                 peakTime            endTime classType  \
# 0    2010-06-12T00:30Z      2010-06-12 00:57:00  2010-06-12T01:02Z      M2.0
# 1    2010-08-07T17:55Z      2010-08-07 18:24:00  2010-08-07T18:47Z      M1.0
# 2    2010-10-16T19:07Z      2010-10-16 19:12:00  2010-10-16T19:15Z      M2.9
# 3    2011-01-28T00:44Z      2011-01-28 01:03:00  2011-01-28T01:10Z      M1.3
# 4    2011-02-09T01:23Z      2011-02-09 01:31:00  2011-02-09T01:35Z      M1.9
# ..                 ...                      ...                ...       ...
# 351  2017-09-13T07:39Z      2017-09-13 07:48:00  2017-09-13T08:09Z      B1.4
# 352  2017-09-20T12:32Z      2017-09-20 12:43:00  2017-09-20T13:00Z      B5.4
# 353  2017-09-20T19:28Z      2017-09-20 19:32:00  2017-09-20T19:49Z      B8.4
# 354  2017-09-26T02:31Z      2017-09-26 02:34:00  2017-09-26T02:43Z      C1.8
# 355  2017-09-27T00:49Z  2017-09-27 01:01:00.000  2017-09-27T01:16Z      C1.7
#
#      activeRegionNum linkedEvents
# 0            11081.0         None
# 1            11093.0         None
# 2            11112.0         None
# 3            11149.0         None
# 4            11153.0         None
# ..               ...          ...
# 351          12680.0         None
# 352          12681.0         None
# 353          12680.0         None
# 354          12683.0         None
# 355          12683.0         None
#
# [356 rows x 6 columns]

# %%
flares.to_csv("only_flares.csv", index=False)

# %% [markdown]
# #### flares with CME and SEP

# %%
# Case 1: filling nan ARs
number_of_donki_mistakes = 0  # count the number of DONKI mistakes
# create an empty array to hold row numbers to drop at the end
flare_linked_drops = []

for i in range(flare_linked.shape[0]):
    if (np.isnan(flare_linked.loc[i]['activeRegionNum'])):
        time = flare_linked['peakTime'].iloc[i]
        time_range = TimeRange(time, time)
        listofresult = Fido.search(a.Time(time_range),a.hek.EventType("FL"),a.hek.OBS.Observatory == "GOES")

        if len(listofresult["hek"]) == 0:
            print(flare_linked.loc[i]['classType'], "has no match in the GOES flare database ; dropping row.")
            flare_linked_drops.append(i)
            number_of_donki_mistakes += 1
            continue
        else:
            if (listofresult[0]['ar_noaanum'] == 0):
                print(flare_linked.loc[i]['activeRegionNum'], flare_linked.loc[i]
                    ['classType'], "has no match in the GOES flare database ; dropping row.")
                flare_linked_drops.append(i)
                number_of_donki_mistakes += 1
                continue
            else:
                print("Missing NOAA number:", flare_linked['activeRegionNum'].iloc[i], flare_linked['classType'].iloc[i],
                    flare_linked['peakTime'].iloc[i], "should be", listofresult[0]['ar_noaanum'][0], "; changing now.")
                flare_linked['activeRegionNum'].iloc[i] = listofresult[0]['ar_noaanum']
                number_of_donki_mistakes += 1

# Drop the rows for which there is no active region number in both the DONKI and GOES flare databases
flare_linked = flare_linked.drop(flare_linked_drops)
flare_linked = flare_linked.reset_index(drop=True)
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Missing NOAA number: nan X1.4 2011-09-22 11:01:00 should be 11302 ; changing now.
# Missing NOAA number: nan X1.3 2012-03-07 01:14:00 should be 11430 ; changing now.
# Missing NOAA number: nan M6.3 2012-03-09 03:53:00 should be 11429 ; changing now.
# Missing NOAA number: nan M5.1 2012-05-17 01:47:00 should be 11476 ; changing now.
# Missing NOAA number: nan X1.1 2012-07-06 23:08:00 should be 11515 ; changing now.
# Missing NOAA number: nan M6.2 2012-07-28 20:56:00 should be 11532 ; changing now.
# Missing NOAA number: nan M1.7 2012-11-08 02:23:00 should be 11611 ; changing now.
# Missing NOAA number: nan M1.2 2013-03-15 06:58:00 should be 11692 ; changing now.
# Missing NOAA number: nan X1.6 2013-05-13 02:17:00 should be 11748 ; changing now.
# Missing NOAA number: nan X2.8 2013-05-13 16:05:00 should be 11748 ; changing now.
# Missing NOAA number: nan X3.2 2013-05-14 01:11:00 should be 11748 ; changing now.
# Missing NOAA number: nan X1.2 2013-05-15 01:48:00 should be 11748 ; changing now.
# Missing NOAA number: nan M5.0 2013-05-22 13:38:00 should be 11745 ; changing now.
# nan M1.0 has no match in the GOES flare database ; dropping row.
# nan M1.1 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan X4.9 2014-02-25 00:49:00 should be 11990 ; changing now.
# nan M1.4 has no match in the GOES flare database ; dropping row.
# nan M2.2 has no match in the GOES flare database ; dropping row.
# nan C1.4 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M1.2 2015-03-05 18:11:00 should be 12297 ; changing now.
# Missing NOAA number: nan M3.0 2015-03-06 04:57:00 should be 12297 ; changing now.
# Missing NOAA number: nan M1.5 2015-03-06 08:15:00 should be 12297 ; changing now.
# nan M2.2 has no match in the GOES flare database ; dropping row.
# nan C2.1 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M2.8 2015-12-21 01:03:00 should be 12472 ; changing now.
# Missing NOAA number: nan M1.1 2015-12-21 10:19:00 should be 12472 ; changing now.
# nan B5.8 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan C4.0 2016-12-10 17:15:00 should be 12615 ; changing now.
# Missing NOAA number: nan C3.2 2017-03-27 11:12:00 should be 12645 ; changing now.
# Missing NOAA number: nan C3.3 2017-04-18 09:41:00 should be 12651 ; changing now.
# Missing NOAA number: nan C5.5 2017-04-18 20:10:00 should be 12651 ; changing now.
# Missing NOAA number: nan C7.7 2017-09-02 15:41:00 should be 12672 ; changing now.
# There are 32 DONKI mistakes so far.

# %%
# Case 2: Updating Incorrect AR
peak_times_noaa = [item["event_peaktime"] for item in listofresults["hek"]]

for i in range(flare_linked.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = flare_linked['peakTime'].iloc[i]
    if peak_time_donki in peak_times_noaa:
        index = peak_times_noaa.index(peak_time_donki)
    else:
        continue
    # ignore NOAA active region numbers equal to zero
    if (listofresults["hek"][index]['ar_noaanum'] == 0):
        continue
    # if yes, check if the DONKI and NOAA active region numbers match up for this peak time
    # if they don't, flag this peak time and replace the DONKI number with the NOAA number
    if (listofresults["hek"][index]['ar_noaanum'] != int(flare_linked['activeRegionNum'].iloc[i])):
        print('Messed up NOAA number:', int(flare_linked['activeRegionNum'].iloc[i]), flare_linked['classType'].iloc[i],
              flare_linked['peakTime'].iloc[i], "should be", listofresults["hek"][index]['ar_noaanum'], "; changing now.")
        flare_linked['activeRegionNum'].iloc[i] = listofresults["hek"][index]['ar_noaanum']
        number_of_donki_mistakes += 1
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Messed up NOAA number: 11093 C4.4 2010-08-14 10:05:00 should be 11099 ; changing now.
# Messed up NOAA number: 11283 X2.1 2011-09-06 22:20:00 should be 1283 ; changing now.
# Messed up NOAA number: 11560 C8.4 2012-08-31 20:43:00 should be 11562 ; changing now.
# Messed up NOAA number: 11943 X1.2 2014-01-07 18:32:00 should be 11944 ; changing now.
# Messed up NOAA number: 12051 M1.2 2014-05-07 16:29:00 should be 12055 ; changing now.
# Messed up NOAA number: 12160 M1.4 2014-07-01 11:23:00 should be 12106 ; changing now.
# Messed up NOAA number: 12282 M2.4 2015-02-09 23:35:00 should be 12280 ; changing now.
# Messed up NOAA number: 12321 M1.1 2015-04-23 10:07:00 should be 12322 ; changing now.
# Messed up NOAA number: 12565 M7.6 2016-07-23 05:16:00 should be 12567 ; changing now.
# Messed up NOAA number: 12565 M5.5 2016-07-23 05:31:00 should be 12567 ; changing now.
# There are 42 DONKI mistakes so far.

# %%
# Case 3: Updating flare peak time.

# create an empty array to hold row numbers to drop at the end
flare_linked_drops = []

active_region_numbers_noaa = [item["ar_noaanum"]
                              for item in listofresults["hek"]]
flare_classes_noaa = [item["fl_goescls"] for item in listofresults["hek"]]

for i in range(flare_linked.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = flare_linked['peakTime'].iloc[i]
    if not peak_time_donki in peak_times_noaa:
        active_region_number_donki = int(
            flare_linked['activeRegionNum'].iloc[i])
        flare_class_donki = flare_linked['classType'].iloc[i]
        flare_class_indices = [i for i, x in enumerate(
            flare_classes_noaa) if x == flare_class_donki]
        active_region_indices = [i for i, x in enumerate(
            active_region_numbers_noaa) if x == active_region_number_donki]
        common_indices = list(
            set(flare_class_indices).intersection(active_region_indices))
        if common_indices:
            print("Messed up time:", int(flare_linked['activeRegionNum'].iloc[i]), flare_linked['classType'].iloc[i],
                  flare_linked['peakTime'].iloc[i], "should be", peak_times_noaa[common_indices[0]], "; changing now.")
            flare_linked['peakTime'].iloc[i] = peak_times_noaa[common_indices[0]]
            number_of_donki_mistakes += 1
        if not common_indices:
            print("DONKI flare peak time",
                  flare_linked['peakTime'].iloc[i], "has no match; dropping row.")
            flare_linked_drops.append(i)
            number_of_donki_mistakes += 1

# Drop the rows for which the NOAA active region number and flare class associated with
# the messed-up flare peak time in the DONKI database has no match in the GOES flare database
flare_linked = flare_linked.drop(flare_linked_drops)
flare_linked = flare_linked.reset_index(drop=True)
# Out:
# Messed up time: 11429 X1.1 2012-03-05 04:05:00 should be 2012-03-05 04:09:00.000 ; changing now.
# DONKI flare peak time 2012-03-10 17:27:00 has no match; dropping row.
# Messed up time: 11745 M5.0 2013-05-22 13:38:00 should be 2013-05-22 13:32:00.000 ; changing now.
# DONKI flare peak time 2014-02-09 16:14:00 has no match; dropping row.
# Messed up time: 12127 M1.5 2014-08-01 18:12:00 should be 2014-08-01 18:13:00.000 ; changing now.
# Messed up time: 12146 M2.0 2014-08-25 15:10:00 should be 2014-08-25 15:11:00.000 ; changing now.
# DONKI flare peak time 2014-09-03 13:53:00 has no match; dropping row.
# DONKI flare peak time 2014-09-09 00:28:00 has no match; dropping row.
# Messed up time: 12172 M2.3 2014-09-23 23:15:00 should be 2014-09-23 23:16:00.000 ; changing now.
# Messed up time: 12242 X1.8 2014-12-20 00:24:00 should be 2014-12-20 00:28:00.000 ; changing now.
# DONKI flare peak time 2015-05-12 03:22:00 has no match; dropping row.
# Messed up time: 12445 M1.9 2015-11-04 03:25:00 should be 2015-11-04 03:26:00.000 ; changing now.
# Messed up time: 12473 M2.3 2015-01-02 00:10:00 should be 2016-01-02 00:11:00.000 ; changing now.
# Messed up time: 12522 C2.2 2016-03-16 06:45:00 should be 2016-03-16 06:46:00.000 ; changing now.
# Messed up time: 12671 C1.1 2017-08-15 13:51:00 should be 2017-08-14 16:24:00.000 ; changing now.

# %%
flare_linked.to_csv("flares_linked_cme_sep.csv", index=False)

# %% [markdown]
# #### only CMEs

# %%
cme.to_csv("only_cme.csv", index=False)

# %% [markdown]
# ### Fetching JSOC Data

# %%
jsoc = pd.read_csv('http://jsoc.stanford.edu/doc/data/hmi/harpnum_to_noaa/all_harps_with_noaa_ars.txt', sep=' ')

# %%
def get_the_jsoc_data(event_count, t_rec):
    """
    Parameters
    ----------
    event_count: number of events
                 int

    t_rec:       list of times, one associated with each event in event_count
                 list of strings in JSOC format ('%Y.%m.%d_%H:%M_TAI')

    """

    catalog_data = []
    classification = []

    for i in range(event_count):

        print("=====", i, "=====")
        # next match NOAA_ARS to HARPNUM
        idx = jsoc[jsoc['NOAA_ARS'].str.contains(
            str(int(listofactiveregions[i])))]

        # if there's no HARPNUM, quit
        if (idx.empty == True):
            print('skip: there are no matching HARPNUMs for',
                  str(int(listofactiveregions[i])))
            continue

        # construct jsoc_info queries and query jsoc database; we are querying for 25 keywords
        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (CODEVER7 !~ '1.1 ') and (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=USFLUX,MEANGBT,MEANJZH,MEANPOT,SHRGT45,TOTUSJH,MEANGBH,MEANALP,MEANGAM,MEANGBZ,MEANJZD,TOTUSJZ,SAVNCPP,TOTPOT,MEANSHR,AREA_ACR,R_VALUE,ABSNJZH"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: cannot successfully get an http response')
            continue

        # read the JSON output
        data = response.json()

        # if there are no data at this time, quit
        if data['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # check to see if the active region is too close to the limb
        # we can compute the latitude of an active region in stonyhurst coordinates as follows:
        # latitude_stonyhurst = CRVAL1 - CRLN_OBS
        # for this we have to query the CEA series (but above we queried the other series as the CEA series does not have CODEVER5 in it)

        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_cea_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=CRVAL1,CRLN_OBS"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: failed to find CEA JSOC data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # read the JSON output
        latitude_information = response.json()

        # if there are no data at this time, quit
        if latitude_information['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        CRVAL1 = float(latitude_information['keywords'][0]['values'][0])
        CRLN_OBS = float(latitude_information['keywords'][1]['values'][0])
        if (np.absolute(CRVAL1 - CRLN_OBS) > 70.0):
            print('skip: latitude is out of range for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        if ('MISSING' in str(data['keywords'])):
            print('skip: there are some missing keywords for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        print('accept NOAA Active Region number', str(int(
            listofactiveregions[i])), 'and HARPNUM', idx.HARPNUM.values[0], 'at time', t_rec[i])

        individual_flare_data = []
        for j in range(18):
            individual_flare_data.append(
                float(data['keywords'][j]['values'][0]))

        catalog_data.append(list(individual_flare_data))

        single_class_instance = [idx.HARPNUM.values[0], str(
            int(listofactiveregions[i])), listofgoesclasses[i], t_rec[i]]
        classification.append(single_class_instance)

    return catalog_data, classification

# %%
only_flares = pd.read_csv("only_flares.csv")
only_cme = pd.read_csv("only_cme.csv")
flares_linked = pd.read_csv("flares_linked_cme_sep.csv")

# %%
# Changing the peaktime to datetime format
from datetime import datetime

def convert_to_datetime(tstr):
    year = int(tstr[:4])
    month = int(tstr[5:7])
    day = int(tstr[8:10])
    hour = int(tstr[11:13])
    minute = int(tstr[14:16])
    return datetime(year, month, day, hour, minute)

for i in range(flares.shape[0]):
    only_flares['peakTime'].iloc[i] = convert_to_datetime(only_flares['peakTime'].iloc[i])
for i in range(cme.shape[0]):
    only_cme['startTime'].iloc[i] = convert_to_datetime(only_cme['startTime'].iloc[i])
for i in range(flare_linked.shape[0]):
    flare_linked['peakTime'].iloc[i] = convert_to_datetime(flare_linked['peakTime'].iloc[i])

# %%
type(only_cme["startTime"].iloc[0])
# Out:
# datetime.datetime

# %%
for j in [6]:
    timedelayvariable = j
    print("Timedelay variable:", timedelayvariable)
    t_rec = [(only_flares['peakTime'].iloc[i] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(only_flares.shape[0])]

    listofactiveregions = list(only_flares['activeRegionNum'].values.flatten())
    listofgoesclasses = list(only_flares['classType'].values.flatten())

    result = get_the_jsoc_data(only_flares.shape[0], t_rec)
    df1 = pd.DataFrame(result[0], columns=['USFLUX', 'MEANGBT', 'MEANJZH', 'MEANPOT', 'SHRGT45', 'TOTUSJH',
                                          'MEANGBH', 'MEANALP', 'MEANGAM', 'MEANGBZ', 'MEANJZD', 'TOTUSJZ', 'SAVNCPP',
                                          'TOTPOT', 'MEANSHR', 'AREA_ACR', 'R_VALUE', 'ABSNJZH'])
    df2 = pd.DataFrame(result[1], columns=['HARPNUM', 'NOAA_ARS', 'GOES_CLASS', 'PEAK_TIME'])
    df = pd.concat([df1, df2], axis=1)
    df.to_csv("/content/drive/MyDrive/Inceoglu/data/only_flares_" + str(timedelayvariable) + ".csv", index=False)
# Out:
# Timedelay variable: 6
# ===== 0 =====
# accept NOAA Active Region number 11081 and HARPNUM 54 at time 2010.06.11_18:57_TAI
# ===== 1 =====
# accept NOAA Active Region number 11093 and HARPNUM 115 at time 2010.08.07_12:24_TAI
# ===== 2 =====
# accept NOAA Active Region number 11112 and HARPNUM 211 at time 2010.10.16_13:12_TAI
# ===== 3 =====
# skip: there are no data for HARPNUM 345 at time 2011.01.27_19:03_TAI
# ===== 4 =====
# accept NOAA Active Region number 11153 and HARPNUM 362 at time 2011.02.08_19:31_TAI
# ===== 5 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.13_11:38_TAI
# ===== 6 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.14_11:26_TAI
# ===== 7 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.15_19:39_TAI
# ===== 8 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.18_04:11_TAI
# ===== 9 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.02.28_06:52_TAI
# ===== 10 =====
# skip: latitude is out of range for HARPNUM 394 at time 2011.03.07_20:29_TAI
# ===== 11 =====
# skip: latitude is out of range for HARPNUM 394 at time 2011.03.08_04:44_TAI
# ===== 12 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.09_17:23_TAI
# ===== 13 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.07.29_20:09_TAI
# ===== 14 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.05_19:50_TAI
# ===== 15 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.08_09:46_TAI
# ===== 16 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.24_07:20_TAI
# ===== 17 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.24_22:50_TAI
# ===== 18 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.03_14:27_TAI
# ===== 19 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.09_22:18_TAI
# ===== 20 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.02_04:52_TAI
# ===== 21 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_03:55_TAI
# ===== 22 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_05:44_TAI
# ===== 23 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.17_19:02_TAI
# ===== 24 =====
# skip: there are no data for HARPNUM 2137 at time 2012.10.20_12:14_TAI
# ===== 25 =====
# skip: there are no data for HARPNUM 2137 at time 2012.10.22_12:51_TAI
# ===== 26 =====
# skip: there are no data for HARPNUM 2137 at time 2012.10.22_21:17_TAI
# ===== 27 =====
# accept NOAA Active Region number 11613 and HARPNUM 2191 at time 2012.11.12_20:04_TAI
# ===== 28 =====
# skip: latitude is out of range for HARPNUM 2716 at time 2013.05.03_11:32_TAI
# ===== 29 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.21_18:22_TAI
# ===== 30 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.22_09:20_TAI
# ===== 31 =====
# accept NOAA Active Region number 11882 and HARPNUM 3311 at time 2013.10.26_13:53_TAI
# ===== 32 =====
# accept NOAA Active Region number 11884 and HARPNUM 3321 at time 2013.11.01_13:53_TAI
# ===== 33 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.05_16:12_TAI
# ===== 34 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2013.12.29_01:56_TAI
# ===== 35 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2013.12.31_15:58_TAI
# ===== 36 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2014.01.01_12:52_TAI
# ===== 37 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.01_20:33_TAI
# ===== 38 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.02_16:18_TAI
# ===== 39 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.03_06:50_TAI
# ===== 40 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.03_15:14_TAI
# ===== 41 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.04_04:25_TAI
# ===== 42 =====
# accept NOAA Active Region number 11946 and HARPNUM 3580 at time 2014.01.06_21:53_TAI
# ===== 43 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.07_04:13_TAI
# ===== 44 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.13_15:51_TAI
# ===== 45 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.30_00:39_TAI
# ===== 46 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_22:09_TAI
# ===== 47 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_01:31_TAI
# ===== 48 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_05:38_TAI
# ===== 49 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_06:46_TAI
# ===== 50 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_13:40_TAI
# ===== 51 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_16:16_TAI
# ===== 52 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.01.31_09:42_TAI
# ===== 53 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.31_19:25_TAI
# ===== 54 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.01_01:23_TAI
# ===== 55 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.02.02_00:34_TAI
# ===== 56 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_02:20_TAI
# ===== 57 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_03:31_TAI
# ===== 58 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_08:06_TAI
# ===== 59 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_12:11_TAI
# ===== 60 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_16:04_TAI
# ===== 61 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.02.03_19:23_TAI
# ===== 62 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.03_22:00_TAI
# ===== 63 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.04_03:49_TAI
# ===== 64 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.04_10:02_TAI
# ===== 65 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.05_10:20_TAI
# ===== 66 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_22:09_TAI
# ===== 67 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.06_22:56_TAI
# ===== 68 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.02.07_04:29_TAI
# ===== 69 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.11_10:51_TAI
# ===== 70 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.11_22:25_TAI
# ===== 71 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.12_00:58_TAI
# ===== 72 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.12_09:51_TAI
# ===== 73 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.12_19:40_TAI
# ===== 74 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.12_20:51_TAI
# ===== 75 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_00:07_TAI
# ===== 76 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_02:12_TAI
# ===== 77 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_09:57_TAI
# ===== 78 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_20:57_TAI
# ===== 79 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.14_06:40_TAI
# ===== 80 =====
# skip: there are no data for HARPNUM 3721 at time 2014.02.14_07:28_TAI
# ===== 81 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.14_10:39_TAI
# ===== 82 =====
# accept NOAA Active Region number 11982 and HARPNUM 3766 at time 2014.02.26_09:01_TAI
# ===== 83 =====
# accept NOAA Active Region number 11991 and HARPNUM 3804 at time 2014.02.27_18:48_TAI
# ===== 84 =====
# accept NOAA Active Region number 12002 and HARPNUM 3836 at time 2014.03.08_17:41_TAI
# ===== 85 =====
# skip: there are no data for HARPNUM 3836 at time 2014.03.09_07:58_TAI
# ===== 86 =====
# accept NOAA Active Region number 12002 and HARPNUM 3836 at time 2014.03.09_14:28_TAI
# ===== 87 =====
# accept NOAA Active Region number 12002 and HARPNUM 3836 at time 2014.03.09_18:26_TAI
# ===== 88 =====
# accept NOAA Active Region number 12002 and HARPNUM 3836 at time 2014.03.10_09:28_TAI
# ===== 89 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.10_17:00_TAI
# ===== 90 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.10_21:50_TAI
# ===== 91 =====
# skip: there are no data for HARPNUM 3804 at time 2014.03.11_06:07_TAI
# ===== 92 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.12_05:05_TAI
# ===== 93 =====
# skip: latitude is out of range for HARPNUM 3813 at time 2014.03.12_16:34_TAI
# ===== 94 =====
# skip: latitude is out of range for HARPNUM 3813 at time 2014.03.13_13:19_TAI
# ===== 95 =====
# accept NOAA Active Region number 12010 and HARPNUM 3856 at time 2014.03.19_21:56_TAI
# ===== 96 =====
# skip: there are no data for HARPNUM 3877 at time 2014.03.22_01:02_TAI
# ===== 97 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.28_13:18_TAI
# ===== 98 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.28_17:51_TAI
# ===== 99 =====
# skip: there are no data for HARPNUM 3894 at time 2014.03.30_05:55_TAI
# ===== 100 =====
# skip: latitude is out of range for HARPNUM 3879 at time 2014.03.31_02:07_TAI
# ===== 101 =====
# accept NOAA Active Region number 12035 and HARPNUM 4000 at time 2014.04.16_13:59_TAI
# ===== 102 =====
# skip: there are some missing keywords for HARPNUM 4000 at time 2014.04.21_23:47_TAI
# ===== 103 =====
# accept NOAA Active Region number 12056 and HARPNUM 4097 at time 2014.05.08_04:07_TAI
# ===== 104 =====
# accept NOAA Active Region number 12065 and HARPNUM 4138 at time 2014.05.24_12:35_TAI
# ===== 105 =====
# accept NOAA Active Region number 12077 and HARPNUM 4186 at time 2014.06.02_22:09_TAI
# ===== 106 =====
# accept NOAA Active Region number 12080 and HARPNUM 4197 at time 2014.06.06_13:31_TAI
# ===== 107 =====
# accept NOAA Active Region number 12080 and HARPNUM 4197 at time 2014.06.10_00:28_TAI
# ===== 108 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_04:17_TAI
# ===== 109 =====
# accept NOAA Active Region number 12080 and HARPNUM 4197 at time 2014.06.10_23:34_TAI
# ===== 110 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_02:09_TAI
# ===== 111 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_03:06_TAI
# ===== 112 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_15:03_TAI
# ===== 113 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_22:21_TAI
# ===== 114 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.12_03:37_TAI
# ===== 115 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.12_04:21_TAI
# ===== 116 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.12_12:13_TAI
# ===== 117 =====
# accept NOAA Active Region number 12089 and HARPNUM 4231 at time 2014.06.12_14:03_TAI
# ===== 118 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.12_15:13_TAI
# ===== 119 =====
# accept NOAA Active Region number 12087 and HARPNUM 4225 at time 2014.06.13_01:56_TAI
# ===== 120 =====
# skip: latitude is out of range for HARPNUM 4197 at time 2014.06.15_05:39_TAI
# ===== 121 =====
# skip: there are no data for HARPNUM 4225 at time 2014.06.15_18:01_TAI
# ===== 122 =====
# accept NOAA Active Region number 12113 and HARPNUM 4344 at time 2014.07.08_18:26_TAI
# ===== 123 =====
# skip: latitude is out of range for HARPNUM 4294 at time 2014.07.10_16:34_TAI
# ===== 124 =====
# accept NOAA Active Region number 12130 and HARPNUM 4396 at time 2014.07.31_05:14_TAI
# ===== 125 =====
# accept NOAA Active Region number 12130 and HARPNUM 4396 at time 2014.08.01_08:48_TAI
# ===== 126 =====
# skip: there are no matching HARPNUMs for 12149
# ===== 127 =====
# skip: there are no matching HARPNUMs for 12151
# ===== 128 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 129 =====
# skip: there are no matching HARPNUMs for 12166
# ===== 130 =====
# skip: there are no matching HARPNUMs for 12166
# ===== 131 =====
# skip: there are no matching HARPNUMs for 12169
# ===== 132 =====
# skip: latitude is out of range for HARPNUM 4616 at time 2014.09.27_02:37_TAI
# ===== 133 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 134 =====
# skip: there are no matching HARPNUMs for 12172
# ===== 135 =====
# skip: there are no data for HARPNUM 4639 at time 2014.10.08_19:43_TAI
# ===== 136 =====
# skip: there are no data for HARPNUM 4639 at time 2014.10.08_19:58_TAI
# ===== 137 =====
# accept NOAA Active Region number 12182 and HARPNUM 4639 at time 2014.10.09_00:59_TAI
# ===== 138 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.18_01:58_TAI
# ===== 139 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.18_23:03_TAI
# ===== 140 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_03:11_TAI
# ===== 141 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_10:37_TAI
# ===== 142 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_13:02_TAI
# ===== 143 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_14:04_TAI
# ===== 144 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_16:55_TAI
# ===== 145 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.21_07:38_TAI
# ===== 146 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.21_19:59_TAI
# ===== 147 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.21_23:17_TAI
# ===== 148 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.22_08:28_TAI
# ===== 149 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.23_03:50_TAI
# ===== 150 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.24_15:41_TAI
# ===== 151 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_11:08_TAI
# ===== 152 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_04:56_TAI
# ===== 153 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_11:17_TAI
# ===== 154 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_12:15_TAI
# ===== 155 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_12:49_TAI
# ===== 156 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_14:21_TAI
# ===== 157 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_18:34_TAI
# ===== 158 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_20:02_TAI
# ===== 159 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_21:41_TAI
# ===== 160 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_04:09_TAI
# ===== 161 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_08:47_TAI
# ===== 162 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_11:40_TAI
# ===== 163 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_20:42_TAI
# ===== 164 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_21:32_TAI
# ===== 165 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_08:06_TAI
# ===== 166 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_02:20_TAI
# ===== 167 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_04:01_TAI
# ===== 168 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_08:33_TAI
# ===== 169 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_10:20_TAI
# ===== 170 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_12:50_TAI
# ===== 171 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_15:22_TAI
# ===== 172 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_18:37_TAI
# ===== 173 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_19:35_TAI
# ===== 174 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.29_22:28_TAI
# ===== 175 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.05_19:39_TAI
# ===== 176 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.06_16:16_TAI
# ===== 177 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.06_20:49_TAI
# ===== 178 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.07_04:22_TAI
# ===== 179 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.09_09:32_TAI
# ===== 180 =====
# skip: there are no data for HARPNUM 4817 at time 2014.11.15_06:03_TAI
# ===== 181 =====
# accept NOAA Active Region number 12209 and HARPNUM 4817 at time 2014.11.16_11:48_TAI
# ===== 182 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.01_00:41_TAI
# ===== 183 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.04_02:10_TAI
# ===== 184 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.04_12:25_TAI
# ===== 185 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.04_13:41_TAI
# ===== 186 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.05_06:25_TAI
# ===== 187 =====
# skip: latitude is out of range for HARPNUM 4941 at time 2014.12.12_23:20_TAI
# ===== 188 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.14_13:33_TAI
# ===== 189 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.16_19:10_TAI
# ===== 190 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.17_13:01_TAI
# ===== 191 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.19_03:44_TAI
# ===== 192 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.21_01:32_TAI
# ===== 193 =====
# skip: latitude is out of range for HARPNUM 4920 at time 2014.12.21_19:49_TAI
# ===== 194 =====
# accept NOAA Active Region number 12249 and HARPNUM 4955 at time 2014.12.26_20:16_TAI
# ===== 195 =====
# accept NOAA Active Region number 12253 and HARPNUM 5011 at time 2015.01.03_03:47_TAI
# ===== 196 =====
# accept NOAA Active Region number 12253 and HARPNUM 5011 at time 2015.01.04_09:36_TAI
# ===== 197 =====
# accept NOAA Active Region number 12257 and HARPNUM 5026 at time 2015.01.12_22:58_TAI
# ===== 198 =====
# skip: latitude is out of range for HARPNUM 5026 at time 2015.01.14_06:58_TAI
# ===== 199 =====
# skip: latitude is out of range for HARPNUM 5107 at time 2015.01.21_22:52_TAI
# ===== 200 =====
# accept NOAA Active Region number 12268 and HARPNUM 5107 at time 2015.01.26_10:53_TAI
# ===== 201 =====
# accept NOAA Active Region number 12268 and HARPNUM 5107 at time 2015.01.27_22:41_TAI
# ===== 202 =====
# skip: latitude is out of range for HARPNUM 5127 at time 2015.01.28_15:37_TAI
# ===== 203 =====
# accept NOAA Active Region number 12268 and HARPNUM 5107 at time 2015.01.29_05:42_TAI
# ===== 204 =====
# accept NOAA Active Region number 12268 and HARPNUM 5107 at time 2015.01.29_18:44_TAI
# ===== 205 =====
# accept NOAA Active Region number 12268 and HARPNUM 5107 at time 2015.01.29_23:36_TAI
# ===== 206 =====
# skip: there are no data for HARPNUM 5127 at time 2015.01.30_06:16_TAI
# ===== 207 =====
# accept NOAA Active Region number 12277 and HARPNUM 5127 at time 2015.02.03_20:15_TAI
# ===== 208 =====
# accept NOAA Active Region number 12280 and HARPNUM 5144 at time 2015.02.11_20:12_TAI
# ===== 209 =====
# accept NOAA Active Region number 12294 and HARPNUM 5246 at time 2015.02.28_03:39_TAI
# ===== 210 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_00:39_TAI
# ===== 211 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_03:48_TAI
# ===== 212 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_09:28_TAI
# ===== 213 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_13:31_TAI
# ===== 214 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.09_08:33_TAI
# ===== 215 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.10_18:02_TAI
# ===== 216 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.11_01:18_TAI
# ===== 217 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.11_01:57_TAI
# ===== 218 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.11_12:51_TAI
# ===== 219 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.11_22:46_TAI
# ===== 220 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.12_05:50_TAI
# ===== 221 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.12_06:14_TAI
# ===== 222 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.12_08:08_TAI
# ===== 223 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.12_15:51_TAI
# ===== 224 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.12_22:01_TAI
# ===== 225 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.13_00:07_TAI
# ===== 226 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.13_22:40_TAI
# ===== 227 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.15_03:40_TAI
# ===== 228 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.15_17:22_TAI
# ===== 229 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.16_04:58_TAI
# ===== 230 =====
# accept NOAA Active Region number 12320 and HARPNUM 5415 at time 2015.04.08_08:43_TAI
# ===== 231 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.21_01:21_TAI
# ===== 232 =====
# skip: there are no data for HARPNUM 5446 at time 2015.04.21_05:57_TAI
# ===== 233 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.21_09:45_TAI
# ===== 234 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.21_11:00_TAI
# ===== 235 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.21_15:45_TAI
# ===== 236 =====
# accept NOAA Active Region number 12325 and HARPNUM 5447 at time 2015.04.21_16:01_TAI
# ===== 237 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.22_02:44_TAI
# ===== 238 =====
# skip: latitude is out of range for HARPNUM 5541 at time 2015.05.05_03:47_TAI
# ===== 239 =====
# skip: latitude is out of range for HARPNUM 5541 at time 2015.05.05_07:53_TAI
# ===== 240 =====
# accept NOAA Active Region number 12335 and HARPNUM 5526 at time 2015.05.05_08:25_TAI
# ===== 241 =====
# accept NOAA Active Region number 12335 and HARPNUM 5526 at time 2015.05.05_11:24_TAI
# ===== 242 =====
# skip: latitude is out of range for HARPNUM 5541 at time 2015.05.06_05:49_TAI
# ===== 243 =====
# accept NOAA Active Region number 12360 and HARPNUM 5637 at time 2015.06.08_21:53_TAI
# ===== 244 =====
# skip: latitude is out of range for HARPNUM 5673 at time 2015.06.11_02:55_TAI
# ===== 245 =====
# skip: latitude is out of range for HARPNUM 5637 at time 2015.06.13_01:29_TAI
# ===== 246 =====
# skip: latitude is out of range for HARPNUM 5637 at time 2015.06.13_18:59_TAI
# ===== 247 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.20_00:48_TAI
# ===== 248 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.24_09:29_TAI
# ===== 249 =====
# accept NOAA Active Region number 12373 and HARPNUM 5718 at time 2015.06.29_12:07_TAI
# ===== 250 =====
# accept NOAA Active Region number 12378 and HARPNUM 5738 at time 2015.07.03_06:51_TAI
# ===== 251 =====
# accept NOAA Active Region number 12381 and HARPNUM 5745 at time 2015.07.06_02:44_TAI
# ===== 252 =====
# accept NOAA Active Region number 12381 and HARPNUM 5745 at time 2015.07.06_14:40_TAI
# ===== 253 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.22_05:34_TAI
# ===== 254 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.20_20:18_TAI
# ===== 255 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.21_14:34_TAI
# ===== 256 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.22_07:23_TAI
# ===== 257 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.22_15:24_TAI
# ===== 258 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.24_01:33_TAI
# ===== 259 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.24_11:46_TAI
# ===== 260 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.26_23:44_TAI
# ===== 261 =====
# skip: there are no data for HARPNUM 5885 at time 2015.08.28_07:16_TAI
# ===== 262 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.28_13:03_TAI
# ===== 263 =====
# skip: latitude is out of range for HARPNUM 5885 at time 2015.08.29_21:30_TAI
# ===== 264 =====
# accept NOAA Active Region number 12414 and HARPNUM 5944 at time 2015.09.11_15:37_TAI
# ===== 265 =====
# skip: latitude is out of range for HARPNUM 5974 at time 2015.09.19_23:03_TAI
# ===== 266 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.27_04:40_TAI
# ===== 267 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.27_15:00_TAI
# ===== 268 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_21:43_TAI
# ===== 269 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_07:18_TAI
# ===== 270 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_08:58_TAI
# ===== 271 =====
# skip: latitude is out of range for HARPNUM 5982 at time 2015.09.28_21:16_TAI
# ===== 272 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_21:43_TAI
# ===== 273 =====
# accept NOAA Active Region number 12428 and HARPNUM 5990 at time 2015.09.28_22:46_TAI
# ===== 274 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_23:16_TAI
# ===== 275 =====
# skip: latitude is out of range for HARPNUM 5982 at time 2015.09.28_23:37_TAI
# ===== 276 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.28_23:56_TAI
# ===== 277 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.29_00:18_TAI
# ===== 278 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.29_00:43_TAI
# ===== 279 =====
# skip: latitude is out of range for HARPNUM 5982 at time 2015.09.29_02:51_TAI
# ===== 280 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.29_03:26_TAI
# ===== 281 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.29_05:15_TAI
# ===== 282 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.29_13:24_TAI
# ===== 283 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.30_04:59_TAI
# ===== 284 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.30_07:20_TAI
# ===== 285 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.10.01_07:10_TAI
# ===== 286 =====
# skip: there are no data for HARPNUM 5983 at time 2015.10.01_18:13_TAI
# ===== 287 =====
# skip: latitude is out of range for HARPNUM 5983 at time 2015.10.02_06:26_TAI
# ===== 288 =====
# skip: latitude is out of range for HARPNUM 5983 at time 2015.10.02_11:18_TAI
# ===== 289 =====
# skip: latitude is out of range for HARPNUM 5983 at time 2015.10.03_20:41_TAI
# ===== 290 =====
# accept NOAA Active Region number 12434 and HARPNUM 6015 at time 2015.10.15_17:31_TAI
# ===== 291 =====
# accept NOAA Active Region number 12434 and HARPNUM 6015 at time 2015.10.16_00:16_TAI
# ===== 292 =====
# skip: latitude is out of range for HARPNUM 6026 at time 2015.10.17_14:23_TAI
# ===== 293 =====
# skip: latitude is out of range for HARPNUM 6026 at time 2015.10.17_14:42_TAI
# ===== 294 =====
# accept NOAA Active Region number 12443 and HARPNUM 6063 at time 2015.10.31_11:52_TAI
# ===== 295 =====
# accept NOAA Active Region number 12443 and HARPNUM 6063 at time 2015.11.03_13:09_TAI
# ===== 296 =====
# skip: latitude is out of range for HARPNUM 6052 at time 2015.11.04_03:00_TAI
# ===== 297 =====
# skip: there are no data for HARPNUM 6052 at time 2015.11.04_06:03_TAI
# ===== 298 =====
# accept NOAA Active Region number 12449 and HARPNUM 6078 at time 2015.11.09_07:12_TAI
# ===== 299 =====
# skip: latitude is out of range for HARPNUM 6206 at time 2015.12.21_21:34_TAI
# ===== 300 =====
# skip: latitude is out of range for HARPNUM 6205 at time 2015.12.22_07:38_TAI
# ===== 301 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.23_20:12_TAI
# ===== 302 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.29_04:32_TAI
# ===== 303 =====
# accept NOAA Active Region number 12494 and HARPNUM 6320 at time 2016.02.04_12:22_TAI
# ===== 304 =====
# accept NOAA Active Region number 12497 and HARPNUM 6327 at time 2016.02.12_04:47_TAI
# ===== 305 =====
# accept NOAA Active Region number 12497 and HARPNUM 6327 at time 2016.02.13_09:24_TAI
# ===== 306 =====
# accept NOAA Active Region number 12497 and HARPNUM 6327 at time 2016.02.14_13:26_TAI
# ===== 307 =====
# accept NOAA Active Region number 12497 and HARPNUM 6327 at time 2016.02.15_05:00_TAI
# ===== 308 =====
# skip: latitude is out of range for HARPNUM 6327 at time 2016.02.16_23:01_TAI
# ===== 309 =====
# accept NOAA Active Region number 12561 and HARPNUM 6661 at time 2016.07.07_01:56_TAI
# ===== 310 =====
# skip: there are no data for HARPNUM 6670 at time 2016.07.20_18:46_TAI
# ===== 311 =====
# skip: there are no data for HARPNUM 6670 at time 2016.07.20_19:49_TAI
# ===== 312 =====
# accept NOAA Active Region number 12567 and HARPNUM 6670 at time 2016.07.22_20:11_TAI
# ===== 313 =====
# skip: latitude is out of range for HARPNUM 6670 at time 2016.07.24_00:20_TAI
# ===== 314 =====
# skip: latitude is out of range for HARPNUM 6670 at time 2016.07.24_11:43_TAI
# ===== 315 =====
# skip: latitude is out of range for HARPNUM 6699 at time 2016.08.08_18:42_TAI
# ===== 316 =====
# accept NOAA Active Region number 12615 and HARPNUM 6870 at time 2016.11.29_11:23_TAI
# ===== 317 =====
# accept NOAA Active Region number 12615 and HARPNUM 6870 at time 2016.11.29_17:38_TAI
# ===== 318 =====
# accept NOAA Active Region number 12628 and HARPNUM 6920 at time 2017.01.21_01:26_TAI
# ===== 319 =====
# accept NOAA Active Region number 12645 and HARPNUM 6975 at time 2017.03.27_12:20_TAI
# ===== 320 =====
# accept NOAA Active Region number 12645 and HARPNUM 6975 at time 2017.04.01_20:46_TAI
# ===== 321 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.02_07:00_TAI
# ===== 322 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.02_14:33_TAI
# ===== 323 =====
# accept NOAA Active Region number 12661 and HARPNUM 7034 at time 2017.06.02_11:57_TAI
# ===== 324 =====
# accept NOAA Active Region number 12665 and HARPNUM 7075 at time 2017.07.08_21:18_TAI
# ===== 325 =====
# skip: there are no matching HARPNUMs for 12667
# ===== 326 =====
# skip: latitude is out of range for HARPNUM 7107 at time 2017.08.14_20:15_TAI
# ===== 327 =====
# skip: there are no data for HARPNUM 7110 at time 2017.08.19_19:52_TAI
# ===== 328 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.03_23:49_TAI
# ===== 329 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_13:37_TAI
# ===== 330 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_14:02_TAI
# ===== 331 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_16:14_TAI
# ===== 332 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_19:08_TAI
# ===== 333 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_21:51_TAI
# ===== 334 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_22:53_TAI
# ===== 335 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.05_00:40_TAI
# ===== 336 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.05_11:43_TAI
# ===== 337 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_03:10_TAI
# ===== 338 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_09:56_TAI
# ===== 339 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_13:30_TAI
# ===== 340 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_17:39_TAI
# ===== 341 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_23:02_TAI
# ===== 342 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.07_03:54_TAI
# ===== 343 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.07_20:24_TAI
# ===== 344 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_09:47_TAI
# ===== 345 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_17:45_TAI
# ===== 346 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_22:28_TAI
# ===== 347 =====
# skip: latitude is out of range for HARPNUM 7115 at time 2017.09.09_05:04_TAI
# ===== 348 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_22:28_TAI
# ===== 349 =====
# skip: latitude is out of range for HARPNUM 7115 at time 2017.09.09_21:09_TAI
# ===== 350 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.11_04:10_TAI
# ===== 351 =====
# accept NOAA Active Region number 12680 and HARPNUM 7131 at time 2017.09.13_01:48_TAI
# ===== 352 =====
# skip: latitude is out of range for HARPNUM 7144 at time 2017.09.20_06:43_TAI
# ===== 353 =====
# accept NOAA Active Region number 12680 and HARPNUM 7131 at time 2017.09.20_13:32_TAI
# ===== 354 =====
# skip: latitude is out of range for HARPNUM 7148 at time 2017.09.25_20:34_TAI
# ===== 355 =====
# skip: there are no data for HARPNUM 7148 at time 2017.09.26_19:01_TAI

# %%
for j in [6]:
    timedelayvariable = j
    print("Timedelay variable:", timedelayvariable)
    t_rec = [(flare_linked['peakTime'].iloc[i] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(flare_linked.shape[0])]

    listofactiveregions = list(flare_linked['activeRegionNum'].values.flatten())
    listofgoesclasses = list(flare_linked['classType'].values.flatten())

    result = get_the_jsoc_data(flare_linked.shape[0], t_rec)
    df1 = pd.DataFrame(result[0], columns=['USFLUX', 'MEANGBT', 'MEANJZH', 'MEANPOT', 'SHRGT45', 'TOTUSJH',
                                          'MEANGBH', 'MEANALP', 'MEANGAM', 'MEANGBZ', 'MEANJZD', 'TOTUSJZ', 'SAVNCPP',
                                          'TOTPOT', 'MEANSHR', 'AREA_ACR', 'R_VALUE', 'ABSNJZH'])
    df2 = pd.DataFrame(result[1], columns=['HARPNUM', 'NOAA_ARS', 'GOES_CLASS', 'PEAK_TIME'])
    df = pd.concat([df1, df2], axis=1)
    df.to_csv("/content/drive/MyDrive/Inceoglu/data/flare_linked_" + str(timedelayvariable) + ".csv", index=False)
# Out:
# Timedelay variable: 6
# ===== 0 =====
# skip: there are no matching HARPNUMs for 11059
# ===== 1 =====
# accept NOAA Active Region number 11099 and HARPNUM 115 at time 2010.08.14_04:05_TAI
# ===== 2 =====
# skip: there are no data for HARPNUM 115 at time 2010.08.17_23:48_TAI
# ===== 3 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.14_19:56_TAI
# ===== 4 =====
# skip: latitude is out of range for HARPNUM 392 at time 2011.02.24_01:35_TAI
# ===== 5 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.07_08:30_TAI
# ===== 6 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.03.07_14:12_TAI
# ===== 7 =====
# skip: there are no data for HARPNUM 415 at time 2011.03.07_21:58_TAI
# ===== 8 =====
# accept NOAA Active Region number 11226 and HARPNUM 637 at time 2011.06.07_00:41_TAI
# ===== 9 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.08.03_07:48_TAI
# ===== 10 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.08.03_21:57_TAI
# ===== 11 =====
# skip: latitude is out of range for HARPNUM 753 at time 2011.08.09_02:05_TAI
# ===== 12 =====
# accept NOAA Active Region number 1283 and HARPNUM 833 at time 2011.09.06_16:20_TAI
# ===== 13 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.07_16:38_TAI
# ===== 14 =====
# skip: latitude is out of range for HARPNUM 892 at time 2011.09.22_05:01_TAI
# ===== 15 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.24_03:40_TAI
# ===== 16 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.24_14:36_TAI
# ===== 17 =====
# skip: there are no data for HARPNUM 1321 at time 2012.01.22_21:59_TAI
# ===== 18 =====
# skip: latitude is out of range for HARPNUM 1321 at time 2012.01.27_12:37_TAI
# ===== 19 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_22:09_TAI
# ===== 20 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.06_18:24_TAI
# ===== 21 =====
# skip: there are no data for HARPNUM 1449 at time 2012.03.06_19:14_TAI
# ===== 22 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.08_21:53_TAI
# ===== 23 =====
# accept NOAA Active Region number 11430 and HARPNUM 1449 at time 2012.03.10_09:52_TAI
# ===== 24 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.10_11:44_TAI
# ===== 25 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.13_11:41_TAI
# ===== 26 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.16_19:47_TAI
# ===== 27 =====
# skip: there are no data for HARPNUM 1750 at time 2012.06.13_07:17_TAI
# ===== 28 =====
# accept NOAA Active Region number 11504 and HARPNUM 1750 at time 2012.06.14_08:35_TAI
# ===== 29 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.06_17:08_TAI
# ===== 30 =====
# skip: latitude is out of range for HARPNUM 1807 at time 2012.07.08_10:32_TAI
# ===== 31 =====
# accept NOAA Active Region number 11520 and HARPNUM 1834 at time 2012.07.12_10:49_TAI
# ===== 32 =====
# skip: latitude is out of range for HARPNUM 1834 at time 2012.07.17_11:15_TAI
# ===== 33 =====
# skip: latitude is out of range for HARPNUM 1834 at time 2012.07.18_23:58_TAI
# ===== 34 =====
# accept NOAA Active Region number 11532 and HARPNUM 1879 at time 2012.07.28_14:56_TAI
# ===== 35 =====
# accept NOAA Active Region number 11562 and HARPNUM 1990 at time 2012.08.31_14:43_TAI
# ===== 36 =====
# skip: there are no data for HARPNUM 2040 at time 2012.09.27_17:57_TAI
# ===== 37 =====
# skip: latitude is out of range for HARPNUM 2186 at time 2012.11.07_20:23_TAI
# ===== 38 =====
# accept NOAA Active Region number 11618 and HARPNUM 2220 at time 2012.11.21_09:30_TAI
# ===== 39 =====
# skip: there are no data for HARPNUM 2546 at time 2013.03.15_00:58_TAI
# ===== 40 =====
# accept NOAA Active Region number 11719 and HARPNUM 2635 at time 2013.04.11_01:16_TAI
# ===== 41 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.12_20:17_TAI
# ===== 42 =====
# skip: latitude is out of range for HARPNUM 2748 at time 2013.05.13_10:05_TAI
# ===== 43 =====
# skip: latitude is out of range for HARPNUM 2748 at time 2013.05.13_19:11_TAI
# ===== 44 =====
# skip: latitude is out of range for HARPNUM 2748 at time 2013.05.14_19:48_TAI
# ===== 45 =====
# accept NOAA Active Region number 11745 and HARPNUM 2739 at time 2013.05.22_07:32_TAI
# ===== 46 =====
# skip: latitude is out of range for HARPNUM 2790 at time 2013.06.07_16:49_TAI
# ===== 47 =====
# skip: latitude is out of range for HARPNUM 2878 at time 2013.06.20_21:14_TAI
# ===== 48 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.22_15:20_TAI
# ===== 49 =====
# skip: there are no data for HARPNUM 3295 at time 2013.10.23_18:30_TAI
# ===== 50 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.25_02:01_TAI
# ===== 51 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.25_09:03_TAI
# ===== 52 =====
# skip: latitude is out of range for HARPNUM 3321 at time 2013.10.26_13:27_TAI
# ===== 53 =====
# skip: there are some missing keywords for HARPNUM 3291 at time 2013.10.27_20:03_TAI
# ===== 54 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.27_22:41_TAI
# ===== 55 =====
# skip: latitude is out of range for HARPNUM 3291 at time 2013.10.29_15:54_TAI
# ===== 56 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.07_22:26_TAI
# ===== 57 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.09_23:14_TAI
# ===== 58 =====
# skip: latitude is out of range for HARPNUM 3364 at time 2013.11.19_04:26_TAI
# ===== 59 =====
# accept NOAA Active Region number 11943 and HARPNUM 3563 at time 2014.01.04_13:46_TAI
# ===== 60 =====
# skip: latitude is out of range for HARPNUM 3535 at time 2014.01.04_16:52_TAI
# ===== 61 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.07_12:32_TAI
# ===== 62 =====
# skip: latitude is out of range for HARPNUM 3587 at time 2014.01.07_21:47_TAI
# ===== 63 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.30_02:11_TAI
# ===== 64 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.30_10:11_TAI
# ===== 65 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.10_21:31_TAI
# ===== 66 =====
# skip: latitude is out of range for HARPNUM 3793 at time 2014.02.24_18:49_TAI
# ===== 67 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.29_11:48_TAI
# ===== 68 =====
# accept NOAA Active Region number 12027 and HARPNUM 3941 at time 2014.04.02_08:05_TAI
# ===== 69 =====
# accept NOAA Active Region number 12036 and HARPNUM 3999 at time 2014.04.18_07:03_TAI
# ===== 70 =====
# skip: latitude is out of range for HARPNUM 4000 at time 2014.04.24_18:27_TAI
# ===== 71 =====
# skip: latitude is out of range for HARPNUM 4071 at time 2014.05.06_03:03_TAI
# ===== 72 =====
# skip: latitude is out of range for HARPNUM 4071 at time 2014.05.06_16:09_TAI
# ===== 73 =====
# accept NOAA Active Region number 12055 and HARPNUM 4097 at time 2014.05.07_10:29_TAI
# ===== 74 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_05:42_TAI
# ===== 75 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_06:52_TAI
# ===== 76 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.12_16:16_TAI
# ===== 77 =====
# accept NOAA Active Region number 12106 and HARPNUM 4294 at time 2014.07.01_05:23_TAI
# ===== 78 =====
# accept NOAA Active Region number 12113 and HARPNUM 4344 at time 2014.07.08_10:20_TAI
# ===== 79 =====
# accept NOAA Active Region number 12127 and HARPNUM 4396 at time 2014.08.01_12:13_TAI
# ===== 80 =====
# skip: there are no matching HARPNUMs for 12149
# ===== 81 =====
# skip: there are no matching HARPNUMs for 12146
# ===== 82 =====
# skip: there are no matching HARPNUMs for 12146
# ===== 83 =====
# skip: there are no matching HARPNUMs for 12158
# ===== 84 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 85 =====
# skip: there are no matching HARPNUMs for 12172
# ===== 86 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 87 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 88 =====
# accept NOAA Active Region number 12182 and HARPNUM 4639 at time 2014.10.10_10:47_TAI
# ===== 89 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.16_07:03_TAI
# ===== 90 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.24_01:48_TAI
# ===== 91 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.03_05:53_TAI
# ===== 92 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.03_16:40_TAI
# ===== 93 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.04_02:38_TAI
# ===== 94 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.04_03:04_TAI
# ===== 95 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.05_03:47_TAI
# ===== 96 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.05_13:44_TAI
# ===== 97 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.05_21:46_TAI
# ===== 98 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.06_22:25_TAI
# ===== 99 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.07_11:26_TAI
# ===== 100 =====
# accept NOAA Active Region number 12209 and HARPNUM 4817 at time 2014.11.15_14:46_TAI
# ===== 101 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.16_19:50_TAI
# ===== 102 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.16_22:51_TAI
# ===== 103 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.18_15:58_TAI
# ===== 104 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.19_18:28_TAI
# ===== 105 =====
# skip: there are no data for HARPNUM 4941 at time 2014.12.21_06:17_TAI
# ===== 106 =====
# accept NOAA Active Region number 12257 and HARPNUM 5026 at time 2015.01.12_22:24_TAI
# ===== 107 =====
# accept NOAA Active Region number 12280 and HARPNUM 5144 at time 2015.02.09_17:35_TAI
# ===== 108 =====
# skip: there are no data for HARPNUM 5233 at time 2015.03.02_19:35_TAI
# ===== 109 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.05_12:11_TAI
# ===== 110 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.05_22:57_TAI
# ===== 111 =====
# skip: latitude is out of range for HARPNUM 5298 at time 2015.03.06_02:15_TAI
# ===== 112 =====
# skip: latitude is out of range for HARPNUM 5298 at time 2015.03.07_16:22_TAI
# ===== 113 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.09_17:53_TAI
# ===== 114 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.09_21:24_TAI
# ===== 115 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.11_10:22_TAI
# ===== 116 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.14_20:13_TAI
# ===== 117 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.17_17:34_TAI
# ===== 118 =====
# skip: latitude is out of range for HARPNUM 5447 at time 2015.04.12_03:50_TAI
# ===== 119 =====
# accept NOAA Active Region number 12321 and HARPNUM 5447 at time 2015.04.18_08:19_TAI
# ===== 120 =====
# skip: there are no data for HARPNUM 5446 at time 2015.04.23_04:07_TAI
# ===== 121 =====
# skip: latitude is out of range for HARPNUM 5541 at time 2015.05.05_16:11_TAI
# ===== 122 =====
# accept NOAA Active Region number 12345 and HARPNUM 5541 at time 2015.05.13_12:18_TAI
# ===== 123 =====
# accept NOAA Active Region number 12364 and HARPNUM 5658 at time 2015.06.09_14:06_TAI
# ===== 124 =====
# skip: there are no data for HARPNUM 5653 at time 2015.06.17_19:27_TAI
# ===== 125 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.18_11:36_TAI
# ===== 126 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.20_19:42_TAI
# ===== 127 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.20_20:36_TAI
# ===== 128 =====
# accept NOAA Active Region number 12367 and HARPNUM 5673 at time 2015.06.21_03:44_TAI
# ===== 129 =====
# accept NOAA Active Region number 12367 and HARPNUM 5673 at time 2015.06.21_12:20_TAI
# ===== 130 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.22_12:23_TAI
# ===== 131 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.25_02:16_TAI
# ===== 132 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.21_03:48_TAI
# ===== 133 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.22_00:49_TAI
# ===== 134 =====
# accept NOAA Active Region number 12415 and HARPNUM 5956 at time 2015.09.20_12:03_TAI
# ===== 135 =====
# accept NOAA Active Region number 12423 and HARPNUM 5982 at time 2015.09.27_21:55_TAI
# ===== 136 =====
# accept NOAA Active Region number 12434 and HARPNUM 6015 at time 2015.10.21_21:40_TAI
# ===== 137 =====
# skip: there are no data for HARPNUM 6054 at time 2015.10.28_19:25_TAI
# ===== 138 =====
# skip: latitude is out of range for HARPNUM 6052 at time 2015.11.03_21:26_TAI
# ===== 139 =====
# accept NOAA Active Region number 12443 and HARPNUM 6063 at time 2015.11.04_07:52_TAI
# ===== 140 =====
# accept NOAA Active Region number 12458 and HARPNUM 6136 at time 2015.12.01_02:10_TAI
# ===== 141 =====
# accept NOAA Active Region number 12468 and HARPNUM 6172 at time 2015.12.16_03:03_TAI
# ===== 142 =====
# skip: there are no data for HARPNUM 6205 at time 2015.12.20_19:03_TAI
# ===== 143 =====
# skip: there are no data for HARPNUM 6205 at time 2015.12.21_04:19_TAI
# ===== 144 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.22_18:40_TAI
# ===== 145 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.28_06:45_TAI
# ===== 146 =====
# skip: there are no data for HARPNUM 6206 at time 2016.01.01_18:11_TAI
# ===== 147 =====
# skip: there are no data for HARPNUM 6289 at time 2016.01.28_06:02_TAI
# ===== 148 =====
# accept NOAA Active Region number 12497 and HARPNUM 6327 at time 2016.02.11_15:03_TAI
# ===== 149 =====
# skip: latitude is out of range for HARPNUM 6427 at time 2016.03.16_00:46_TAI
# ===== 150 =====
# accept NOAA Active Region number 12529 and HARPNUM 6483 at time 2016.04.09_07:42_TAI
# ===== 151 =====
# accept NOAA Active Region number 12529 and HARPNUM 6483 at time 2016.04.17_18:29_TAI
# ===== 152 =====
# skip: latitude is out of range for HARPNUM 6666 at time 2016.07.09_18:59_TAI
# ===== 153 =====
# accept NOAA Active Region number 12567 and HARPNUM 6670 at time 2016.07.22_23:16_TAI
# ===== 154 =====
# accept NOAA Active Region number 12567 and HARPNUM 6670 at time 2016.07.22_23:31_TAI
# ===== 155 =====
# skip: there are no data for HARPNUM 6870 at time 2016.12.10_11:15_TAI
# ===== 156 =====
# accept NOAA Active Region number 12645 and HARPNUM 6975 at time 2017.03.27_05:12_TAI
# ===== 157 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.01_13:56_TAI
# ===== 158 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.01_15:48_TAI
# ===== 159 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.02_02:02_TAI
# ===== 160 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.02_12:38_TAI
# ===== 161 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.02_19:05_TAI
# ===== 162 =====
# skip: latitude is out of range for HARPNUM 6972 at time 2017.04.03_08:29_TAI
# ===== 163 =====
# skip: latitude is out of range for HARPNUM 6986 at time 2017.04.18_03:41_TAI
# ===== 164 =====
# skip: latitude is out of range for HARPNUM 6986 at time 2017.04.18_14:10_TAI
# ===== 165 =====
# skip: latitude is out of range for HARPNUM 7058 at time 2017.07.02_06:39_TAI
# ===== 166 =====
# accept NOAA Active Region number 12665 and HARPNUM 7075 at time 2017.07.13_20:09_TAI
# ===== 167 =====
# accept NOAA Active Region number 12665 and HARPNUM 7075 at time 2017.07.15_13:36_TAI
# ===== 168 =====
# skip: latitude is out of range for HARPNUM 7107 at time 2017.08.14_10:24_TAI
# ===== 169 =====
# accept NOAA Active Region number 12671 and HARPNUM 7107 at time 2017.08.19_15:55_TAI
# ===== 170 =====
# skip: there are no data for HARPNUM 7110 at time 2017.09.02_09:41_TAI
# ===== 171 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_09:30_TAI
# ===== 172 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_12:22_TAI
# ===== 173 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_14:33_TAI
# ===== 174 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.06_06:02_TAI
# ===== 175 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.07_04:15_TAI
# ===== 176 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.07_08:36_TAI
# ===== 177 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.07_17:59_TAI
# ===== 178 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.07_21:43_TAI
# ===== 179 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_01:49_TAI
# ===== 180 =====
# skip: latitude is out of range for HARPNUM 7115 at time 2017.09.10_10:06_TAI
# ===== 181 =====
# accept NOAA Active Region number 12680 and HARPNUM 7131 at time 2017.09.12_01:29_TAI
# ===== 182 =====
# accept NOAA Active Region number 12680 and HARPNUM 7131 at time 2017.09.12_13:20_TAI
# ===== 183 =====
# skip: there are no data for HARPNUM 7169 at time 2017.10.20_17:28_TAI

# %%
def get_the_jsoc_data(event_count, t_rec):
    """
    Parameters
    ----------
    event_count: number of events
                 int

    t_rec:       list of times, one associated with each event in event_count
                 list of strings in JSOC format ('%Y.%m.%d_%H:%M_TAI')

    """

    catalog_data = []
    classification = []

    for i in range(event_count):

        print("=====", i, "=====")
        # next match NOAA_ARS to HARPNUM
        idx = jsoc[jsoc['NOAA_ARS'].str.contains(
            str(int(listofactiveregions[i])))]

        # if there's no HARPNUM, quit
        if (idx.empty == True):
            print('skip: there are no matching HARPNUMs for',
                  str(int(listofactiveregions[i])))
            continue

        # construct jsoc_info queries and query jsoc database; we are querying for 25 keywords
        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (CODEVER7 !~ '1.1 ') and (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=USFLUX,MEANGBT,MEANJZH,MEANPOT,SHRGT45,TOTUSJH,MEANGBH,MEANALP,MEANGAM,MEANGBZ,MEANJZD,TOTUSJZ,SAVNCPP,TOTPOT,MEANSHR,AREA_ACR,R_VALUE,ABSNJZH"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: cannot successfully get an http response')
            continue

        # read the JSON output
        data = response.json()

        # if there are no data at this time, quit
        if data['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # check to see if the active region is too close to the limb
        # we can compute the latitude of an active region in stonyhurst coordinates as follows:
        # latitude_stonyhurst = CRVAL1 - CRLN_OBS
        # for this we have to query the CEA series (but above we queried the other series as the CEA series does not have CODEVER5 in it)

        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_cea_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=CRVAL1,CRLN_OBS"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: failed to find CEA JSOC data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # read the JSON output
        latitude_information = response.json()

        # if there are no data at this time, quit
        if latitude_information['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        CRVAL1 = float(latitude_information['keywords'][0]['values'][0])
        CRLN_OBS = float(latitude_information['keywords'][1]['values'][0])
        if (np.absolute(CRVAL1 - CRLN_OBS) > 70.0):
            print('skip: latitude is out of range for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        if ('MISSING' in str(data['keywords'])):
            print('skip: there are some missing keywords for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        print('accept NOAA Active Region number', str(int(
            listofactiveregions[i])), 'and HARPNUM', idx.HARPNUM.values[0], 'at time', t_rec[i])

        individual_flare_data = []
        for j in range(18):
            individual_flare_data.append(
                float(data['keywords'][j]['values'][0]))

        catalog_data.append(list(individual_flare_data))

        single_class_instance = [idx.HARPNUM.values[0], str(
            int(listofactiveregions[i])), listofcmeanalysis[i], t_rec[i]]
        classification.append(single_class_instance)

    return catalog_data, classification

# %%
for j in [6]:
    timedelayvariable = j
    print("Timedelay variable:", timedelayvariable)
    t_rec = [(cme['startTime'].iloc[i] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(cme.shape[0])]

    listofactiveregions = list(cme['activeRegionNum'].values.flatten())
    listofcmeanalysis = list(cme['cmeAnalyses'].values.flatten())

    result = get_the_jsoc_data(cme.shape[0], t_rec)
    df1 = pd.DataFrame(result[0], columns=['USFLUX', 'MEANGBT', 'MEANJZH', 'MEANPOT', 'SHRGT45', 'TOTUSJH',
                                          'MEANGBH', 'MEANALP', 'MEANGAM', 'MEANGBZ', 'MEANJZD', 'TOTUSJZ', 'SAVNCPP',
                                          'TOTPOT', 'MEANSHR', 'AREA_ACR', 'R_VALUE', 'ABSNJZH'])
    df2 = pd.DataFrame(result[1], columns=['HARPNUM', 'NOAA_ARS', 'ANALYSIS', 'PEAK_TIME'])
    df = pd.concat([df1, df2], axis=1)
    df.to_csv("/content/drive/MyDrive/Inceoglu/data/only_cme_" + str(timedelayvariable) + ".csv", index=False)
# Out:
# Timedelay variable: 6
# ===== 0 =====
# accept NOAA Active Region number 11123 and HARPNUM 245 at time 2010.11.11_11:00_TAI
# ===== 1 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.10.01_03:54_TAI
# ===== 2 =====
# accept NOAA Active Region number 11305 and HARPNUM 902 at time 2011.10.01_04:24_TAI
# ===== 3 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_22:25_TAI
# ===== 4 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.05_02:36_TAI
# ===== 5 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.06_08:36_TAI
# ===== 6 =====
# accept NOAA Active Region number 11905 and HARPNUM 3420 at time 2013.11.25_22:36_TAI
# ===== 7 =====
# accept NOAA Active Region number 11909 and HARPNUM 3437 at time 2013.12.07_01:39_TAI
# ===== 8 =====
# skip: latitude is out of range for HARPNUM 3587 at time 2014.01.08_06:48_TAI
# ===== 9 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_22:36_TAI
# ===== 10 =====
# skip: there are no data for HARPNUM 2569 at time 2014.02.04_10:39_TAI
# ===== 11 =====
# skip: there are no data for HARPNUM 5233 at time 2014.03.02_21:18_TAI
# ===== 12 =====
# skip: there are no data for HARPNUM 5233 at time 2014.03.02_21:18_TAI
# ===== 13 =====
# skip: there are no data for HARPNUM 3856 at time 2014.03.17_06:48_TAI
# ===== 14 =====
# accept NOAA Active Region number 12013 and HARPNUM 3874 at time 2014.03.21_05:24_TAI
# ===== 15 =====
# skip: latitude is out of range for HARPNUM 3879 at time 2014.03.31_02:54_TAI
# ===== 16 =====
# accept NOAA Active Region number 12030 and HARPNUM 3941 at time 2014.04.02_22:54_TAI
# ===== 17 =====
# accept NOAA Active Region number 12030 and HARPNUM 3941 at time 2014.04.09_18:48_TAI
# ===== 18 =====
# accept NOAA Active Region number 12032 and HARPNUM 3985 at time 2014.04.09_22:24_TAI
# ===== 19 =====
# accept NOAA Active Region number 12036 and HARPNUM 3999 at time 2014.04.14_07:24_TAI
# ===== 20 =====
# skip: there are no data for HARPNUM 3999 at time 2014.04.17_18:12_TAI
# ===== 21 =====
# skip: there are no data for HARPNUM 3942 at time 2014.04.18_01:39_TAI
# ===== 22 =====
# accept NOAA Active Region number 12038 and HARPNUM 4000 at time 2014.04.21_15:28_TAI
# ===== 23 =====
# skip: latitude is out of range for HARPNUM 4097 at time 2014.05.05_09:36_TAI
# ===== 24 =====
# skip: latitude is out of range for HARPNUM 4071 at time 2014.05.06_12:09_TAI
# ===== 25 =====
# skip: latitude is out of range for HARPNUM 4156 at time 2014.05.19_17:24_TAI
# ===== 26 =====
# skip: latitude is out of range for HARPNUM 4156 at time 2014.05.20_20:12_TAI
# ===== 27 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.12_12:39_TAI
# ===== 28 =====
# accept NOAA Active Region number 12093 and HARPNUM 4252 at time 2014.06.20_06:24_TAI
# ===== 29 =====
# accept NOAA Active Region number 12113 and HARPNUM 4344 at time 2014.07.08_03:48_TAI
# ===== 30 =====
# accept NOAA Active Region number 12113 and HARPNUM 4344 at time 2014.07.10_17:12_TAI
# ===== 31 =====
# skip: latitude is out of range for HARPNUM 4294 at time 2014.07.11_03:24_TAI
# ===== 32 =====
# accept NOAA Active Region number 12119 and HARPNUM 4375 at time 2014.07.23_02:12_TAI
# ===== 33 =====
# skip: latitude is out of range for HARPNUM 4396 at time 2014.07.28_08:19_TAI
# ===== 34 =====
# accept NOAA Active Region number 12132 and HARPNUM 4396 at time 2014.08.02_21:24_TAI
# ===== 35 =====
# accept NOAA Active Region number 12132 and HARPNUM 4396 at time 2014.08.04_16:24_TAI
# ===== 36 =====
# accept NOAA Active Region number 12134 and HARPNUM 4424 at time 2014.08.05_10:24_TAI
# ===== 37 =====
# skip: there are no matching HARPNUMs for 12146
# ===== 38 =====
# skip: there are no matching HARPNUMs for 12147
# ===== 39 =====
# skip: there are no matching HARPNUMs for 12147
# ===== 40 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 41 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 42 =====
# skip: there are no matching HARPNUMs for 12156
# ===== 43 =====
# skip: there are no matching HARPNUMs for 12165
# ===== 44 =====
# accept NOAA Active Region number 12178 and HARPNUM 4616 at time 2014.09.28_23:00_TAI
# ===== 45 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.17_10:00_TAI
# ===== 46 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.21_11:48_TAI
# ===== 47 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.22_11:36_TAI
# ===== 48 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.27_00:12_TAI
# ===== 49 =====
# accept NOAA Active Region number 12208 and HARPNUM 4800 at time 2014.11.10_08:36_TAI
# ===== 50 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.11_06:36_TAI
# ===== 51 =====
# accept NOAA Active Region number 12207 and HARPNUM 4800 at time 2014.11.13_19:54_TAI
# ===== 52 =====
# accept NOAA Active Region number 12215 and HARPNUM 4839 at time 2014.11.18_20:12_TAI
# ===== 53 =====
# accept NOAA Active Region number 12215 and HARPNUM 4839 at time 2014.11.20_20:48_TAI
# ===== 54 =====
# accept NOAA Active Region number 12215 and HARPNUM 4839 at time 2014.11.21_01:12_TAI
# ===== 55 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.11.27_01:12_TAI
# ===== 56 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.11.28_00:12_TAI
# ===== 57 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.11.28_20:24_TAI
# ===== 58 =====
# skip: latitude is out of range for HARPNUM 4862 at time 2014.12.05_00:24_TAI
# ===== 59 =====
# accept NOAA Active Region number 12245 and HARPNUM 4969 at time 2014.12.22_04:00_TAI
# ===== 60 =====
# skip: latitude is out of range for HARPNUM 4941 at time 2014.12.24_23:36_TAI
# ===== 61 =====
# skip: latitude is out of range for HARPNUM 4941 at time 2014.12.25_03:12_TAI
# ===== 62 =====
# skip: there are no data for HARPNUM 4941 at time 2014.12.25_23:48_TAI
# ===== 63 =====
# accept NOAA Active Region number 12259 and HARPNUM 5039 at time 2015.01.17_04:36_TAI
# ===== 64 =====
# skip: latitude is out of range for HARPNUM 5127 at time 2015.01.28_17:06_TAI
# ===== 65 =====
# accept NOAA Active Region number 12282 and HARPNUM 5186 at time 2015.02.10_02:24_TAI
# ===== 66 =====
# accept NOAA Active Region number 12289 and HARPNUM 5230 at time 2015.02.27_00:36_TAI
# ===== 67 =====
# skip: there are no data for HARPNUM 5229 at time 2015.02.27_12:00_TAI
# ===== 68 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_00:24_TAI
# ===== 69 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.02_09:56_TAI
# ===== 70 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.14_11:06_TAI
# ===== 71 =====
# skip: latitude is out of range for HARPNUM 5298 at time 2015.03.19_20:00_TAI
# ===== 72 =====
# accept NOAA Active Region number 12314 and HARPNUM 5385 at time 2015.03.28_12:04_TAI
# ===== 73 =====
# skip: there are no data for HARPNUM 5342 at time 2015.03.28_18:00_TAI
# ===== 74 =====
# accept NOAA Active Region number 12320 and HARPNUM 5415 at time 2015.04.05_17:48_TAI
# ===== 75 =====
# accept NOAA Active Region number 12318 and HARPNUM 5422 at time 2015.04.05_23:48_TAI
# ===== 76 =====
# skip: there are no data for HARPNUM 5366 at time 2015.04.06_05:36_TAI
# ===== 77 =====
# accept NOAA Active Region number 12320 and HARPNUM 5415 at time 2015.04.09_17:12_TAI
# ===== 78 =====
# skip: latitude is out of range for HARPNUM 5447 at time 2015.04.12_06:24_TAI
# ===== 79 =====
# skip: there are no data for HARPNUM 5415 at time 2015.04.12_18:00_TAI
# ===== 80 =====
# skip: latitude is out of range for HARPNUM 5462 at time 2015.04.28_01:31_TAI
# ===== 81 =====
# accept NOAA Active Region number 12343 and HARPNUM 5545 at time 2015.05.10_23:00_TAI
# ===== 82 =====
# accept NOAA Active Region number 12337 and HARPNUM 5534 at time 2015.05.12_06:24_TAI
# ===== 83 =====
# accept NOAA Active Region number 12342 and HARPNUM 5545 at time 2015.05.13_21:36_TAI
# ===== 84 =====
# accept NOAA Active Region number 12365 and HARPNUM 5653 at time 2015.06.13_22:24_TAI
# ===== 85 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.17_21:18_TAI
# ===== 86 =====
# accept NOAA Active Region number 12367 and HARPNUM 5673 at time 2015.06.21_02:00_TAI
# ===== 87 =====
# skip: there are no data for HARPNUM 5673 at time 2015.06.22_18:00_TAI
# ===== 88 =====
# accept NOAA Active Region number 12381 and HARPNUM 5745 at time 2015.07.04_14:12_TAI
# ===== 89 =====
# skip: there are no data for HARPNUM 5736 at time 2015.07.05_08:00_TAI
# ===== 90 =====
# accept NOAA Active Region number 12381 and HARPNUM 5745 at time 2015.07.07_09:24_TAI
# ===== 91 =====
# accept NOAA Active Region number 12381 and HARPNUM 5745 at time 2015.07.14_00:36_TAI
# ===== 92 =====
# accept NOAA Active Region number 12388 and HARPNUM 5783 at time 2015.07.17_00:12_TAI
# ===== 93 =====
# accept NOAA Active Region number 12384 and HARPNUM 5758 at time 2015.07.18_23:24_TAI
# ===== 94 =====
# accept NOAA Active Region number 12392 and HARPNUM 5830 at time 2015.07.31_10:24_TAI
# ===== 95 =====
# skip: latitude is out of range for HARPNUM 5831 at time 2015.08.11_13:12_TAI
# ===== 96 =====
# accept NOAA Active Region number 12398 and HARPNUM 5856 at time 2015.08.15_07:25_TAI
# ===== 97 =====
# skip: there are no data for HARPNUM 5880 at time 2015.08.24_03:12_TAI
# ===== 98 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.25_10:00_TAI
# ===== 99 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.26_14:26_TAI
# ===== 100 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.28_01:12_TAI
# ===== 101 =====
# skip: there are no data for HARPNUM 5885 at time 2015.08.30_23:36_TAI
# ===== 102 =====
# skip: latitude is out of range for HARPNUM 5974 at time 2015.09.20_23:36_TAI
# ===== 103 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.23_13:00_TAI
# ===== 104 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.23_23:12_TAI
# ===== 105 =====
# accept NOAA Active Region number 12422 and HARPNUM 5983 at time 2015.09.25_10:12_TAI
# ===== 106 =====
# skip: there are no data for HARPNUM 5983 at time 2015.09.29_18:00_TAI
# ===== 107 =====
# skip: there are no data for HARPNUM 5974 at time 2015.10.04_00:48_TAI
# ===== 108 =====
# skip: latitude is out of range for HARPNUM 6026 at time 2015.10.17_15:36_TAI
# ===== 109 =====
# skip: there are no data for HARPNUM 6026 at time 2015.10.17_18:00_TAI
# ===== 110 =====
# skip: there are no data for HARPNUM 6050 at time 2015.10.27_07:25_TAI
# ===== 111 =====
# skip: there are no data for HARPNUM 5518 at time 2015.10.30_11:00_TAI
# ===== 112 =====
# accept NOAA Active Region number 12442 and HARPNUM 6052 at time 2015.11.01_06:48_TAI
# ===== 113 =====
# accept NOAA Active Region number 12441 and HARPNUM 6060 at time 2015.11.03_20:12_TAI
# ===== 114 =====
# skip: there are no data for HARPNUM 6060 at time 2015.11.05_11:00_TAI
# ===== 115 =====
# skip: latitude is out of range for HARPNUM 6078 at time 2015.11.07_00:00_TAI
# ===== 116 =====
# accept NOAA Active Region number 12448 and HARPNUM 6075 at time 2015.11.11_09:24_TAI
# ===== 117 =====
# accept NOAA Active Region number 12458 and HARPNUM 6136 at time 2015.12.01_21:12_TAI
# ===== 118 =====
# accept NOAA Active Region number 12462 and HARPNUM 6154 at time 2015.12.04_12:30_TAI
# ===== 119 =====
# accept NOAA Active Region number 12468 and HARPNUM 6172 at time 2015.12.13_05:12_TAI
# ===== 120 =====
# accept NOAA Active Region number 12468 and HARPNUM 6172 at time 2015.12.20_14:00_TAI
# ===== 121 =====
# skip: latitude is out of range for HARPNUM 6206 at time 2015.12.21_17:12_TAI
# ===== 122 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.24_00:24_TAI
# ===== 123 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.28_12:48_TAI
# ===== 124 =====
# accept NOAA Active Region number 12481 and HARPNUM 6247 at time 2016.01.08_10:30_TAI
# ===== 125 =====
# accept NOAA Active Region number 12483 and HARPNUM 6246 at time 2016.01.16_00:24_TAI
# ===== 126 =====
# accept NOAA Active Region number 12488 and HARPNUM 6289 at time 2016.01.28_01:24_TAI
# ===== 127 =====
# skip: latitude is out of range for HARPNUM 6281 at time 2016.01.29_15:17_TAI
# ===== 128 =====
# accept NOAA Active Region number 12489 and HARPNUM 6301 at time 2016.02.01_00:48_TAI
# ===== 129 =====
# accept NOAA Active Region number 12494 and HARPNUM 6320 at time 2016.02.07_23:36_TAI
# ===== 130 =====
# accept NOAA Active Region number 12501 and HARPNUM 6359 at time 2016.02.16_13:36_TAI
# ===== 131 =====
# skip: latitude is out of range for HARPNUM 6327 at time 2016.02.17_11:48_TAI
# ===== 132 =====
# accept NOAA Active Region number 12529 and HARPNUM 6483 at time 2016.04.16_15:54_TAI
# ===== 133 =====
# skip: there are no data for HARPNUM 6507 at time 2016.04.27_20:12_TAI
# ===== 134 =====
# accept NOAA Active Region number 12535 and HARPNUM 6507 at time 2016.04.28_00:36_TAI
# ===== 135 =====
# accept NOAA Active Region number 12535 and HARPNUM 6507 at time 2016.04.28_01:24_TAI
# ===== 136 =====
# accept NOAA Active Region number 12535 and HARPNUM 6507 at time 2016.05.04_07:41_TAI
# ===== 137 =====
# accept NOAA Active Region number 12544 and HARPNUM 6550 at time 2016.05.11_05:48_TAI
# ===== 138 =====
# accept NOAA Active Region number 12542 and HARPNUM 6537 at time 2016.05.15_09:36_TAI
# ===== 139 =====
# skip: latitude is out of range for HARPNUM 6558 at time 2016.05.26_10:12_TAI
# ===== 140 =====
# accept NOAA Active Region number 12553 and HARPNUM 6613 at time 2016.06.14_07:25_TAI
# ===== 141 =====
# accept NOAA Active Region number 12553 and HARPNUM 6613 at time 2016.06.20_23:12_TAI
# ===== 142 =====
# accept NOAA Active Region number 12565 and HARPNUM 6670 at time 2016.07.13_13:09_TAI
# ===== 143 =====
# skip: there are no data for HARPNUM 6657 at time 2016.07.15_07:36_TAI
# ===== 144 =====
# skip: there are no data for HARPNUM 6670 at time 2016.07.20_17:12_TAI
# ===== 145 =====
# skip: there are no data for HARPNUM 6670 at time 2016.07.20_18:36_TAI
# ===== 146 =====
# accept NOAA Active Region number 12565 and HARPNUM 6670 at time 2016.07.22_16:18_TAI
# ===== 147 =====
# skip: latitude is out of range for HARPNUM 6670 at time 2016.07.24_19:25_TAI
# ===== 148 =====
# skip: there are no data for HARPNUM 6681 at time 2016.07.26_01:24_TAI
# ===== 149 =====
# skip: there are no data for HARPNUM 6737 at time 2016.09.16_07:36_TAI
# ===== 150 =====
# accept NOAA Active Region number 12592 and HARPNUM 6759 at time 2016.09.16_09:36_TAI
# ===== 151 =====
# accept NOAA Active Region number 12597 and HARPNUM 6769 at time 2016.09.28_00:12_TAI
# ===== 152 =====
# skip: there are no data for HARPNUM 740 at time 2016.09.29_14:36_TAI
# ===== 153 =====
# skip: latitude is out of range for HARPNUM 6798 at time 2016.10.07_03:36_TAI
# ===== 154 =====
# accept NOAA Active Region number 12599 and HARPNUM 6794 at time 2016.10.11_12:48_TAI
# ===== 155 =====
# skip: latitude is out of range for HARPNUM 6803 at time 2016.10.22_11:24_TAI
# ===== 156 =====
# skip: there are no data for HARPNUM 6815 at time 2016.10.29_17:24_TAI
# ===== 157 =====
# skip: there are no data for HARPNUM 7115 at time 2017.01.11_07:34_TAI
# ===== 158 =====
# accept NOAA Active Region number 12646 and HARPNUM 6974 at time 2017.03.27_20:12_TAI
# ===== 159 =====
# skip: latitude is out of range for HARPNUM 6972 at time 2017.04.04_01:00_TAI
# ===== 160 =====
# skip: latitude is out of range for HARPNUM 6972 at time 2017.04.04_03:24_TAI
# ===== 161 =====
# skip: there are no data for HARPNUM 6972 at time 2017.04.04_06:00_TAI
# ===== 162 =====
# skip: latitude is out of range for HARPNUM 6972 at time 2017.04.04_11:24_TAI
# ===== 163 =====
# skip: latitude is out of range for HARPNUM 6972 at time 2017.04.04_15:36_TAI
# ===== 164 =====
# skip: there are no data for HARPNUM 6972 at time 2017.04.09_11:36_TAI
# ===== 165 =====
# skip: there are no data for HARPNUM 6972 at time 2017.04.10_06:39_TAI
# ===== 166 =====
# accept NOAA Active Region number 12651 and HARPNUM 6986 at time 2017.04.20_10:48_TAI
# ===== 167 =====
# skip: there are no data for HARPNUM 7058 at time 2017.07.03_10:48_TAI
# ===== 168 =====
# accept NOAA Active Region number 12665 and HARPNUM 7075 at time 2017.07.11_15:17_TAI
# ===== 169 =====
# skip: latitude is out of range for HARPNUM 7075 at time 2017.07.17_11:00_TAI
# ===== 170 =====
# accept NOAA Active Region number 12671 and HARPNUM 7107 at time 2017.08.16_09:36_TAI
# ===== 171 =====
# accept NOAA Active Region number 12672 and HARPNUM 7110 at time 2017.08.28_12:39_TAI
# ===== 172 =====
# skip: latitude is out of range for HARPNUM 7123 at time 2017.09.06_04:00_TAI
# ===== 173 =====
# skip: latitude is out of range for HARPNUM 7115 at time 2017.09.09_10:48_TAI
# ===== 174 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.11_07:34_TAI
# ===== 175 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.12_08:48_TAI
# ===== 176 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.12_14:42_TAI
# ===== 177 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.13_12:00_TAI
# ===== 178 =====
# skip: latitude is out of range for HARPNUM 7147 at time 2017.09.25_00:48_TAI
# ===== 179 =====
# accept NOAA Active Region number 12682 and HARPNUM 7147 at time 2017.09.25_16:24_TAI
# ===== 180 =====
# accept NOAA Active Region number 12683 and HARPNUM 7148 at time 2017.09.28_20:39_TAI
# ===== 181 =====
# accept NOAA Active Region number 12683 and HARPNUM 7148 at time 2017.10.07_02:48_TAI
# ===== 182 =====
# skip: there are no data for HARPNUM 7147 at time 2017.10.16_21:36_TAI
# ===== 183 =====
# accept NOAA Active Region number 12687 and HARPNUM 7189 at time 2017.11.16_08:54_TAI
# ===== 184 =====
# accept NOAA Active Region number 12692 and HARPNUM 7211 at time 2017.12.20_18:12_TAI
# ===== 185 =====
# accept NOAA Active Region number 12696 and HARPNUM 7229 at time 2018.01.21_21:12_TAI
