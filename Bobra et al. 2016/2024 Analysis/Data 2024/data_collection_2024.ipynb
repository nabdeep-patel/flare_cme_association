# %%
! pip install sunpy[all]
from IPython.display import clear_output
clear_output()

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # predicting coronal mass ejections using machine learning methods

# %% [markdown]
# A Coronal Mass Ejection (CME) throws magnetic flux and plasma from the Sun into interplanetary space. These eruptions are actually related to solar flares -- in fact, CMEs and solar flares are considered “a single magnetically driven event” ([Webb & Howard 2012](http://adsabs.harvard.edu/abs/2012LRSP....9....3W)), wherein a flare unassociated with a CME is called a confined or compact flare. <br>
#
# In general, the more energetic a flare, the more likely it is to be associated with a CME ([Yashiro et al. 2005](http://adsabs.harvard.edu/abs/2005JGRA..11012S05Y)) -- but this is not, by any means, a rule. For example, [Sun et al. (2015)](http://adsabs.harvard.edu/abs/2015ApJ...804L..28S) found that the largest active region in the last 24 years, shown below, produced 6 X-class flares but not a single observed CME.<br>
#
# In this notebook, we will be predicting whether or not a flaring active region will also emit a CME using a machine learning algorithm from the scikit-learn package called Support Vector Machine.
#
# The analysis that follows is published in [Bobra & Ilonidis, 2016, <i> Astrophysical Journal</i>, 821, 127](http://adsabs.harvard.edu/abs/2016ApJ...821..127B). If you use any of this code, we ask that you cite Bobra & Ilonidis (2016).

# %% [markdown]
# To do this analysis, we'll look at every active region observed by the Helioseismic and Magnetic Imager instrument on NASA's Solar Dynamics Observatory (SDO) satellite over the last eight years. Each active region is characterized by a bunch of features. These features describe the magnetic field at the solar surface. One feature, for example, is the total energy contained within an active region. Another is the total flux through an active region. We have 18 features, all of which are calculated every 12 minutes throughout an active region's lifetime. See [Bobra et al., 2014](http://link.springer.com/article/10.1007%2Fs11207-014-0529-3) for more information on how we calculate these features. <br>
#
# We'll then ascribe each active region to one of two classes:
#
# 1. The positive class contains flaring active regions that did produce a CME.
# 2. The negative class contains flaring active regions that did not produce a CME.

# %% [markdown]
# First, we'll import some modules.

# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib.mlab as mlab
import pandas as pd
import scipy.stats
import requests
import urllib
import json
from datetime import datetime as dt_obj
from datetime import timedelta
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sunpy.time import TimeRange
from sunpy.net import Fido, attrs as a

pd.set_option('display.max_rows', 500)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Now we'll gather the data. The data come from three different places:
#
# 1. CME data from SOHO/LASCO and STEREO/SECCHI coronographs, which can be accesed from the [DONKI database](http://kauai.ccmc.gsfc.nasa.gov/DONKI/) at NASA Goddard. This tells us if an active region has produced a CME or not.
# 2. Flare data from the GOES flare catalog at NOAA, which can be accessed with the `sunpy.instr.goes.get_event_list()` function. This tells us if an active region produced a flare or not.
# 3. Active region data from the Solar Dynamics Observatory's Heliosesmic and Magnetic Imager instrument, which can be accessed from the [JSOC database](http://jsoc.stanford.edu/) via a JSON API. This gives us the features characterizing each active region.

# %% [markdown]
# ### step 1: gathering data for the positive class

# %% [markdown]
# Let's first query the [DONKI database](http://kauai.ccmc.gsfc.nasa.gov/DONKI/) to get the data associated with the positive class. Be forewarned: there's a lot of data cleaning involved with building the positive class.

# %%
# request the data
baseurl = "https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/FLR?"
t_start = "2010-05-01"
t_end = "2024-12-31"
url = baseurl+"startDate="+t_start+"&endDate="+t_end

# if there's no response at this time, print warning
response = requests.get(url)
if response.status_code != 200:
    print('cannot successfully get an http response')

# %%
# read the data

print("Getting data from", url)
df = pd.read_json(url)

# select flares associated with a linked event (SEP or CME), and
# select only M or X-class flares
events_list = df.loc[df['classType'].str.contains("M|X") & ~df['linkedEvents'].isnull()]

# drop all rows that don't satisfy the above conditions
events_list = events_list.reset_index(drop=True)
# Out:
# Getting data from https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/FLR?startDate=2010-05-01&endDate=2024-12-31

# %%
# drop the rows that aren't linked to CME events
for i in range(events_list.shape[0]):
    value = events_list.loc[i]['linkedEvents'][0]['activityID']
    if not "CME" in value:
        print(value, "not a CME, dropping row")
        events_list = events_list.drop([i])
events_list = events_list.reset_index(drop=True)
# Out:
# 2011-08-09T08:40:00-SEP-001 not a CME, dropping row
# 2011-09-07T06:00:00-SEP-001 not a CME, dropping row
# 2011-09-24T20:45:00-SEP-001 not a CME, dropping row
# 2013-06-21T06:09:00-SEP-001 not a CME, dropping row
# 2015-03-06T19:20:00-SEP-001 not a CME, dropping row
# 2015-06-18T09:25:00-SEP-001 not a CME, dropping row
# 2015-06-21T20:35:00-SEP-001 not a CME, dropping row
# 2015-06-21T20:35:00-SEP-001 not a CME, dropping row
# 2023-07-18T01:00:00-SEP-002 not a CME, dropping row
# 2023-08-05T10:00:00-SEP-001 not a CME, dropping row
# 2024-01-22T13:00:00-SEP-001 not a CME, dropping row
# 2024-05-10T14:50:00-SEP-001 not a CME, dropping row
# 2024-09-09T20:55:00-SEP-002 not a CME, dropping row
# 2024-12-21T16:12:00-SEP-001 not a CME, dropping row
# 2024-12-21T16:12:00-SEP-001 not a CME, dropping row
# 2024-12-21T16:12:00-SEP-001 not a CME, dropping row

# %% [markdown]
# Convert the `peakTime` column in the `events_list` dataframe from a string into a datetime object:

# %%
def parse_tai_string(tstr):
    year = int(tstr[:4])
    month = int(tstr[5:7])
    day = int(tstr[8:10])
    hour = int(tstr[11:13])
    minute = int(tstr[14:16])
    return dt_obj(year, month, day, hour, minute)


for i in range(events_list.shape[0]):
    events_list['peakTime'].iloc[i] = parse_tai_string(events_list['peakTime'].iloc[i])

# %% [markdown]
# Check for Case 1: In this case, the CME and flare exist but NOAA active region number does not exist in the DONKI database.

# %%
# Case 1: CME and Flare exist but NOAA active region number does not exist in DONKI database

number_of_donki_mistakes = 0  # count the number of DONKI mistakes
# create an empty array to hold row numbers to drop at the end
event_list_drops = []

for i in range(events_list.shape[0]):
    if (np.isnan(events_list.loc[i]['activeRegionNum'])):
        time = events_list['peakTime'].iloc[i]
        time_range = TimeRange(time, time)
        listofresult = Fido.search(a.Time(time_range),a.hek.EventType("FL"),a.hek.FL.GOESCls > "M1.0",a.hek.OBS.Observatory == "GOES")

        if len(listofresult["hek"]) == 0:
            print(events_list.loc[i]['classType'], "has no match in the GOES flare database ; dropping row.")
            event_list_drops.append(i)
            number_of_donki_mistakes += 1
            continue
        else:
            if (listofresult[0]['ar_noaanum'] == 0):
                print(events_list.loc[i]['activeRegionNum'], events_list.loc[i]
                    ['classType'], "has no match in the GOES flare database ; dropping row.")
                event_list_drops.append(i)
                number_of_donki_mistakes += 1
                continue
            else:
                print("Missing NOAA number:", events_list['activeRegionNum'].iloc[i], events_list['classType'].iloc[i],
                    events_list['peakTime'].iloc[i], "should be", listofresult[0]['ar_noaanum'][0], "; changing now.")
                events_list['activeRegionNum'].iloc[i] = listofresult[0]['ar_noaanum']
                number_of_donki_mistakes += 1

# Drop the rows for which there is no active region number in both the DONKI and GOES flare databases
events_list = events_list.drop(event_list_drops)
events_list = events_list.reset_index(drop=True)
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Missing NOAA number: nan X1.4 2011-09-22 11:01:00 should be 11302 ; changing now.
# Missing NOAA number: nan X1.3 2012-03-07 01:14:00 should be 11430 ; changing now.
# Missing NOAA number: nan M6.3 2012-03-09 03:53:00 should be 11429 ; changing now.
# Missing NOAA number: nan M5.1 2012-05-17 01:47:00 should be 11476 ; changing now.
# Missing NOAA number: nan X1.1 2012-07-06 23:08:00 should be 11515 ; changing now.
# Missing NOAA number: nan M6.2 2012-07-28 20:56:00 should be 11532 ; changing now.
# Missing NOAA number: nan M1.7 2012-11-08 02:23:00 should be 11611 ; changing now.
# Missing NOAA number: nan M1.2 2013-03-15 06:58:00 should be 11692 ; changing now.
# Missing NOAA number: nan X1.6 2013-05-13 02:17:00 should be 11748 ; changing now.
# Missing NOAA number: nan X2.8 2013-05-13 16:05:00 should be 11748 ; changing now.
# Missing NOAA number: nan X3.2 2013-05-14 01:11:00 should be 11748 ; changing now.
# Missing NOAA number: nan X1.2 2013-05-15 01:48:00 should be 11748 ; changing now.
# Missing NOAA number: nan M5.0 2013-05-22 13:38:00 should be 11745 ; changing now.
# M1.0 has no match in the GOES flare database ; dropping row.
# nan M1.1 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan X4.9 2014-02-25 00:49:00 should be 11990 ; changing now.
# nan M1.4 has no match in the GOES flare database ; dropping row.
# nan M2.2 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M3.0 2015-03-06 04:57:00 should be 12297 ; changing now.
# Missing NOAA number: nan M1.5 2015-03-06 08:15:00 should be 12297 ; changing now.
# nan M2.2 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M2.8 2015-12-21 01:03:00 should be 12472 ; changing now.
# Missing NOAA number: nan M1.1 2015-12-21 10:19:00 should be 12472 ; changing now.
# nan M4.4 has no match in the GOES flare database ; dropping row.
# M1.4 has no match in the GOES flare database ; dropping row.
# M1.1 has no match in the GOES flare database ; dropping row.
# nan M5.4 has no match in the GOES flare database ; dropping row.
# Missing NOAA number: nan M5.5 2024-09-01 13:22:00 should be 13813 ; changing now.
# There are 28 DONKI mistakes so far.

# %% [markdown]
# Now we grab all the data from the GOES database in preparation for checking Cases 2 and 3.

# %%
# Grab all the data from the GOES database
t_start = "2010-05-01"
t_end = "2024-12-31"
time_range = TimeRange(t_start, t_end)
listofresults = Fido.search(a.Time(time_range),a.hek.EventType("FL"),a.hek.FL.GOESCls >= "M1.0",a.hek.OBS.Observatory == "GOES")
print('Grabbed all the GOES data; there are', len(listofresults["hek"]), 'events.')
# Out:
# Grabbed all the GOES data; there are 2302 events.

# %% [markdown]
# Check for Case 2: In this case, the NOAA active region number is wrong in the DONKI database.

# %%
# Case 2: NOAA active region number is wrong in DONKI database

# collect all the peak flares times in the NOAA database
peak_times_noaa = [item["event_peaktime"] for item in listofresults["hek"]]

for i in range(events_list.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = events_list['peakTime'].iloc[i]
    if peak_time_donki in peak_times_noaa:
        index = peak_times_noaa.index(peak_time_donki)
    else:
        continue
    # ignore NOAA active region numbers equal to zero
    if (listofresults["hek"][index]['ar_noaanum'] == 0):
        continue
    # if yes, check if the DONKI and NOAA active region numbers match up for this peak time
    # if they don't, flag this peak time and replace the DONKI number with the NOAA number
    if (listofresults["hek"][index]['ar_noaanum'] != int(events_list['activeRegionNum'].iloc[i])):
        print('Messed up NOAA number:', int(events_list['activeRegionNum'].iloc[i]), events_list['classType'].iloc[i],
              events_list['peakTime'].iloc[i], "should be", listofresults["hek"][index]['ar_noaanum'], "; changing now.")
        events_list['activeRegionNum'].iloc[i] = listofresults["hek"][index]['ar_noaanum']
        number_of_donki_mistakes += 1
print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Messed up NOAA number: 11943 X1.2 2014-01-07 18:32:00 should be 11944 ; changing now.
# Messed up NOAA number: 12051 M1.2 2014-05-07 16:29:00 should be 12055 ; changing now.
# Messed up NOAA number: 12160 M1.4 2014-07-01 11:23:00 should be 12106 ; changing now.
# Messed up NOAA number: 12282 M2.4 2015-02-09 23:35:00 should be 12280 ; changing now.
# Messed up NOAA number: 12321 M1.1 2015-04-23 10:07:00 should be 12322 ; changing now.
# Messed up NOAA number: 12565 M7.6 2016-07-23 05:16:00 should be 12567 ; changing now.
# Messed up NOAA number: 12565 M5.5 2016-07-23 05:31:00 should be 12567 ; changing now.
# Messed up NOAA number: 13191 M6.0 2023-01-15 03:42:00 should be 13188 ; changing now.
# Messed up NOAA number: 13312 M1.9 2023-05-22 13:37:00 should be 13314 ; changing now.
# Messed up NOAA number: 13561 M1.0 2024-01-23 13:08:00 should be 13559 ; changing now.
# Messed up NOAA number: 13615 M9.4 2024-03-30 21:16:00 should be 13515 ; changing now.
# Messed up NOAA number: 13638 M1.0 2024-04-19 13:06:00 should be 13647 ; changing now.
# Messed up NOAA number: 13730 M1.5 2024-07-03 07:41:00 should be 13729 ; changing now.
# Messed up NOAA number: 13762 M2.0 2024-07-27 10:40:00 should be 13767 ; changing now.
# Messed up NOAA number: 13766 M4.2 2024-07-29 14:46:00 should be 13772 ; changing now.
# Messed up NOAA number: 13772 M4.1 2024-08-01 11:37:00 should be 13768 ; changing now.
# Messed up NOAA number: 13765 X1.7 2024-08-05 13:40:00 should be 13767 ; changing now.
# Messed up NOAA number: 13777 M4.4 2024-08-14 04:02:00 should be 13774 ; changing now.
# Messed up NOAA number: 13823 M1.0 2024-09-14 04:31:00 should be 13825 ; changing now.
# Messed up NOAA number: 13852 M2.1 2024-10-11 16:33:00 should be 13854 ; changing now.
# There are 48 DONKI mistakes so far.

# %% [markdown]
# Check for Case 3: In this case, the flare peak time is wrong in the DONKI database.

# %%
# Case 3: The flare peak time is wrong in the DONKI database.

# create an empty array to hold row numbers to drop at the end
event_list_drops = []

active_region_numbers_noaa = [item["ar_noaanum"]
                              for item in listofresults["hek"]]
flare_classes_noaa = [item["fl_goescls"] for item in listofresults["hek"]]

for i in range(events_list.shape[0]):
    # check if a particular DONKI flare peak time is also in the NOAA database
    peak_time_donki = events_list['peakTime'].iloc[i]
    if not peak_time_donki in peak_times_noaa:
        active_region_number_donki = int(
            events_list['activeRegionNum'].iloc[i])
        flare_class_donki = events_list['classType'].iloc[i]
        flare_class_indices = [i for i, x in enumerate(
            flare_classes_noaa) if x == flare_class_donki]
        active_region_indices = [i for i, x in enumerate(
            active_region_numbers_noaa) if x == active_region_number_donki]
        common_indices = list(
            set(flare_class_indices).intersection(active_region_indices))
        if common_indices:
            print("Messed up time:", int(events_list['activeRegionNum'].iloc[i]), events_list['classType'].iloc[i],
                  events_list['peakTime'].iloc[i], "should be", peak_times_noaa[common_indices[0]], "; changing now.")
            events_list['peakTime'].iloc[i] = peak_times_noaa[common_indices[0]]
            number_of_donki_mistakes += 1
        if not common_indices:
            print("DONKI flare peak time",
                  events_list['peakTime'].iloc[i], "has no match; dropping row.")
            event_list_drops.append(i)
            number_of_donki_mistakes += 1

# Drop the rows for which the NOAA active region number and flare class associated with
# the messed-up flare peak time in the DONKI database has no match in the GOES flare database
events_list = events_list.drop(event_list_drops)
events_list = events_list.reset_index(drop=True)

# Create a list of corrected flare peak times
peak_times_donki = [events_list['peakTime'].iloc[i]
                    for i in range(events_list.shape[0])]

print('There are', number_of_donki_mistakes, 'DONKI mistakes so far.')
# Out:
# Messed up time: 11429 X1.1 2012-03-05 04:05:00 should be 2012-03-05 04:09:00.000 ; changing now.
# DONKI flare peak time 2012-03-10 17:27:00 has no match; dropping row.
# Messed up time: 11745 M5.0 2013-05-22 13:38:00 should be 2013-05-22 13:32:00.000 ; changing now.
# DONKI flare peak time 2014-02-09 16:14:00 has no match; dropping row.
# Messed up time: 12127 M1.5 2014-08-01 18:12:00 should be 2014-08-01 18:13:00.000 ; changing now.
# Messed up time: 12146 M2.0 2014-08-25 15:10:00 should be 2014-08-25 15:11:00.000 ; changing now.
# DONKI flare peak time 2014-09-03 13:53:00 has no match; dropping row.
# DONKI flare peak time 2014-09-09 00:28:00 has no match; dropping row.
# Messed up time: 12172 M2.3 2014-09-23 23:15:00 should be 2014-09-23 23:16:00.000 ; changing now.
# Messed up time: 12242 X1.8 2014-12-20 00:24:00 should be 2014-12-20 00:28:00.000 ; changing now.
# Messed up time: 12445 M1.9 2015-11-04 03:25:00 should be 2015-11-04 03:26:00.000 ; changing now.
# DONKI flare peak time 2021-11-02 02:51:00 has no match; dropping row.
# DONKI flare peak time 2022-03-28 19:23:00 has no match; dropping row.
# DONKI flare peak time 2022-08-26 13:17:00 has no match; dropping row.
# DONKI flare peak time 2022-08-29 16:39:00 has no match; dropping row.
# DONKI flare peak time 2022-09-17 13:19:00 has no match; dropping row.
# DONKI flare peak time 2022-12-16 04:59:00 has no match; dropping row.
# Messed up time: 13196 M1.0 2023-01-19 10:27:00 should be 2023-01-20 10:27:00.000 ; changing now.
# DONKI flare peak time 2023-02-21 11:11:00 has no match; dropping row.
# DONKI flare peak time 2023-05-07 23:23:00 has no match; dropping row.
# DONKI flare peak time 2023-06-22 23:44:00 has no match; dropping row.
# DONKI flare peak time 2023-07-18 00:06:00 has no match; dropping row.
# DONKI flare peak time 2023-07-27 22:34:00 has no match; dropping row.
# DONKI flare peak time 2023-08-05 07:22:00 has no match; dropping row.
# DONKI flare peak time 2023-08-07 16:11:00 has no match; dropping row.
# DONKI flare peak time 2023-08-22 23:04:00 has no match; dropping row.
# DONKI flare peak time 2023-08-26 22:50:00 has no match; dropping row.
# DONKI flare peak time 2023-09-01 03:52:00 has no match; dropping row.
# DONKI flare peak time 2023-09-30 16:32:00 has no match; dropping row.
# DONKI flare peak time 2023-11-14 23:05:00 has no match; dropping row.
# DONKI flare peak time 2023-11-28 19:32:00 has no match; dropping row.
# DONKI flare peak time 2023-11-28 19:50:00 has no match; dropping row.
# DONKI flare peak time 2023-12-01 21:20:00 has no match; dropping row.
# DONKI flare peak time 2023-12-22 00:04:00 has no match; dropping row.
# DONKI flare peak time 2024-03-28 20:46:00 has no match; dropping row.
# DONKI flare peak time 2024-03-30 22:53:00 has no match; dropping row.
# DONKI flare peak time 2024-05-08 04:30:00 has no match; dropping row.
# DONKI flare peak time 2024-05-08 12:04:00 has no match; dropping row.
# DONKI flare peak time 2024-05-13 09:33:00 has no match; dropping row.
# DONKI flare peak time 2024-05-15 10:35:00 has no match; dropping row.
# DONKI flare peak time 2024-05-29 16:22:00 has no match; dropping row.
# Messed up time: 13697 M7.3 2024-06-01 19:40:00 should be 2024-06-02 19:39:00.000 ; changing now.
# DONKI flare peak time 2024-07-28 14:22:00 has no match; dropping row.
# Messed up time: 13811 M1.2 2024-09-13 00:00:00 should be 2024-09-04 20:00:00.000 ; changing now.
# Messed up time: 13883 M1.1 2024-11-03 15:18:00 should be 2024-11-04 14:28:00.000 ; changing now.
# Messed up time: 13883 M5.5 2024-11-04 15:38:00 should be 2024-11-04 15:41:00.000 ; changing now.
# Messed up time: 13889 M1.6 2024-11-06 15:57:00 should be 2024-11-07 00:04:00.000 ; changing now.
# Messed up time: 13893 M1.1 2024-11-15 01:47:00 should be 2024-11-16 01:46:00.000 ; changing now.
# DONKI flare peak time 2024-12-10 06:48:00 has no match; dropping row.
# There are 97 DONKI mistakes so far.

# %% [markdown]
# This is our final table of events that fall into the positive class:

# %%
events_list
# Out:
#                            flrID      catalog  \
# 0    2011-02-15T01:44:00-FLR-001  M2M_CATALOG
# 1    2011-02-24T07:23:00-FLR-001  M2M_CATALOG
# 2    2011-03-07T13:44:00-FLR-001  M2M_CATALOG
# 3    2011-03-07T19:43:00-FLR-001  M2M_CATALOG
# 4    2011-03-08T03:37:00-FLR-001  M2M_CATALOG
# ..                           ...          ...
# 518  2024-12-25T04:46:00-FLR-001  M2M_CATALOG
# 519  2024-12-25T23:59:00-FLR-001  M2M_CATALOG
# 520  2024-12-29T04:18:00-FLR-001  M2M_CATALOG
# 521  2024-12-29T16:56:00-FLR-001  M2M_CATALOG
# 522  2024-12-30T04:01:00-FLR-001  M2M_CATALOG
#
#                                       instruments          beginTime  \
# 0    [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2011-02-15T01:44Z
# 1    [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2011-02-24T07:23Z
# 2    [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2011-03-07T13:44Z
# 3    [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2011-03-07T19:43Z
# 4    [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2011-03-08T03:37Z
# ..                                            ...                ...
# 518     [{'displayName': 'GOES-S: EXIS 1.0-8.0'}]  2024-12-25T04:46Z
# 519     [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2024-12-25T23:59Z
# 520     [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2024-12-29T04:18Z
# 521     [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2024-12-29T16:56Z
# 522     [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2024-12-30T04:01Z
#
#                 peakTime            endTime classType sourceLocation  \
# 0    2011-02-15 01:56:00  2011-02-15T02:06Z      X2.2         S20W10
# 1    2011-02-24 07:35:00  2011-02-24T07:42Z      M3.5         N14E87
# 2    2011-03-07 14:30:00  2011-03-07T15:08Z      M2.0         N11E21
# 3    2011-03-07 20:12:00  2011-03-07T21:40Z      M3.7         N30W48
# 4    2011-03-08 03:58:00  2011-03-08T04:20Z      M1.5         S21E72
# ..                   ...                ...       ...            ...
# 518  2024-12-25 04:49:00  2024-12-25T04:53Z      M4.9         S18E10
# 519  2024-12-26 00:30:00  2024-12-26T00:53Z      M3.1         N20E52
# 520  2024-12-29 04:30:00  2024-12-29T04:45Z      M2.0         S15E30
# 521  2024-12-29 17:08:00  2024-12-29T17:20Z      M3.3         S12E23
# 522  2024-12-30 04:14:00  2024-12-30T04:28Z      X1.5         N13W46
#
#      activeRegionNum                                               note  \
# 0            11158.0
# 1            11163.0
# 2            11166.0
# 3            11164.0
# 4            11171.0
# ..               ...                                                ...
# 518          13932.0
# 519          13938.0  Simultaneous flaring from AR 3938 (N20E52) and...
# 520          13939.0
# 521          13939.0
# 522          13936.0
#
#         submissionTime  versionId  \
# 0    2015-07-16T19:24Z          2
# 1    2015-07-16T19:28Z          2
# 2    2013-07-18T13:28Z          1
# 3    2013-07-18T18:41Z          1
# 4    2013-07-18T19:11Z          1
# ..                 ...        ...
# 518  2024-12-25T13:40Z          1
# 519  2024-12-26T16:51Z          2
# 520  2024-12-29T14:21Z          1
# 521  2024-12-29T20:43Z          1
# 522  2025-01-06T14:03Z          3
#
#                                                   link  \
# 0    https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 1    https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 2    https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 3    https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 4    https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# ..                                                 ...
# 518  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 519  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 520  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 521  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
# 522  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/FL...
#
#                                         linkedEvents  \
# 0    [{'activityID': '2011-02-15T02:25:00-CME-001'}]
# 1    [{'activityID': '2011-02-24T08:00:00-CME-001'}]
# 2    [{'activityID': '2011-03-07T14:40:00-CME-001'}]
# 3    [{'activityID': '2011-03-07T20:12:00-CME-001'}]
# 4    [{'activityID': '2011-03-08T05:00:00-CME-001'}]
# ..                                               ...
# 518  [{'activityID': '2024-12-25T04:48:00-CME-001'}]
# 519  [{'activityID': '2024-12-26T01:25:00-CME-001'}]
# 520  [{'activityID': '2024-12-29T06:24:00-CME-001'}]
# 521  [{'activityID': '2024-12-29T18:24:00-CME-001'}]
# 522  [{'activityID': '2024-12-30T05:24:00-CME-001'}]
#
#                                      sentNotifications
# 0    [{'messageID': '20110215-AL-001', 'messageIssu...
# 1    [{'messageID': '20110224-AL-001', 'messageIssu...
# 2    [{'messageID': '20110307-AL-001', 'messageIssu...
# 3    [{'messageID': '20110307-AL-002', 'messageIssu...
# 4    [{'messageID': '20110308-AL-004', 'messageIssu...
# ..                                                 ...
# 518                                               None
# 519                                               None
# 520                                               None
# 521                                               None
# 522  [{'messageID': '20241230-AL-002', 'messageIssu...
#
# [523 rows x 15 columns]

# %% [markdown]
# Now let's query the JSOC database to see if there are active region parameters at the time of the flare. First read the following file to map NOAA active region numbers to HARPNUMs (a HARP, or an HMI Active Region Patch, is the preferred numbering system for the HMI active regions as they appear in the magnetic field data before NOAA observes them in white light):

# %%
answer = pd.read_csv('http://jsoc.stanford.edu/doc/data/hmi/harpnum_to_noaa/all_harps_with_noaa_ars.txt', sep=' ')

# %% [markdown]
# Now, let's determine at which time we'd like to predict CMEs. In general, many people try to predict a CME either 24 or 48 hours before it happens. We can report both in this study by setting a variable called `timedelayvariable`:

# %% [markdown]
# Now, we'll convert subtract `timedelayvariable` from the GOES Peak Time and re-format the datetime object into a string that JSOC can understand:

# %% [markdown]
# Now we can grab the SDO data from the JSOC database by executing the JSON queries. We are selecting data that satisfies several criteria: The data has to be [1] disambiguated with a version of the disambiguation module greater than 1.1, [2] taken while the orbital velocity of the spacecraft is less than 3500 m/s, [3] of a high quality, and [4] within 70 degrees of central meridian. If the data pass all these tests, they are stuffed into one of two lists: one for the positive class (called CME_data) and one for the negative class (called no_CME_data).

# %%
def get_the_jsoc_data(event_count, t_rec):
    """
    Parameters
    ----------
    event_count: number of events
                 int

    t_rec:       list of times, one associated with each event in event_count
                 list of strings in JSOC format ('%Y.%m.%d_%H:%M_TAI')

    peaktime:    the peak time of the event in question
                 datetime object

    """

    catalog_data = []
    classification = []

    for i in range(event_count):

        print("=====", i, "=====")
        # next match NOAA_ARS to HARPNUM
        idx = answer[answer['NOAA_ARS'].str.contains(
            str(int(listofactiveregions[i])))]

        # if there's no HARPNUM, quit
        if (idx.empty == True):
            print('skip: there are no matching HARPNUMs for',
                  str(int(listofactiveregions[i])))
            continue

        # construct jsoc_info queries and query jsoc database; we are querying for 25 keywords
        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (CODEVER7 !~ '1.1 ') and (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=USFLUX,MEANGBT,MEANJZH,MEANPOT,SHRGT45,TOTUSJH,MEANGBH,MEANALP,MEANGAM,MEANGBZ,MEANJZD,TOTUSJZ,SAVNCPP,TOTPOT,MEANSHR,AREA_ACR,R_VALUE,ABSNJZH"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: cannot successfully get an http response')
            continue

        # read the JSON output
        data = response.json()

        # if there are no data at this time, quit
        if data['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # check to see if the active region is too close to the limb
        # we can compute the latitude of an active region in stonyhurst coordinates as follows:
        # latitude_stonyhurst = CRVAL1 - CRLN_OBS
        # for this we have to query the CEA series (but above we queried the other series as the CEA series does not have CODEVER5 in it)

        url = "http://jsoc.stanford.edu/cgi-bin/ajax/jsoc_info?ds=hmi.sharp_cea_720s["+str(
            idx.HARPNUM.values[0])+"]["+t_rec[i]+"][? (abs(OBS_VR)< 3500) and (QUALITY<65536) ?]&op=rs_list&key=CRVAL1,CRLN_OBS"
        response = requests.get(url)

        # if there's no response at this time, quit
        if response.status_code != 200:
            print('skip: failed to find CEA JSOC data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        # read the JSON output
        latitude_information = response.json()

        # if there are no data at this time, quit
        if latitude_information['count'] == 0:
            print('skip: there are no data for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        CRVAL1 = float(latitude_information['keywords'][0]['values'][0])
        CRLN_OBS = float(latitude_information['keywords'][1]['values'][0])
        if (np.absolute(CRVAL1 - CRLN_OBS) > 70.0):
            print('skip: latitude is out of range for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        if ('MISSING' in str(data['keywords'])):
            print('skip: there are some missing keywords for HARPNUM',
                  idx.HARPNUM.values[0], 'at time', t_rec[i])
            continue

        print('accept NOAA Active Region number', str(int(
            listofactiveregions[i])), 'and HARPNUM', idx.HARPNUM.values[0], 'at time', t_rec[i])

        individual_flare_data = []
        for j in range(18):
            individual_flare_data.append(
                float(data['keywords'][j]['values'][0]))

        catalog_data.append(list(individual_flare_data))

        single_class_instance = [idx.HARPNUM.values[0], str(
            int(listofactiveregions[i])), listofgoesclasses[i], t_rec[i], peaktimes[i]]
        classification.append(single_class_instance)

    return catalog_data, classification

# %% [markdown]
# Now we prepare the data to be fed into the function:

# %%
listofactiveregions = list(events_list['activeRegionNum'].values.flatten())
listofgoesclasses = list(events_list['classType'].values.flatten())
peaktimes = list(events_list['peakTime'].values.flatten())

# %% [markdown]
# And call the function:

# %%
for i in range(48,50,4):
  timedelayvariable = i
  t_rec = [(events_list['peakTime'].iloc[i] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(events_list.shape[0])]
  positive_result = get_the_jsoc_data(events_list.shape[0], t_rec)
  positive_df = pd.concat([pd.DataFrame(positive_result[0]), pd.DataFrame(positive_result[1])], axis=1)
  positive_df.columns = ["USFLUX", "MEANGBT", "MEANJZH", "MEANPOT", "SHRGT45", "TOTUSJH", "MEANGBH",
              "MEANALP", "MEANGAM", "MEANGBZ", "MEANJZD", "TOTUSJZ", "SAVNCPP", "TOTPOT",
              "MEANSHR", "AREA_ACR", "R_VALUE", "ABSNJZH", "HARPNUM", "NOAA", "Class", "T_REC", "Peak Time"]
  positive_df.to_csv(f"positive{i}.csv")
# Out:
# ===== 0 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.13_01:56_TAI
# ===== 1 =====
# skip: there are no data for HARPNUM 392 at time 2011.02.22_07:35_TAI
# ===== 2 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.05_14:30_TAI
# ===== 3 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.03.05_20:12_TAI
# ===== 4 =====
# skip: there are no data for HARPNUM 415 at time 2011.03.06_03:58_TAI
# ===== 5 =====
# accept NOAA Active Region number 11226 and HARPNUM 637 at time 2011.06.05_06:41_TAI
# ===== 6 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.08.01_13:48_TAI
# ===== 7 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.08.02_03:57_TAI
# ===== 8 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.05_22:38_TAI
# ===== 9 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.20_11:01_TAI
# ===== 10 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.22_09:40_TAI
# ===== 11 =====
# accept NOAA Active Region number 11402 and HARPNUM 1321 at time 2012.01.21_03:59_TAI
# ===== 12 =====
# accept NOAA Active Region number 11402 and HARPNUM 1321 at time 2012.01.25_18:37_TAI
# ===== 13 =====
# skip: latitude is out of range for HARPNUM 1449 at time 2012.03.03_04:09_TAI
# ===== 14 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.05_00:24_TAI
# ===== 15 =====
# accept NOAA Active Region number 11430 and HARPNUM 1449 at time 2012.03.05_01:14_TAI
# ===== 16 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.07_03:53_TAI
# ===== 17 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.08_17:44_TAI
# ===== 18 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.11_17:41_TAI
# ===== 19 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.15_01:47_TAI
# ===== 20 =====
# accept NOAA Active Region number 11504 and HARPNUM 1750 at time 2012.06.11_13:17_TAI
# ===== 21 =====
# accept NOAA Active Region number 11504 and HARPNUM 1750 at time 2012.06.12_14:35_TAI
# ===== 22 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_23:08_TAI
# ===== 23 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.06_16:32_TAI
# ===== 24 =====
# skip: there are no data for HARPNUM 1834 at time 2012.07.10_16:49_TAI
# ===== 25 =====
# accept NOAA Active Region number 11520 and HARPNUM 1834 at time 2012.07.15_17:15_TAI
# ===== 26 =====
# skip: there are no data for HARPNUM 1834 at time 2012.07.17_05:58_TAI
# ===== 27 =====
# accept NOAA Active Region number 11532 and HARPNUM 1879 at time 2012.07.26_20:56_TAI
# ===== 28 =====
# skip: there are no data for HARPNUM 2186 at time 2012.11.06_02:23_TAI
# ===== 29 =====
# accept NOAA Active Region number 11618 and HARPNUM 2220 at time 2012.11.19_15:30_TAI
# ===== 30 =====
# skip: there are no data for HARPNUM 2546 at time 2013.03.13_06:58_TAI
# ===== 31 =====
# accept NOAA Active Region number 11719 and HARPNUM 2635 at time 2013.04.09_07:16_TAI
# ===== 32 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.11_02:17_TAI
# ===== 33 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.11_16:05_TAI
# ===== 34 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.12_01:11_TAI
# ===== 35 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.13_01:48_TAI
# ===== 36 =====
# accept NOAA Active Region number 11745 and HARPNUM 2739 at time 2013.05.20_13:32_TAI
# ===== 37 =====
# accept NOAA Active Region number 11762 and HARPNUM 2790 at time 2013.06.05_22:49_TAI
# ===== 38 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.20_21:20_TAI
# ===== 39 =====
# accept NOAA Active Region number 11877 and HARPNUM 3295 at time 2013.10.22_00:30_TAI
# ===== 40 =====
# skip: there are no data for HARPNUM 3311 at time 2013.10.23_08:01_TAI
# ===== 41 =====
# skip: there are no data for HARPNUM 3311 at time 2013.10.23_15:03_TAI
# ===== 42 =====
# skip: there are no data for HARPNUM 3321 at time 2013.10.24_19:27_TAI
# ===== 43 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.26_02:03_TAI
# ===== 44 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.26_04:41_TAI
# ===== 45 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.27_21:54_TAI
# ===== 46 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.06_04:26_TAI
# ===== 47 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.08_05:14_TAI
# ===== 48 =====
# skip: there are some missing keywords for HARPNUM 3364 at time 2013.11.17_10:26_TAI
# ===== 49 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.02_19:46_TAI
# ===== 50 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2014.01.02_22:52_TAI
# ===== 51 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.05_18:32_TAI
# ===== 52 =====
# accept NOAA Active Region number 11947 and HARPNUM 3587 at time 2014.01.06_03:47_TAI
# ===== 53 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_08:11_TAI
# ===== 54 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_16:11_TAI
# ===== 55 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.09_03:31_TAI
# ===== 56 =====
# skip: there are no data for HARPNUM 3793 at time 2014.02.23_00:49_TAI
# ===== 57 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.27_17:48_TAI
# ===== 58 =====
# skip: latitude is out of range for HARPNUM 3941 at time 2014.03.31_14:05_TAI
# ===== 59 =====
# accept NOAA Active Region number 12036 and HARPNUM 3999 at time 2014.04.16_13:03_TAI
# ===== 60 =====
# accept NOAA Active Region number 12035 and HARPNUM 4000 at time 2014.04.23_00:27_TAI
# ===== 61 =====
# accept NOAA Active Region number 12051 and HARPNUM 4071 at time 2014.05.04_09:03_TAI
# ===== 62 =====
# accept NOAA Active Region number 12051 and HARPNUM 4071 at time 2014.05.04_22:09_TAI
# ===== 63 =====
# skip: latitude is out of range for HARPNUM 4097 at time 2014.05.05_16:29_TAI
# ===== 64 =====
# skip: there are no data for HARPNUM 4225 at time 2014.06.08_11:42_TAI
# ===== 65 =====
# skip: there are no data for HARPNUM 4225 at time 2014.06.08_12:52_TAI
# ===== 66 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.10_22:16_TAI
# ===== 67 =====
# skip: latitude is out of range for HARPNUM 4294 at time 2014.06.29_11:23_TAI
# ===== 68 =====
# skip: latitude is out of range for HARPNUM 4344 at time 2014.07.06_16:20_TAI
# ===== 69 =====
# skip: there are no data for HARPNUM 4396 at time 2014.07.30_18:13_TAI
# ===== 70 =====
# skip: there are no matching HARPNUMs for 12149
# ===== 71 =====
# skip: there are no matching HARPNUMs for 12146
# ===== 72 =====
# skip: there are no matching HARPNUMs for 12146
# ===== 73 =====
# skip: there are no matching HARPNUMs for 12158
# ===== 74 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 75 =====
# skip: there are no matching HARPNUMs for 12172
# ===== 76 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 77 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 78 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.14_13:03_TAI
# ===== 79 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.22_07:48_TAI
# ===== 80 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.01_11:53_TAI
# ===== 81 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.01_22:40_TAI
# ===== 82 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.02_08:38_TAI
# ===== 83 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.02_09:04_TAI
# ===== 84 =====
# skip: there are no data for HARPNUM 4781 at time 2014.11.03_09:47_TAI
# ===== 85 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.03_19:44_TAI
# ===== 86 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.04_03:46_TAI
# ===== 87 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.05_04:25_TAI
# ===== 88 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.05_17:26_TAI
# ===== 89 =====
# skip: latitude is out of range for HARPNUM 4817 at time 2014.11.13_20:46_TAI
# ===== 90 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.15_01:50_TAI
# ===== 91 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.15_04:51_TAI
# ===== 92 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.16_21:58_TAI
# ===== 93 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.18_00:28_TAI
# ===== 94 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.19_12:17_TAI
# ===== 95 =====
# accept NOAA Active Region number 12257 and HARPNUM 5026 at time 2015.01.11_04:24_TAI
# ===== 96 =====
# accept NOAA Active Region number 12280 and HARPNUM 5144 at time 2015.02.07_23:35_TAI
# ===== 97 =====
# skip: latitude is out of range for HARPNUM 5233 at time 2015.03.01_01:35_TAI
# ===== 98 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.04_04:57_TAI
# ===== 99 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.04_08:15_TAI
# ===== 100 =====
# skip: there are no data for HARPNUM 5298 at time 2015.03.05_22:22_TAI
# ===== 101 =====
# skip: latitude is out of range for HARPNUM 5298 at time 2015.03.07_23:53_TAI
# ===== 102 =====
# skip: latitude is out of range for HARPNUM 5298 at time 2015.03.08_03:24_TAI
# ===== 103 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.09_16:22_TAI
# ===== 104 =====
# accept NOAA Active Region number 12297 and HARPNUM 5298 at time 2015.03.15_23:34_TAI
# ===== 105 =====
# skip: there are no data for HARPNUM 5447 at time 2015.04.10_09:50_TAI
# ===== 106 =====
# skip: latitude is out of range for HARPNUM 5446 at time 2015.04.21_10:07_TAI
# ===== 107 =====
# skip: there are no data for HARPNUM 5541 at time 2015.05.03_22:11_TAI
# ===== 108 =====
# skip: latitude is out of range for HARPNUM 5692 at time 2015.06.16_17:36_TAI
# ===== 109 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.19_01:42_TAI
# ===== 110 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.19_02:36_TAI
# ===== 111 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.20_18:23_TAI
# ===== 112 =====
# accept NOAA Active Region number 12371 and HARPNUM 5692 at time 2015.06.23_08:16_TAI
# ===== 113 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.19_09:48_TAI
# ===== 114 =====
# accept NOAA Active Region number 12403 and HARPNUM 5885 at time 2015.08.20_06:49_TAI
# ===== 115 =====
# skip: there are no data for HARPNUM 5956 at time 2015.09.18_18:03_TAI
# ===== 116 =====
# accept NOAA Active Region number 12423 and HARPNUM 5982 at time 2015.09.26_03:55_TAI
# ===== 117 =====
# accept NOAA Active Region number 12445 and HARPNUM 6052 at time 2015.11.02_03:26_TAI
# ===== 118 =====
# accept NOAA Active Region number 12443 and HARPNUM 6063 at time 2015.11.02_13:52_TAI
# ===== 119 =====
# skip: there are no data for HARPNUM 6205 at time 2015.12.19_01:03_TAI
# ===== 120 =====
# skip: there are no data for HARPNUM 6205 at time 2015.12.19_10:19_TAI
# ===== 121 =====
# skip: there are no data for HARPNUM 6206 at time 2015.12.21_00:40_TAI
# ===== 122 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.26_12:45_TAI
# ===== 123 =====
# accept NOAA Active Region number 12473 and HARPNUM 6206 at time 2015.12.31_00:11_TAI
# ===== 124 =====
# accept NOAA Active Region number 12529 and HARPNUM 6483 at time 2016.04.16_00:29_TAI
# ===== 125 =====
# accept NOAA Active Region number 12567 and HARPNUM 6670 at time 2016.07.21_05:16_TAI
# ===== 126 =====
# accept NOAA Active Region number 12567 and HARPNUM 6670 at time 2016.07.21_05:31_TAI
# ===== 127 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.03.30_21:48_TAI
# ===== 128 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.03.31_08:02_TAI
# ===== 129 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.03.31_18:38_TAI
# ===== 130 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.01_01:05_TAI
# ===== 131 =====
# accept NOAA Active Region number 12644 and HARPNUM 6972 at time 2017.04.01_14:29_TAI
# ===== 132 =====
# accept NOAA Active Region number 12665 and HARPNUM 7075 at time 2017.07.12_02:09_TAI
# ===== 133 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.02_15:30_TAI
# ===== 134 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.02_18:22_TAI
# ===== 135 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.02_20:33_TAI
# ===== 136 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.04_12:02_TAI
# ===== 137 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.05_10:15_TAI
# ===== 138 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.05_14:36_TAI
# ===== 139 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.05_23:59_TAI
# ===== 140 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.06_03:43_TAI
# ===== 141 =====
# skip: there are no data for HARPNUM 7115 at time 2017.09.06_07:49_TAI
# ===== 142 =====
# accept NOAA Active Region number 12673 and HARPNUM 7115 at time 2017.09.08_16:06_TAI
# ===== 143 =====
# skip: there are no data for HARPNUM 7169 at time 2017.10.18_23:28_TAI
# ===== 144 =====
# accept NOAA Active Region number 12816 and HARPNUM 7570 at time 2021.04.17_23:42_TAI
# ===== 145 =====
# skip: there are no data for HARPNUM 7581 at time 2021.05.05_19:04_TAI
# ===== 146 =====
# accept NOAA Active Region number 12824 and HARPNUM 7590 at time 2021.05.20_21:36_TAI
# ===== 147 =====
# accept NOAA Active Region number 12824 and HARPNUM 7590 at time 2021.05.21_11:08_TAI
# ===== 148 =====
# skip: there are no data for HARPNUM 7652 at time 2021.07.01_07:17_TAI
# ===== 149 =====
# skip: there are no data for HARPNUM 7652 at time 2021.07.01_14:29_TAI
# ===== 150 =====
# skip: there are no data for HARPNUM 7652 at time 2021.07.01_17:03_TAI
# ===== 151 =====
# skip: there are no data for HARPNUM 7652 at time 2021.07.02_05:09_TAI
# ===== 152 =====
# accept NOAA Active Region number 12860 and HARPNUM 7716 at time 2021.08.26_06:11_TAI
# ===== 153 =====
# accept NOAA Active Region number 12871 and HARPNUM 7745 at time 2021.09.21_04:42_TAI
# ===== 154 =====
# accept NOAA Active Region number 12871 and HARPNUM 7745 at time 2021.09.21_15:28_TAI
# ===== 155 =====
# accept NOAA Active Region number 12882 and HARPNUM 7770 at time 2021.10.07_06:38_TAI
# ===== 156 =====
# accept NOAA Active Region number 12887 and HARPNUM 7798 at time 2021.10.26_15:35_TAI
# ===== 157 =====
# accept NOAA Active Region number 12887 and HARPNUM 7798 at time 2021.10.30_01:45_TAI
# ===== 158 =====
# skip: latitude is out of range for HARPNUM 7807 at time 2021.11.07_17:02_TAI
# ===== 159 =====
# skip: latitude is out of range for HARPNUM 7842 at time 2021.12.03_07:19_TAI
# ===== 160 =====
# accept NOAA Active Region number 12908 and HARPNUM 7871 at time 2021.12.18_11:36_TAI
# ===== 161 =====
# accept NOAA Active Region number 12908 and HARPNUM 7871 at time 2021.12.20_07:06_TAI
# ===== 162 =====
# skip: there are no data for HARPNUM 7937 at time 2022.01.12_02:03_TAI
# ===== 163 =====
# accept NOAA Active Region number 12929 and HARPNUM 7934 at time 2022.01.16_17:44_TAI
# ===== 164 =====
# skip: there are no data for HARPNUM 7934 at time 2022.01.18_06:01_TAI
# ===== 165 =====
# accept NOAA Active Region number 12936 and HARPNUM 7966 at time 2022.01.27_23:32_TAI
# ===== 166 =====
# skip: there are no data for HARPNUM 7976 at time 2022.02.10_08:44_TAI
# ===== 167 =====
# accept NOAA Active Region number 12958 and HARPNUM 8043 at time 2022.02.28_17:39_TAI
# ===== 168 =====
# accept NOAA Active Region number 12964 and HARPNUM 8060 at time 2022.03.09_22:32_TAI
# ===== 169 =====
# accept NOAA Active Region number 12974 and HARPNUM 8086 at time 2022.03.23_05:26_TAI
# ===== 170 =====
# accept NOAA Active Region number 12975 and HARPNUM 8088 at time 2022.03.26_11:29_TAI
# ===== 171 =====
# accept NOAA Active Region number 12975 and HARPNUM 8088 at time 2022.03.28_17:37_TAI
# ===== 172 =====
# skip: there are no data for HARPNUM 8088 at time 2022.03.29_18:35_TAI
# ===== 173 =====
# accept NOAA Active Region number 12976 and HARPNUM 8088 at time 2022.03.31_13:55_TAI
# ===== 174 =====
# skip: there are no data for HARPNUM 8155 at time 2022.04.15_03:34_TAI
# ===== 175 =====
# skip: latitude is out of range for HARPNUM 8134 at time 2022.04.17_20:49_TAI
# ===== 176 =====
# skip: latitude is out of range for HARPNUM 8134 at time 2022.04.18_01:36_TAI
# ===== 177 =====
# skip: latitude is out of range for HARPNUM 8134 at time 2022.04.18_03:57_TAI
# ===== 178 =====
# skip: latitude is out of range for HARPNUM 8155 at time 2022.04.19_01:59_TAI
# ===== 179 =====
# accept NOAA Active Region number 12996 and HARPNUM 8155 at time 2022.04.27_07:30_TAI
# ===== 180 =====
# accept NOAA Active Region number 12994 and HARPNUM 8155 at time 2022.04.28_09:58_TAI
# ===== 181 =====
# accept NOAA Active Region number 12994 and HARPNUM 8155 at time 2022.04.28_13:47_TAI
# ===== 182 =====
# accept NOAA Active Region number 12994 and HARPNUM 8155 at time 2022.04.28_19:47_TAI
# ===== 183 =====
# skip: there are no data for HARPNUM 8206 at time 2022.05.01_07:53_TAI
# ===== 184 =====
# accept NOAA Active Region number 13006 and HARPNUM 8206 at time 2022.05.08_13:55_TAI
# ===== 185 =====
# skip: latitude is out of range for HARPNUM 8195 at time 2022.05.09_18:58_TAI
# ===== 186 =====
# skip: there are no data for HARPNUM 8230 at time 2022.05.10_20:19_TAI
# ===== 187 =====
# accept NOAA Active Region number 13016 and HARPNUM 8240 at time 2022.05.23_18:24_TAI
# ===== 188 =====
# skip: latitude is out of range for HARPNUM 8301 at time 2022.06.11_04:07_TAI
# ===== 189 =====
# accept NOAA Active Region number 13053 and HARPNUM 8390 at time 2022.07.06_20:49_TAI
# ===== 190 =====
# skip: there are no data for HARPNUM 8435 at time 2022.07.12_21:48_TAI
# ===== 191 =====
# accept NOAA Active Region number 13078 and HARPNUM 8507 at time 2022.08.13_14:36_TAI
# ===== 192 =====
# accept NOAA Active Region number 13078 and HARPNUM 8507 at time 2022.08.15_13:45_TAI
# ===== 193 =====
# accept NOAA Active Region number 13078 and HARPNUM 8507 at time 2022.08.16_10:09_TAI
# ===== 194 =====
# accept NOAA Active Region number 13078 and HARPNUM 8507 at time 2022.08.16_10:55_TAI
# ===== 195 =====
# accept NOAA Active Region number 13078 and HARPNUM 8507 at time 2022.08.17_04:44_TAI
# ===== 196 =====
# accept NOAA Active Region number 13088 and HARPNUM 8528 at time 2022.08.25_02:40_TAI
# ===== 197 =====
# accept NOAA Active Region number 13088 and HARPNUM 8528 at time 2022.08.26_16:19_TAI
# ===== 198 =====
# skip: latitude is out of range for HARPNUM 8528 at time 2022.08.28_19:29_TAI
# ===== 199 =====
# skip: latitude is out of range for HARPNUM 8567 at time 2022.09.15_13:39_TAI
# ===== 200 =====
# skip: there are no data for HARPNUM 8625 at time 2022.09.21_18:10_TAI
# ===== 201 =====
# accept NOAA Active Region number 13110 and HARPNUM 8625 at time 2022.09.29_20:10_TAI
# ===== 202 =====
# accept NOAA Active Region number 13110 and HARPNUM 8625 at time 2022.09.30_02:21_TAI
# ===== 203 =====
# skip: there are some missing keywords for HARPNUM 8625 at time 2022.09.30_20:25_TAI
# ===== 204 =====
# accept NOAA Active Region number 13110 and HARPNUM 8625 at time 2022.10.01_10:11_TAI
# ===== 205 =====
# accept NOAA Active Region number 13110 and HARPNUM 8625 at time 2022.10.01_20:28_TAI
# ===== 206 =====
# accept NOAA Active Region number 13110 and HARPNUM 8625 at time 2022.10.02_13:15_TAI
# ===== 207 =====
# accept NOAA Active Region number 13112 and HARPNUM 8640 at time 2022.10.09_08:42_TAI
# ===== 208 =====
# accept NOAA Active Region number 13112 and HARPNUM 8640 at time 2022.10.09_10:52_TAI
# ===== 209 =====
# skip: latitude is out of range for HARPNUM 8766 at time 2022.11.05_00:11_TAI
# ===== 210 =====
# skip: there are no data for HARPNUM 8808 at time 2022.11.17_12:56_TAI
# ===== 211 =====
# accept NOAA Active Region number 13152 and HARPNUM 8818 at time 2022.11.29_07:21_TAI
# ===== 212 =====
# skip: latitude is out of range for HARPNUM 8846 at time 2022.12.01_17:41_TAI
# ===== 213 =====
# accept NOAA Active Region number 13165 and HARPNUM 8882 at time 2022.12.12_07:40_TAI
# ===== 214 =====
# accept NOAA Active Region number 13153 and HARPNUM 8844 at time 2022.12.12_08:31_TAI
# ===== 215 =====
# accept NOAA Active Region number 13165 and HARPNUM 8882 at time 2022.12.12_17:12_TAI
# ===== 216 =====
# skip: there are no data for HARPNUM 8882 at time 2022.12.12_22:06_TAI
# ===== 217 =====
# accept NOAA Active Region number 13165 and HARPNUM 8882 at time 2022.12.13_07:58_TAI
# ===== 218 =====
# skip: there are no data for HARPNUM 8903 at time 2022.12.15_19:53_TAI
# ===== 219 =====
# accept NOAA Active Region number 13176 and HARPNUM 8918 at time 2022.12.28_15:28_TAI
# ===== 220 =====
# skip: there are no data for HARPNUM 8963 at time 2023.01.06_09:48_TAI
# ===== 221 =====
# accept NOAA Active Region number 13181 and HARPNUM 8942 at time 2023.01.07_09:01_TAI
# ===== 222 =====
# skip: there are no data for HARPNUM 8968 at time 2023.01.08_00:16_TAI
# ===== 223 =====
# skip: there are no data for HARPNUM 8968 at time 2023.01.08_22:47_TAI
# ===== 224 =====
# skip: there are no data for HARPNUM 8968 at time 2023.01.09_00:59_TAI
# ===== 225 =====
# skip: there are no data for HARPNUM 8968 at time 2023.01.09_08:33_TAI
# ===== 226 =====
# accept NOAA Active Region number 13182 and HARPNUM 8950 at time 2023.01.12_21:00_TAI
# ===== 227 =====
# accept NOAA Active Region number 13188 and HARPNUM 8971 at time 2023.01.13_03:42_TAI
# ===== 228 =====
# accept NOAA Active Region number 13196 and HARPNUM 8978 at time 2023.01.18_10:27_TAI
# ===== 229 =====
# accept NOAA Active Region number 13213 and HARPNUM 9058 at time 2023.02.06_16:03_TAI
# ===== 230 =====
# skip: there are no data for HARPNUM 9088 at time 2023.02.07_09:07_TAI
# ===== 231 =====
# skip: there are no data for HARPNUM 9121 at time 2023.02.15_20:16_TAI
# ===== 232 =====
# skip: there are no data for HARPNUM 9133 at time 2023.02.18_14:58_TAI
# ===== 233 =====
# skip: there are no data for HARPNUM 9133 at time 2023.02.19_20:17_TAI
# ===== 234 =====
# skip: there are no data for HARPNUM 9121 at time 2023.02.22_20:30_TAI
# ===== 235 =====
# accept NOAA Active Region number 13229 and HARPNUM 9121 at time 2023.02.23_19:44_TAI
# ===== 236 =====
# accept NOAA Active Region number 13234 and HARPNUM 9133 at time 2023.02.26_17:50_TAI
# ===== 237 =====
# accept NOAA Active Region number 13234 and HARPNUM 9133 at time 2023.02.28_21:16_TAI
# ===== 238 =====
# accept NOAA Active Region number 13234 and HARPNUM 9133 at time 2023.03.01_10:32_TAI
# ===== 239 =====
# accept NOAA Active Region number 13234 and HARPNUM 9133 at time 2023.03.01_17:52_TAI
# ===== 240 =====
# accept NOAA Active Region number 13234 and HARPNUM 9133 at time 2023.03.02_15:57_TAI
# ===== 241 =====
# accept NOAA Active Region number 13243 and HARPNUM 9152 at time 2023.03.04_02:28_TAI
# ===== 242 =====
# accept NOAA Active Region number 13256 and HARPNUM 9250 at time 2023.03.28_07:37_TAI
# ===== 243 =====
# skip: there are no data for HARPNUM 9374 at time 2023.04.19_18:12_TAI
# ===== 244 =====
# skip: there are no data for HARPNUM 9470 at time 2023.04.28_20:28_TAI
# ===== 245 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.02_08:44_TAI
# ===== 246 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.03_08:01_TAI
# ===== 247 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.07_03:54_TAI
# ===== 248 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.07_06:13_TAI
# ===== 249 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.07_18:58_TAI
# ===== 250 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.07_20:52_TAI
# ===== 251 =====
# accept NOAA Active Region number 13296 and HARPNUM 9470 at time 2023.05.08_14:21_TAI
# ===== 252 =====
# accept NOAA Active Region number 13294 and HARPNUM 9478 at time 2023.05.09_09:01_TAI
# ===== 253 =====
# accept NOAA Active Region number 13294 and HARPNUM 9478 at time 2023.05.09_18:29_TAI
# ===== 254 =====
# accept NOAA Active Region number 13314 and HARPNUM 9561 at time 2023.05.20_13:37_TAI
# ===== 255 =====
# accept NOAA Active Region number 13312 and HARPNUM 9559 at time 2023.05.23_14:46_TAI
# ===== 256 =====
# accept NOAA Active Region number 13327 and HARPNUM 9632 at time 2023.06.05_11:46_TAI
# ===== 257 =====
# skip: latitude is out of range for HARPNUM 9643 at time 2023.06.07_17:11_TAI
# ===== 258 =====
# skip: latitude is out of range for HARPNUM 9679 at time 2023.06.14_05:30_TAI
# ===== 259 =====
# skip: latitude is out of range for HARPNUM 9679 at time 2023.06.14_10:38_TAI
# ===== 260 =====
# accept NOAA Active Region number 13336 and HARPNUM 9680 at time 2023.06.16_13:53_TAI
# ===== 261 =====
# skip: there are no data for HARPNUM 9716 at time 2023.06.18_17:09_TAI
# ===== 262 =====
# accept NOAA Active Region number 13337 and HARPNUM 9679 at time 2023.06.22_12:17_TAI
# ===== 263 =====
# skip: latitude is out of range for HARPNUM 9751 at time 2023.06.29_22:23_TAI
# ===== 264 =====
# skip: latitude is out of range for HARPNUM 9751 at time 2023.06.30_02:35_TAI
# ===== 265 =====
# accept NOAA Active Region number 13366 and HARPNUM 9751 at time 2023.07.08_03:55_TAI
# ===== 266 =====
# skip: there are no data for HARPNUM 9802 at time 2023.07.09_18:08_TAI
# ===== 267 =====
# accept NOAA Active Region number 13363 and HARPNUM 9781 at time 2023.07.12_09:36_TAI
# ===== 268 =====
# accept NOAA Active Region number 13363 and HARPNUM 9781 at time 2023.07.13_07:41_TAI
# ===== 269 =====
# accept NOAA Active Region number 13363 and HARPNUM 9781 at time 2023.07.14_17:46_TAI
# ===== 270 =====
# accept NOAA Active Region number 13376 and HARPNUM 9822 at time 2023.07.16_19:48_TAI
# ===== 271 =====
# accept NOAA Active Region number 13376 and HARPNUM 9822 at time 2023.07.16_20:05_TAI
# ===== 272 =====
# accept NOAA Active Region number 13363 and HARPNUM 9781 at time 2023.07.17_17:25_TAI
# ===== 273 =====
# skip: latitude is out of range for HARPNUM 9822 at time 2023.07.26_15:58_TAI
# ===== 274 =====
# accept NOAA Active Region number 13386 and HARPNUM 9862 at time 2023.08.02_04:24_TAI
# ===== 275 =====
# accept NOAA Active Region number 13386 and HARPNUM 9862 at time 2023.08.04_18:40_TAI
# ===== 276 =====
# accept NOAA Active Region number 13386 and HARPNUM 9862 at time 2023.08.05_04:41_TAI
# ===== 277 =====
# accept NOAA Active Region number 13386 and HARPNUM 9862 at time 2023.08.05_20:46_TAI
# ===== 278 =====
# skip: latitude is out of range for HARPNUM 9987 at time 2023.08.23_01:09_TAI
# ===== 279 =====
# accept NOAA Active Region number 13413 and HARPNUM 9981 at time 2023.08.31_07:12_TAI
# ===== 280 =====
# accept NOAA Active Region number 13413 and HARPNUM 9981 at time 2023.09.01_00:23_TAI
# ===== 281 =====
# accept NOAA Active Region number 13413 and HARPNUM 9981 at time 2023.09.01_08:36_TAI
# ===== 282 =====
# skip: there are no data for HARPNUM 10046 at time 2023.09.05_19:09_TAI
# ===== 283 =====
# skip: latitude is out of range for HARPNUM 10078 at time 2023.09.09_01:28_TAI
# ===== 284 =====
# skip: there are no data for HARPNUM 10086 at time 2023.09.09_04:07_TAI
# ===== 285 =====
# accept NOAA Active Region number 13429 and HARPNUM 10078 at time 2023.09.12_07:45_TAI
# ===== 286 =====
# accept NOAA Active Region number 13429 and HARPNUM 10078 at time 2023.09.12_21:26_TAI
# ===== 287 =====
# skip: latitude is out of range for HARPNUM 10115 at time 2023.09.17_03:55_TAI
# ===== 288 =====
# skip: there are no data for HARPNUM 10115 at time 2023.09.17_09:38_TAI
# ===== 289 =====
# skip: latitude is out of range for HARPNUM 10115 at time 2023.09.17_20:14_TAI
# ===== 290 =====
# accept NOAA Active Region number 13435 and HARPNUM 10115 at time 2023.09.18_14:19_TAI
# ===== 291 =====
# accept NOAA Active Region number 13435 and HARPNUM 10115 at time 2023.09.19_12:54_TAI
# ===== 292 =====
# accept NOAA Active Region number 13443 and HARPNUM 10114 at time 2023.09.20_16:23_TAI
# ===== 293 =====
# accept NOAA Active Region number 13435 and HARPNUM 10115 at time 2023.09.20_23:00_TAI
# ===== 294 =====
# skip: there are no data for HARPNUM 10346 at time 2023.10.30_12:26_TAI
# ===== 295 =====
# skip: latitude is out of range for HARPNUM 10346 at time 2023.10.31_19:21_TAI
# ===== 296 =====
# skip: there are no data for HARPNUM 10439 at time 2023.11.21_03:38_TAI
# ===== 297 =====
# accept NOAA Active Region number 13499 and HARPNUM 10409 at time 2023.11.22_09:33_TAI
# ===== 298 =====
# accept NOAA Active Region number 13514 and HARPNUM 10489 at time 2023.12.12_07:44_TAI
# ===== 299 =====
# accept NOAA Active Region number 13514 and HARPNUM 10489 at time 2023.12.12_17:02_TAI
# ===== 300 =====
# accept NOAA Active Region number 13514 and HARPNUM 10489 at time 2023.12.13_07:15_TAI
# ===== 301 =====
# accept NOAA Active Region number 13514 and HARPNUM 10489 at time 2023.12.13_07:34_TAI
# ===== 302 =====
# accept NOAA Active Region number 13519 and HARPNUM 10507 at time 2023.12.19_05:38_TAI
# ===== 303 =====
# skip: there are no data for HARPNUM 10598 at time 2023.12.29_21:55_TAI
# ===== 304 =====
# skip: latitude is out of range for HARPNUM 10598 at time 2023.12.31_18:30_TAI
# ===== 305 =====
# accept NOAA Active Region number 13561 and HARPNUM 10647 at time 2024.01.20_21:21_TAI
# ===== 306 =====
# accept NOAA Active Region number 13561 and HARPNUM 10647 at time 2024.01.20_21:43_TAI
# ===== 307 =====
# accept NOAA Active Region number 13559 and HARPNUM 10678 at time 2024.01.21_03:31_TAI
# ===== 308 =====
# accept NOAA Active Region number 13559 and HARPNUM 10678 at time 2024.01.21_13:08_TAI
# ===== 309 =====
# accept NOAA Active Region number 13561 and HARPNUM 10647 at time 2024.01.21_16:40_TAI
# ===== 310 =====
# accept NOAA Active Region number 13561 and HARPNUM 10647 at time 2024.01.22_01:40_TAI
# ===== 311 =====
# accept NOAA Active Region number 13561 and HARPNUM 10647 at time 2024.01.22_20:58_TAI
# ===== 312 =====
# accept NOAA Active Region number 13559 and HARPNUM 10678 at time 2024.01.27_01:40_TAI
# ===== 313 =====
# accept NOAA Active Region number 13559 and HARPNUM 10678 at time 2024.01.27_04:38_TAI
# ===== 314 =====
# skip: latitude is out of range for HARPNUM 10764 at time 2024.01.31_03:01_TAI
# ===== 315 =====
# skip: there are no data for HARPNUM 10779 at time 2024.02.03_06:22_TAI
# ===== 316 =====
# accept NOAA Active Region number 13575 and HARPNUM 10769 at time 2024.02.04_02:28_TAI
# ===== 317 =====
# accept NOAA Active Region number 13575 and HARPNUM 10769 at time 2024.02.04_03:12_TAI
# ===== 318 =====
# accept NOAA Active Region number 13575 and HARPNUM 10769 at time 2024.02.04_18:49_TAI
# ===== 319 =====
# accept NOAA Active Region number 13575 and HARPNUM 10769 at time 2024.02.05_03:31_TAI
# ===== 320 =====
# skip: there are no data for HARPNUM 10728 at time 2024.02.06_14:18_TAI
# ===== 321 =====
# skip: latitude is out of range for HARPNUM 10769 at time 2024.02.06_23:55_TAI
# ===== 322 =====
# skip: latitude is out of range for HARPNUM 10769 at time 2024.02.07_13:14_TAI
# ===== 323 =====
# skip: there are no data for HARPNUM 10813 at time 2024.02.08_03:54_TAI
# ===== 324 =====
# accept NOAA Active Region number 13576 and HARPNUM 10779 at time 2024.02.08_23:07_TAI
# ===== 325 =====
# accept NOAA Active Region number 13576 and HARPNUM 10779 at time 2024.02.10_03:48_TAI
# ===== 326 =====
# skip: there are no data for HARPNUM 10826 at time 2024.02.10_21:17_TAI
# ===== 327 =====
# accept NOAA Active Region number 13576 and HARPNUM 10779 at time 2024.02.13_17:07_TAI
# ===== 328 =====
# accept NOAA Active Region number 13576 and HARPNUM 10779 at time 2024.02.14_06:53_TAI
# ===== 329 =====
# skip: there are no data for HARPNUM 10866 at time 2024.02.20_00:14_TAI
# ===== 330 =====
# accept NOAA Active Region number 13590 and HARPNUM 10856 at time 2024.02.26_18:54_TAI
# ===== 331 =====
# accept NOAA Active Region number 13599 and HARPNUM 10897 at time 2024.03.08_12:13_TAI
# ===== 332 =====
# skip: there are no data for HARPNUM 10965 at time 2024.03.16_03:32_TAI
# ===== 333 =====
# accept NOAA Active Region number 13614 and HARPNUM 10973 at time 2024.03.21_01:33_TAI
# ===== 334 =====
# accept NOAA Active Region number 13615 and HARPNUM 10976 at time 2024.03.26_20:56_TAI
# ===== 335 =====
# skip: there are no data for HARPNUM 10495 at time 2024.03.28_21:16_TAI
# ===== 336 =====
# skip: there are no data for HARPNUM 11079 at time 2024.04.11_05:02_TAI
# ===== 337 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.16_02:48_TAI
# ===== 338 =====
# accept NOAA Active Region number 13647 and HARPNUM 11079 at time 2024.04.17_13:06_TAI
# ===== 339 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.19_15:14_TAI
# ===== 340 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.19_21:52_TAI
# ===== 341 =====
# skip: latitude is out of range for HARPNUM 11117 at time 2024.04.20_15:50_TAI
# ===== 342 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.20_21:16_TAI
# ===== 343 =====
# skip: latitude is out of range for HARPNUM 11117 at time 2024.04.21_03:19_TAI
# ===== 344 =====
# skip: latitude is out of range for HARPNUM 11117 at time 2024.04.21_08:21_TAI
# ===== 345 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.21_17:44_TAI
# ===== 346 =====
# accept NOAA Active Region number 13638 and HARPNUM 11079 at time 2024.04.23_17:12_TAI
# ===== 347 =====
# skip: there are no data for HARPNUM 11117 at time 2024.04.28_01:14_TAI
# ===== 348 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.04.29_22:31_TAI
# ===== 349 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.01_02:22_TAI
# ===== 350 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.01_08:11_TAI
# ===== 351 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.01_23:16_TAI
# ===== 352 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.01_23:30_TAI
# ===== 353 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.02_00:36_TAI
# ===== 354 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.02_06:19_TAI
# ===== 355 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.02_23:48_TAI
# ===== 356 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.03_01:27_TAI
# ===== 357 =====
# skip: there are no data for HARPNUM 11142 at time 2024.05.03_06:01_TAI
# ===== 358 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.03_08:19_TAI
# ===== 359 =====
# accept NOAA Active Region number 13663 and HARPNUM 11142 at time 2024.05.03_11:54_TAI
# ===== 360 =====
# skip: there are no data for HARPNUM 11142 at time 2024.05.04_06:35_TAI
# ===== 361 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.06_05:09_TAI
# ===== 362 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.06_21:40_TAI
# ===== 363 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.06_22:27_TAI
# ===== 364 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.07_09:13_TAI
# ===== 365 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.07_17:44_TAI
# ===== 366 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.08_06:54_TAI
# ===== 367 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.09_01:23_TAI
# ===== 368 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.09_15:25_TAI
# ===== 369 =====
# skip: there are no data for HARPNUM 11149 at time 2024.05.11_08:20_TAI
# ===== 370 =====
# skip: there are no data for HARPNUM 11149 at time 2024.05.11_08:29_TAI
# ===== 371 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.11_09:44_TAI
# ===== 372 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.12_02:09_TAI
# ===== 373 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.12_12:55_TAI
# ===== 374 =====
# accept NOAA Active Region number 13664 and HARPNUM 11149 at time 2024.05.12_16:51_TAI
# ===== 375 =====
# skip: latitude is out of range for HARPNUM 11213 at time 2024.05.12_17:38_TAI
# ===== 376 =====
# skip: latitude is out of range for HARPNUM 11149 at time 2024.05.13_08:37_TAI
# ===== 377 =====
# skip: there are no data for HARPNUM 11237 at time 2024.05.13_14:38_TAI
# ===== 378 =====
# skip: latitude is out of range for HARPNUM 11237 at time 2024.05.15_21:08_TAI
# ===== 379 =====
# skip: latitude is out of range for HARPNUM 11237 at time 2024.05.17_13:44_TAI
# ===== 380 =====
# skip: there are no data for HARPNUM 11237 at time 2024.05.17_17:56_TAI
# ===== 381 =====
# accept NOAA Active Region number 13679 and HARPNUM 11192 at time 2024.05.19_19:31_TAI
# ===== 382 =====
# accept NOAA Active Region number 13679 and HARPNUM 11192 at time 2024.05.20_03:13_TAI
# ===== 383 =====
# accept NOAA Active Region number 13679 and HARPNUM 11192 at time 2024.05.21_02:16_TAI
# ===== 384 =====
# accept NOAA Active Region number 13679 and HARPNUM 11192 at time 2024.05.21_04:29_TAI
# ===== 385 =====
# accept NOAA Active Region number 13679 and HARPNUM 11192 at time 2024.05.21_10:08_TAI
# ===== 386 =====
# skip: latitude is out of range for HARPNUM 11192 at time 2024.05.21_13:20_TAI
# ===== 387 =====
# skip: latitude is out of range for HARPNUM 11192 at time 2024.05.22_20:25_TAI
# ===== 388 =====
# skip: there are no data for HARPNUM 11297 at time 2024.05.25_07:08_TAI
# ===== 389 =====
# skip: latitude is out of range for HARPNUM 11297 at time 2024.05.27_14:37_TAI
# ===== 390 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.05.31_19:39_TAI
# ===== 391 =====
# accept NOAA Active Region number 13695 and HARPNUM 11275 at time 2024.06.01_14:11_TAI
# ===== 392 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.06.06_00:51_TAI
# ===== 393 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.06.06_01:49_TAI
# ===== 394 =====
# accept NOAA Active Region number 13703 and HARPNUM 11317 at time 2024.06.06_21:02_TAI
# ===== 395 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.06.08_10:06_TAI
# ===== 396 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.06.08_10:58_TAI
# ===== 397 =====
# accept NOAA Active Region number 13697 and HARPNUM 11297 at time 2024.06.08_11:08_TAI
# ===== 398 =====
# skip: latitude is out of range for HARPNUM 11297 at time 2024.06.08_18:40_TAI
# ===== 399 =====
# accept NOAA Active Region number 13711 and HARPNUM 11329 at time 2024.06.15_20:35_TAI
# ===== 400 =====
# accept NOAA Active Region number 13711 and HARPNUM 11329 at time 2024.06.17_06:38_TAI
# ===== 401 =====
# skip: there are no data for HARPNUM 11385 at time 2024.06.21_06:30_TAI
# ===== 402 =====
# skip: latitude is out of range for HARPNUM 11430 at time 2024.06.23_12:45_TAI
# ===== 403 =====
# accept NOAA Active Region number 13730 and HARPNUM 11430 at time 2024.06.29_11:02_TAI
# ===== 404 =====
# accept NOAA Active Region number 13729 and HARPNUM 11455 at time 2024.07.01_07:41_TAI
# ===== 405 =====
# accept NOAA Active Region number 13723 and HARPNUM 11430 at time 2024.07.02_14:25_TAI
# ===== 406 =====
# accept NOAA Active Region number 13730 and HARPNUM 11430 at time 2024.07.02_20:05_TAI
# ===== 407 =====
# accept NOAA Active Region number 13738 and HARPNUM 11487 at time 2024.07.13_09:37_TAI
# ===== 408 =====
# accept NOAA Active Region number 13753 and HARPNUM 11520 at time 2024.07.14_07:37_TAI
# ===== 409 =====
# accept NOAA Active Region number 13738 and HARPNUM 11487 at time 2024.07.14_13:26_TAI
# ===== 410 =====
# accept NOAA Active Region number 13744 and HARPNUM 11526 at time 2024.07.14_22:06_TAI
# ===== 411 =====
# accept NOAA Active Region number 13743 and HARPNUM 11513 at time 2024.07.15_06:39_TAI
# ===== 412 =====
# accept NOAA Active Region number 13744 and HARPNUM 11526 at time 2024.07.19_03:55_TAI
# ===== 413 =====
# accept NOAA Active Region number 13757 and HARPNUM 11558 at time 2024.07.19_16:31_TAI
# ===== 414 =====
# skip: there are no data for HARPNUM 11587 at time 2024.07.21_14:28_TAI
# ===== 415 =====
# skip: there are no data for HARPNUM 11547 at time 2024.07.22_07:42_TAI
# ===== 416 =====
# accept NOAA Active Region number 13751 and HARPNUM 11547 at time 2024.07.22_17:21_TAI
# ===== 417 =====
# accept NOAA Active Region number 13751 and HARPNUM 11547 at time 2024.07.23_15:37_TAI
# ===== 418 =====
# accept NOAA Active Region number 13762 and HARPNUM 11573 at time 2024.07.25_05:46_TAI
# ===== 419 =====
# accept NOAA Active Region number 13767 and HARPNUM 11587 at time 2024.07.25_10:40_TAI
# ===== 420 =====
# accept NOAA Active Region number 13762 and HARPNUM 11573 at time 2024.07.25_18:39_TAI
# ===== 421 =====
# accept NOAA Active Region number 13766 and HARPNUM 11587 at time 2024.07.26_01:51_TAI
# ===== 422 =====
# accept NOAA Active Region number 13766 and HARPNUM 11587 at time 2024.07.26_01:57_TAI
# ===== 423 =====
# accept NOAA Active Region number 13762 and HARPNUM 11573 at time 2024.07.26_10:42_TAI
# ===== 424 =====
# skip: there are some missing keywords for HARPNUM 11573 at time 2024.07.27_12:55_TAI
# ===== 425 =====
# skip: there are no data for HARPNUM 11640 at time 2024.07.27_14:46_TAI
# ===== 426 =====
# skip: there are no data for HARPNUM 11640 at time 2024.07.27_19:57_TAI
# ===== 427 =====
# skip: there are no data for HARPNUM 11640 at time 2024.07.28_19:38_TAI
# ===== 428 =====
# skip: there are no data for HARPNUM 11573 at time 2024.07.29_06:46_TAI
# ===== 429 =====
# skip: latitude is out of range for HARPNUM 11640 at time 2024.07.29_13:05_TAI
# ===== 430 =====
# accept NOAA Active Region number 13768 and HARPNUM 11573 at time 2024.07.29_18:37_TAI
# ===== 431 =====
# accept NOAA Active Region number 13773 and HARPNUM 11573 at time 2024.07.30_01:50_TAI
# ===== 432 =====
# skip: there are no data for HARPNUM 11573 at time 2024.07.30_07:09_TAI
# ===== 433 =====
# accept NOAA Active Region number 13768 and HARPNUM 11573 at time 2024.07.30_11:37_TAI
# ===== 434 =====
# accept NOAA Active Region number 13768 and HARPNUM 11573 at time 2024.07.31_04:55_TAI
# ===== 435 =====
# skip: there are no data for HARPNUM 11662 at time 2024.08.02_15:15_TAI
# ===== 436 =====
# skip: there are no data for HARPNUM 11662 at time 2024.08.02_22:11_TAI
# ===== 437 =====
# skip: there are no data for HARPNUM 11662 at time 2024.08.03_02:31_TAI
# ===== 438 =====
# skip: there are no data for HARPNUM 11662 at time 2024.08.03_05:23_TAI
# ===== 439 =====
# skip: latitude is out of range for HARPNUM 11587 at time 2024.08.03_13:40_TAI
# ===== 440 =====
# skip: latitude is out of range for HARPNUM 11662 at time 2024.08.03_15:27_TAI
# ===== 441 =====
# accept NOAA Active Region number 13774 and HARPNUM 11644 at time 2024.08.05_13:50_TAI
# ===== 442 =====
# skip: there are no data for HARPNUM 11644 at time 2024.08.05_18:54_TAI
# ===== 443 =====
# accept NOAA Active Region number 13777 and HARPNUM 11644 at time 2024.08.06_04:41_TAI
# ===== 444 =====
# accept NOAA Active Region number 13777 and HARPNUM 11644 at time 2024.08.06_19:35_TAI
# ===== 445 =====
# accept NOAA Active Region number 13774 and HARPNUM 11644 at time 2024.08.07_21:23_TAI
# ===== 446 =====
# accept NOAA Active Region number 13780 and HARPNUM 11662 at time 2024.08.08_02:37_TAI
# ===== 447 =====
# skip: latitude is out of range for HARPNUM 11644 at time 2024.08.12_04:02_TAI
# ===== 448 =====
# skip: there are no data for HARPNUM 11689 at time 2024.08.12_06:40_TAI
# ===== 449 =====
# accept NOAA Active Region number 13780 and HARPNUM 11662 at time 2024.08.14_13:24_TAI
# ===== 450 =====
# accept NOAA Active Region number 13784 and HARPNUM 11689 at time 2024.08.15_10:33_TAI
# ===== 451 =====
# skip: latitude is out of range for HARPNUM 11786 at time 2024.08.28_12:20_TAI
# ===== 452 =====
# skip: latitude is out of range for HARPNUM 11786 at time 2024.08.30_13:22_TAI
# ===== 453 =====
# accept NOAA Active Region number 13807 and HARPNUM 11786 at time 2024.08.31_13:43_TAI
# ===== 454 =====
# accept NOAA Active Region number 13815 and HARPNUM 11786 at time 2024.09.05_07:49_TAI
# ===== 455 =====
# accept NOAA Active Region number 13806 and HARPNUM 11786 at time 2024.09.07_03:32_TAI
# ===== 456 =====
# accept NOAA Active Region number 13814 and HARPNUM 11839 at time 2024.09.08_00:28_TAI
# ===== 457 =====
# accept NOAA Active Region number 13814 and HARPNUM 11839 at time 2024.09.08_23:50_TAI
# ===== 458 =====
# skip: there are no data for HARPNUM 11887 at time 2024.09.09_15:30_TAI
# ===== 459 =====
# accept NOAA Active Region number 13811 and HARPNUM 11786 at time 2024.09.09_17:26_TAI
# ===== 460 =====
# accept NOAA Active Region number 13811 and HARPNUM 11786 at time 2024.09.10_00:12_TAI
# ===== 461 =====
# accept NOAA Active Region number 13811 and HARPNUM 11786 at time 2024.09.02_20:00_TAI
# ===== 462 =====
# skip: latitude is out of range for HARPNUM 11887 at time 2024.09.12_04:31_TAI
# ===== 463 =====
# skip: latitude is out of range for HARPNUM 11887 at time 2024.09.12_15:29_TAI
# ===== 464 =====
# skip: latitude is out of range for HARPNUM 11930 at time 2024.09.20_21:39_TAI
# ===== 465 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.09.28_23:59_TAI
# ===== 466 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.09.29_22:20_TAI
# ===== 467 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.09.30_05:38_TAI
# ===== 468 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.09.30_13:38_TAI
# ===== 469 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.10.01_12:18_TAI
# ===== 470 =====
# accept NOAA Active Region number 13843 and HARPNUM 11930 at time 2024.10.01_20:28_TAI
# ===== 471 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.10.02_04:55_TAI
# ===== 472 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.10.05_19:13_TAI
# ===== 473 =====
# accept NOAA Active Region number 13842 and HARPNUM 11930 at time 2024.10.05_20:59_TAI
# ===== 474 =====
# accept NOAA Active Region number 13848 and HARPNUM 12001 at time 2024.10.07_01:56_TAI
# ===== 475 =====
# skip: latitude is out of range for HARPNUM 11930 at time 2024.10.07_15:47_TAI
# ===== 476 =====
# skip: there are no data for HARPNUM 12032 at time 2024.10.09_16:33_TAI
# ===== 477 =====
# accept NOAA Active Region number 13848 and HARPNUM 12001 at time 2024.10.12_00:17_TAI
# ===== 478 =====
# accept NOAA Active Region number 13848 and HARPNUM 12001 at time 2024.10.12_13:37_TAI
# ===== 479 =====
# skip: latitude is out of range for HARPNUM 12001 at time 2024.10.13_18:18_TAI
# ===== 480 =====
# accept NOAA Active Region number 13854 and HARPNUM 12032 at time 2024.10.17_06:56_TAI
# ===== 481 =====
# skip: latitude is out of range for HARPNUM 12094 at time 2024.10.22_03:57_TAI
# ===== 482 =====
# accept NOAA Active Region number 13873 and HARPNUM 12094 at time 2024.10.23_07:33_TAI
# ===== 483 =====
# accept NOAA Active Region number 13873 and HARPNUM 12094 at time 2024.10.24_06:23_TAI
# ===== 484 =====
# accept NOAA Active Region number 13873 and HARPNUM 12094 at time 2024.10.24_07:19_TAI
# ===== 485 =====
# skip: there are no matching HARPNUMs for 13875
# ===== 486 =====
# skip: there are no data for HARPNUM 12160 at time 2024.10.29_21:20_TAI
# ===== 487 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_14:28_TAI
# ===== 488 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_01:40_TAI
# ===== 489 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_15:33_TAI
# ===== 490 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_15:41_TAI
# ===== 491 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.03_06:54_TAI
# ===== 492 =====
# skip: latitude is out of range for HARPNUM 12094 at time 2024.11.03_15:26_TAI
# ===== 493 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.05_00:04_TAI
# ===== 494 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_23:16_TAI
# ===== 495 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.08_12:06_TAI
# ===== 496 =====
# accept NOAA Active Region number 13893 and HARPNUM 12235 at time 2024.11.14_01:46_TAI
# ===== 497 =====
# accept NOAA Active Region number 13897 and HARPNUM 12216 at time 2024.11.16_11:12_TAI
# ===== 498 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_19:15_TAI
# ===== 499 =====
# skip: latitude is out of range for HARPNUM 12216 at time 2024.11.18_19:48_TAI
# ===== 500 =====
# skip: latitude is out of range for HARPNUM 12261 at time 2024.11.20_22:15_TAI
# ===== 501 =====
# accept NOAA Active Region number 13906 and HARPNUM 12261 at time 2024.11.23_01:59_TAI
# ===== 502 =====
# accept NOAA Active Region number 13901 and HARPNUM 12261 at time 2024.11.23_20:54_TAI
# ===== 503 =====
# skip: there are no data for HARPNUM 12363 at time 2024.12.02_10:00_TAI
# ===== 504 =====
# skip: latitude is out of range for HARPNUM 12261 at time 2024.12.03_10:40_TAI
# ===== 505 =====
# accept NOAA Active Region number 13912 and HARPNUM 12334 at time 2024.12.06_09:06_TAI
# ===== 506 =====
# skip: there are no data for HARPNUM 12404 at time 2024.12.08_07:09_TAI
# ===== 507 =====
# skip: there are no data for HARPNUM 12404 at time 2024.12.08_11:02_TAI
# ===== 508 =====
# skip: there are no data for HARPNUM 12404 at time 2024.12.08_17:58_TAI
# ===== 509 =====
# skip: there are no data for HARPNUM 12404 at time 2024.12.09_06:04_TAI
# ===== 510 =====
# accept NOAA Active Region number 13920 and HARPNUM 12392 at time 2024.12.09_10:06_TAI
# ===== 511 =====
# accept NOAA Active Region number 13922 and HARPNUM 12404 at time 2024.12.11_03:18_TAI
# ===== 512 =====
# accept NOAA Active Region number 13922 and HARPNUM 12404 at time 2024.12.11_14:24_TAI
# ===== 513 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.20_20:49_TAI
# ===== 514 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.21_11:12_TAI
# ===== 515 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.22_00:19_TAI
# ===== 516 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.22_08:41_TAI
# ===== 517 =====
# accept NOAA Active Region number 13930 and HARPNUM 12425 at time 2024.12.22_20:28_TAI
# ===== 518 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.23_04:49_TAI
# ===== 519 =====
# accept NOAA Active Region number 13938 and HARPNUM 12471 at time 2024.12.24_00:30_TAI
# ===== 520 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.27_04:30_TAI
# ===== 521 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.27_17:08_TAI
# ===== 522 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_04:14_TAI

# %% [markdown]
# Here is the number of events associated with the positive class:

# %%
CME_data = positive_result[0]
positive_class = positive_result[1]
print("There are", len(CME_data), "CME events in the positive class.")
# Out:
# There are 320 CME events in the positive class.

# %% [markdown]
# ### step 2: gathering data for the negative class

# %% [markdown]
# To gather the examples for the negative class, we only need to:
#
# 1. Query the GOES database for all the M- and X-class flares during our time of interest, and
# 2. Select the ones that are not associated with a CME.

# %%
# select peak times that belong to both classes
all_peak_times = np.array([(listofresults["hek"][i]['event_peaktime'])
                           for i in range(len(listofresults["hek"]))])

negative_class_possibilities = []
counter_positive = 0
counter_negative = 0
for i in range(len(listofresults["hek"])):
    this_peak_time = all_peak_times[i]
    if (this_peak_time in peak_times_donki):
        counter_positive += 1
    else:
        counter_negative += 1
        this_instance = [listofresults["hek"][i]['ar_noaanum'],
                         listofresults["hek"][i]['fl_goescls'], listofresults["hek"][i]['event_peaktime']]
        negative_class_possibilities.append(this_instance)
print("There are", counter_positive, "events in the positive class.")
print("There are", counter_negative, "events in the negative class.")
# Out:
# There are 534 events in the positive class.
# There are 1768 events in the negative class.

# %% [markdown]
# Again, we compute times that are one day before the flare peak time and convert it into a string that JSOC can understand:

# %%
t_rec = np.array([(negative_class_possibilities[i][2] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(len(negative_class_possibilities))])

# %% [markdown]
# And again, we query the JSOC database to see if these data are present:

# %%
listofactiveregions = list(negative_class_possibilities[i][0] for i in range(counter_negative))
listofgoesclasses = list(negative_class_possibilities[i][1] for i in range(counter_negative))
peaktimes = list(negative_class_possibilities[i][2] for i in range(counter_negative))

# %%
for i in range(32,50,4):
  timedelayvariable = i
  t_rec = np.array([(negative_class_possibilities[i][2] - timedelta(hours=timedelayvariable)).strftime('%Y.%m.%d_%H:%M_TAI') for i in range(len(negative_class_possibilities))])
  negative_result = get_the_jsoc_data(counter_negative, t_rec)
  negative_df = pd.concat([pd.DataFrame(negative_result[0]), pd.DataFrame(negative_result[1])], axis=1)
  negative_df.columns = ["USFLUX", "MEANGBT", "MEANJZH", "MEANPOT", "SHRGT45", "TOTUSJH", "MEANGBH",
              "MEANALP", "MEANGAM", "MEANGBZ", "MEANJZD", "TOTUSJZ", "SAVNCPP", "TOTPOT",
              "MEANSHR", "AREA_ACR", "R_VALUE", "ABSNJZH", "HARPNUM", "NOAA", "Class", "T_REC", "Peak Time"]
  negative_df.to_csv(f"negative{i}.csv")
# Out:
# ===== 0 =====
# accept NOAA Active Region number 11069 and HARPNUM 8 at time 2010.05.04_09:19_TAI
# ===== 1 =====
# skip: there are no data for HARPNUM 54 at time 2010.06.10_16:57_TAI
# ===== 2 =====
# skip: there are no data for HARPNUM 49 at time 2010.06.11_21:39_TAI
# ===== 3 =====
# accept NOAA Active Region number 11093 and HARPNUM 115 at time 2010.08.06_10:24_TAI
# ===== 4 =====
# accept NOAA Active Region number 11112 and HARPNUM 211 at time 2010.10.15_11:12_TAI
# ===== 5 =====
# skip: there are no data for HARPNUM 245 at time 2010.11.03_15:58_TAI
# ===== 6 =====
# skip: there are no data for HARPNUM 245 at time 2010.11.03_15:58_TAI
# ===== 7 =====
# skip: latitude is out of range for HARPNUM 245 at time 2010.11.04_05:29_TAI
# ===== 8 =====
# skip: latitude is out of range for HARPNUM 245 at time 2010.11.05_07:36_TAI
# ===== 9 =====
# accept NOAA Active Region number 11149 and HARPNUM 345 at time 2011.01.26_17:03_TAI
# ===== 10 =====
# accept NOAA Active Region number 11153 and HARPNUM 362 at time 2011.02.07_17:31_TAI
# ===== 11 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.12_09:38_TAI
# ===== 12 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.13_09:26_TAI
# ===== 13 =====
# skip: there are no data for HARPNUM 1 at time 2011.02.14_17:39_TAI
# ===== 14 =====
# accept NOAA Active Region number 11161 and HARPNUM 384 at time 2011.02.14_23:44_TAI
# ===== 15 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.15_06:25_TAI
# ===== 16 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.17_02:11_TAI
# ===== 17 =====
# accept NOAA Active Region number 11162 and HARPNUM 384 at time 2011.02.17_02:26_TAI
# ===== 18 =====
# accept NOAA Active Region number 11158 and HARPNUM 377 at time 2011.02.17_05:03_TAI
# ===== 19 =====
# skip: there are no data for HARPNUM 384 at time 2011.02.17_06:08_TAI
# ===== 20 =====
# accept NOAA Active Region number 11162 and HARPNUM 384 at time 2011.02.17_13:04_TAI
# ===== 21 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.02.27_04:52_TAI
# ===== 22 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.03.05_21:13_TAI
# ===== 23 =====
# accept NOAA Active Region number 11165 and HARPNUM 394 at time 2011.03.05_23:54_TAI
# ===== 24 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.03.06_00:07_TAI
# ===== 25 =====
# accept NOAA Active Region number 11164 and HARPNUM 393 at time 2011.03.06_01:20_TAI
# ===== 26 =====
# accept NOAA Active Region number 11165 and HARPNUM 394 at time 2011.03.06_13:50_TAI
# ===== 27 =====
# accept NOAA Active Region number 11165 and HARPNUM 394 at time 2011.03.06_18:29_TAI
# ===== 28 =====
# skip: latitude is out of range for HARPNUM 394 at time 2011.03.07_02:44_TAI
# ===== 29 =====
# skip: latitude is out of range for HARPNUM 394 at time 2011.03.07_10:28_TAI
# ===== 30 =====
# skip: latitude is out of range for HARPNUM 394 at time 2011.03.07_12:16_TAI
# ===== 31 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.08_03:07_TAI
# ===== 32 =====
# skip: there are no data for HARPNUM 401 at time 2011.03.08_06:02_TAI
# ===== 33 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.08_15:23_TAI
# ===== 34 =====
# skip: there are no data for HARPNUM 1 at time 2011.03.09_14:41_TAI
# ===== 35 =====
# accept NOAA Active Region number 11166 and HARPNUM 401 at time 2011.03.10_20:43_TAI
# ===== 36 =====
# accept NOAA Active Region number 11169 and HARPNUM 407 at time 2011.03.13_11:52_TAI
# ===== 37 =====
# accept NOAA Active Region number 11169 and HARPNUM 407 at time 2011.03.13_16:22_TAI
# ===== 38 =====
# skip: there are no data for HARPNUM 437 at time 2011.03.21_18:17_TAI
# ===== 39 =====
# skip: latitude is out of range for HARPNUM 437 at time 2011.03.23_04:07_TAI
# ===== 40 =====
# accept NOAA Active Region number 11176 and HARPNUM 437 at time 2011.03.24_15:22_TAI
# ===== 41 =====
# accept NOAA Active Region number 11190 and HARPNUM 495 at time 2011.04.14_09:12_TAI
# ===== 42 =====
# accept NOAA Active Region number 11195 and HARPNUM 514 at time 2011.04.20_20:57_TAI
# ===== 43 =====
# accept NOAA Active Region number 11195 and HARPNUM 514 at time 2011.04.21_07:53_TAI
# ===== 44 =====
# skip: latitude is out of range for HARPNUM 637 at time 2011.05.27_13:50_TAI
# ===== 45 =====
# skip: latitude is out of range for HARPNUM 637 at time 2011.05.28_02:33_TAI
# ===== 46 =====
# skip: latitude is out of range for HARPNUM 667 at time 2011.06.13_13:47_TAI
# ===== 47 =====
# accept NOAA Active Region number 11260 and HARPNUM 746 at time 2011.07.26_08:07_TAI
# ===== 48 =====
# skip: there are no data for HARPNUM 750 at time 2011.07.28_18:09_TAI
# ===== 49 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.07.31_22:19_TAI
# ===== 50 =====
# accept NOAA Active Region number 11261 and HARPNUM 750 at time 2011.08.01_19:37_TAI
# ===== 51 =====
# accept NOAA Active Region number 11263 and HARPNUM 753 at time 2011.08.01_20:32_TAI
# ===== 52 =====
# accept NOAA Active Region number 11263 and HARPNUM 753 at time 2011.08.07_10:10_TAI
# ===== 53 =====
# accept NOAA Active Region number 11263 and HARPNUM 753 at time 2011.08.07_19:54_TAI
# ===== 54 =====
# accept NOAA Active Region number 11263 and HARPNUM 753 at time 2011.08.08_00:05_TAI
# ===== 55 =====
# accept NOAA Active Region number 11286 and HARPNUM 814 at time 2011.09.03_03:45_TAI
# ===== 56 =====
# accept NOAA Active Region number 11286 and HARPNUM 814 at time 2011.09.03_20:28_TAI
# ===== 57 =====
# accept NOAA Active Region number 11286 and HARPNUM 814 at time 2011.09.03_23:58_TAI
# ===== 58 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.04_17:50_TAI
# ===== 59 =====
# accept NOAA Active Region number 1283 and HARPNUM 833 at time 2011.09.05_14:20_TAI
# ===== 60 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.05_14:20_TAI
# ===== 61 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.07_07:46_TAI
# ===== 62 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.07_22:11_TAI
# ===== 63 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.08_04:49_TAI
# ===== 64 =====
# accept NOAA Active Region number 11283 and HARPNUM 833 at time 2011.09.08_23:40_TAI
# ===== 65 =====
# accept NOAA Active Region number 11301 and HARPNUM 878 at time 2011.09.20_04:23_TAI
# ===== 66 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.21_02:00_TAI
# ===== 67 =====
# skip: there are no data for HARPNUM 856 at time 2011.09.21_17:59_TAI
# ===== 68 =====
# accept NOAA Active Region number 11295 and HARPNUM 856 at time 2011.09.22_14:15_TAI
# ===== 69 =====
# skip: latitude is out of range for HARPNUM 892 at time 2011.09.22_15:56_TAI
# ===== 70 =====
# skip: latitude is out of range for HARPNUM 892 at time 2011.09.23_05:20_TAI
# ===== 71 =====
# skip: there are no data for HARPNUM 856 at time 2011.09.23_08:59_TAI
# ===== 72 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.23_09:25_TAI
# ===== 73 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.23_10:15_TAI
# ===== 74 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.23_11:21_TAI
# ===== 75 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.23_12:36_TAI
# ===== 76 =====
# skip: there are no data for HARPNUM 899 at time 2011.09.23_13:27_TAI
# ===== 77 =====
# skip: there are no data for HARPNUM 899 at time 2011.09.23_15:58_TAI
# ===== 78 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.23_18:33_TAI
# ===== 79 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.23_20:50_TAI
# ===== 80 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.24_00:49_TAI
# ===== 81 =====
# accept NOAA Active Region number 11303 and HARPNUM 899 at time 2011.09.24_01:35_TAI
# ===== 82 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.24_07:33_TAI
# ===== 83 =====
# skip: there are no data for HARPNUM 899 at time 2011.09.24_08:58_TAI
# ===== 84 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.24_21:08_TAI
# ===== 85 =====
# skip: there are no data for HARPNUM 892 at time 2011.09.25_06:46_TAI
# ===== 86 =====
# accept NOAA Active Region number 11302 and HARPNUM 892 at time 2011.09.27_05:28_TAI
# ===== 87 =====
# accept NOAA Active Region number 11305 and HARPNUM 902 at time 2011.09.29_11:06_TAI
# ===== 88 =====
# accept NOAA Active Region number 11305 and HARPNUM 902 at time 2011.09.30_01:59_TAI
# ===== 89 =====
# accept NOAA Active Region number 11305 and HARPNUM 902 at time 2011.09.30_16:50_TAI
# ===== 90 =====
# skip: there are no data for HARPNUM 892 at time 2011.10.01_09:23_TAI
# ===== 91 =====
# skip: there are no data for HARPNUM 1 at time 2011.10.18_19:25_TAI
# ===== 92 =====
# accept NOAA Active Region number 11319 and HARPNUM 940 at time 2011.10.20_05:00_TAI
# ===== 93 =====
# accept NOAA Active Region number 11314 and HARPNUM 940 at time 2011.10.21_03:10_TAI
# ===== 94 =====
# skip: there are no data for HARPNUM 1 at time 2011.10.30_07:08_TAI
# ===== 95 =====
# skip: there are no data for HARPNUM 1 at time 2011.10.30_10:08_TAI
# ===== 96 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.01_14:01_TAI
# ===== 97 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.02_03:11_TAI
# ===== 98 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.02_12:27_TAI
# ===== 99 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.02_15:36_TAI
# ===== 100 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.03_12:40_TAI
# ===== 101 =====
# accept NOAA Active Region number 11339 and HARPNUM 1028 at time 2011.11.03_19:35_TAI
# ===== 102 =====
# accept NOAA Active Region number 11339 and HARPNUM 1028 at time 2011.11.04_03:21_TAI
# ===== 103 =====
# accept NOAA Active Region number 11339 and HARPNUM 1028 at time 2011.11.04_12:38_TAI
# ===== 104 =====
# accept NOAA Active Region number 11339 and HARPNUM 1028 at time 2011.11.04_17:03_TAI
# ===== 105 =====
# accept NOAA Active Region number 11339 and HARPNUM 1028 at time 2011.11.04_22:35_TAI
# ===== 106 =====
# accept NOAA Active Region number 11342 and HARPNUM 1041 at time 2011.11.08_05:35_TAI
# ===== 107 =====
# accept NOAA Active Region number 11348 and HARPNUM 1028 at time 2011.11.14_01:12_TAI
# ===== 108 =====
# accept NOAA Active Region number 11346 and HARPNUM 1066 at time 2011.11.14_04:43_TAI
# ===== 109 =====
# skip: latitude is out of range for HARPNUM 1028 at time 2011.11.14_14:35_TAI
# ===== 110 =====
# accept NOAA Active Region number 11387 and HARPNUM 1209 at time 2011.12.24_10:16_TAI
# ===== 111 =====
# skip: there are no data for HARPNUM 1209 at time 2011.12.24_18:27_TAI
# ===== 112 =====
# accept NOAA Active Region number 11387 and HARPNUM 1209 at time 2011.12.25_12:30_TAI
# ===== 113 =====
# skip: latitude is out of range for HARPNUM 1256 at time 2011.12.28_05:50_TAI
# ===== 114 =====
# skip: latitude is out of range for HARPNUM 1256 at time 2011.12.28_13:51_TAI
# ===== 115 =====
# skip: there are no data for HARPNUM 1256 at time 2011.12.28_19:09_TAI
# ===== 116 =====
# accept NOAA Active Region number 11389 and HARPNUM 1256 at time 2011.12.30_05:15_TAI
# ===== 117 =====
# accept NOAA Active Region number 11389 and HARPNUM 1256 at time 2011.12.30_08:26_TAI
# ===== 118 =====
# skip: there are no data for HARPNUM 1321 at time 2012.01.13_05:18_TAI
# ===== 119 =====
# skip: latitude is out of range for HARPNUM 1321 at time 2012.01.15_20:53_TAI
# ===== 120 =====
# accept NOAA Active Region number 11401 and HARPNUM 1321 at time 2012.01.17_11:12_TAI
# ===== 121 =====
# accept NOAA Active Region number 11402 and HARPNUM 1321 at time 2012.01.18_08:05_TAI
# ===== 122 =====
# accept NOAA Active Region number 11410 and HARPNUM 1350 at time 2012.02.05_12:00_TAI
# ===== 123 =====
# skip: there are no data for HARPNUM 1449 at time 2012.03.01_09:46_TAI
# ===== 124 =====
# skip: latitude is out of range for HARPNUM 1449 at time 2012.03.03_02:52_TAI
# ===== 125 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_11:16_TAI
# ===== 126 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_11:30_TAI
# ===== 127 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_14:34_TAI
# ===== 128 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_16:28_TAI
# ===== 129 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_17:44_TAI
# ===== 130 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_20:05_TAI
# ===== 131 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.04_23:55_TAI
# ===== 132 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.05_04:41_TAI
# ===== 133 =====
# skip: there are no data for HARPNUM 1 at time 2012.03.05_13:11_TAI
# ===== 134 =====
# accept NOAA Active Region number 11429 and HARPNUM 1449 at time 2012.03.05_14:53_TAI
# ===== 135 =====
# skip: there are no data for HARPNUM 1461 at time 2012.03.13_07:21_TAI
# ===== 136 =====
# accept NOAA Active Region number 11432 and HARPNUM 1461 at time 2012.03.13_23:52_TAI
# ===== 137 =====
# accept NOAA Active Region number 11434 and HARPNUM 1464 at time 2012.03.16_12:39_TAI
# ===== 138 =====
# skip: there are no data for HARPNUM 1500 at time 2012.03.22_11:40_TAI
# ===== 139 =====
# skip: there are no data for HARPNUM 1582 at time 2012.04.15_09:45_TAI
# ===== 140 =====
# accept NOAA Active Region number 11466 and HARPNUM 1603 at time 2012.04.26_00:24_TAI
# ===== 141 =====
# skip: there are no data for HARPNUM 1638 at time 2012.05.04_05:23_TAI
# ===== 142 =====
# skip: latitude is out of range for HARPNUM 1638 at time 2012.05.04_15:01_TAI
# ===== 143 =====
# skip: latitude is out of range for HARPNUM 1638 at time 2012.05.04_17:18_TAI
# ===== 144 =====
# skip: there are no data for HARPNUM 1638 at time 2012.05.05_09:47_TAI
# ===== 145 =====
# accept NOAA Active Region number 11471 and HARPNUM 1621 at time 2012.05.06_06:31_TAI
# ===== 146 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.07_05:08_TAI
# ===== 147 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.08_04:32_TAI
# ===== 148 =====
# skip: there are no data for HARPNUM 1638 at time 2012.05.08_06:08_TAI
# ===== 149 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.08_13:05_TAI
# ===== 150 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.08_20:18_TAI
# ===== 151 =====
# accept NOAA Active Region number 11476 and HARPNUM 1638 at time 2012.05.09_12:26_TAI
# ===== 152 =====
# accept NOAA Active Region number 11496 and HARPNUM 1722 at time 2012.06.02_09:55_TAI
# ===== 153 =====
# accept NOAA Active Region number 11494 and HARPNUM 1724 at time 2012.06.05_12:06_TAI
# ===== 154 =====
# skip: there are no data for HARPNUM 1750 at time 2012.06.08_03:32_TAI
# ===== 155 =====
# skip: there are no data for HARPNUM 1750 at time 2012.06.08_08:53_TAI
# ===== 156 =====
# skip: latitude is out of range for HARPNUM 1750 at time 2012.06.08_22:45_TAI
# ===== 157 =====
# skip: latitude is out of range for HARPNUM 1806 at time 2012.06.27_08:12_TAI
# ===== 158 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.06.28_01:20_TAI
# ===== 159 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.06.29_04:52_TAI
# ===== 160 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.06.29_10:32_TAI
# ===== 161 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.06.30_11:18_TAI
# ===== 162 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.06.30_16:35_TAI
# ===== 163 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.01_02:52_TAI
# ===== 164 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.01_12:07_TAI
# ===== 165 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.01_15:56_TAI
# ===== 166 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.02_20:37_TAI
# ===== 167 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_01:55_TAI
# ===== 168 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_04:24_TAI
# ===== 169 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_06:40_TAI
# ===== 170 =====
# accept NOAA Active Region number 11513 and HARPNUM 1806 at time 2012.07.03_08:39_TAI
# ===== 171 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_14:09_TAI
# ===== 172 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_15:55_TAI
# ===== 173 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_17:10_TAI
# ===== 174 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_18:42_TAI
# ===== 175 =====
# skip: there are no data for HARPNUM 1807 at time 2012.07.03_19:36_TAI
# ===== 176 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.03_22:58_TAI
# ===== 177 =====
# skip: there are no data for HARPNUM 1834 at time 2012.07.03_23:45_TAI
# ===== 178 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_02:48_TAI
# ===== 179 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_03:44_TAI
# ===== 180 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_05:18_TAI
# ===== 181 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_12:14_TAI
# ===== 182 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_13:45_TAI
# ===== 183 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_17:40_TAI
# ===== 184 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.04_18:51_TAI
# ===== 185 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_00:23_TAI
# ===== 186 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_02:29_TAI
# ===== 187 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_05:30_TAI
# ===== 188 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_10:55_TAI
# ===== 189 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.05_19:15_TAI
# ===== 190 =====
# skip: latitude is out of range for HARPNUM 1834 at time 2012.07.06_00:28_TAI
# ===== 191 =====
# skip: there are some missing keywords for HARPNUM 1807 at time 2012.07.06_03:03_TAI
# ===== 192 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.06_21:46_TAI
# ===== 193 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.07_01:53_TAI
# ===== 194 =====
# accept NOAA Active Region number 11515 and HARPNUM 1807 at time 2012.07.07_04:10_TAI
# ===== 195 =====
# accept NOAA Active Region number 11520 and HARPNUM 1834 at time 2012.07.08_15:07_TAI
# ===== 196 =====
# accept NOAA Active Region number 11520 and HARPNUM 1834 at time 2012.07.08_21:14_TAI
# ===== 197 =====
# accept NOAA Active Region number 11520 and HARPNUM 1834 at time 2012.07.08_22:27_TAI
# ===== 198 =====
# accept NOAA Active Region number 11521 and HARPNUM 1834 at time 2012.07.12_20:58_TAI
# ===== 199 =====
# skip: there are some missing keywords for HARPNUM 1879 at time 2012.07.26_09:26_TAI
# ===== 200 =====
# accept NOAA Active Region number 11532 and HARPNUM 1879 at time 2012.07.27_22:22_TAI
# ===== 201 =====
# accept NOAA Active Region number 11536 and HARPNUM 1879 at time 2012.07.29_07:48_TAI
# ===== 202 =====
# skip: there are no data for HARPNUM 1930 at time 2012.08.04_20:38_TAI
# ===== 203 =====
# accept NOAA Active Region number 11540 and HARPNUM 1907 at time 2012.08.10_04:20_TAI
# ===== 204 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.16_05:19_TAI
# ===== 205 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.16_09:20_TAI
# ===== 206 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.16_17:02_TAI
# ===== 207 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.16_19:23_TAI
# ===== 208 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.17_08:07_TAI
# ===== 209 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.17_14:54_TAI
# ===== 210 =====
# skip: there are no data for HARPNUM 1946 at time 2012.08.17_15:22_TAI
# ===== 211 =====
# skip: there are no data for HARPNUM 1996 at time 2012.08.29_04:11_TAI
# ===== 212 =====
# skip: there are no data for HARPNUM 1993 at time 2012.09.04_20:13_TAI
# ===== 213 =====
# accept NOAA Active Region number 11564 and HARPNUM 1999 at time 2012.09.07_09:59_TAI
# ===== 214 =====
# accept NOAA Active Region number 11564 and HARPNUM 1999 at time 2012.09.08_14:36_TAI
# ===== 215 =====
# accept NOAA Active Region number 11583 and HARPNUM 2040 at time 2012.09.28_20:33_TAI
# ===== 216 =====
# skip: there are no data for HARPNUM 1 at time 2012.10.07_03:17_TAI
# ===== 217 =====
# skip: there are no data for HARPNUM 1 at time 2012.10.08_15:31_TAI
# ===== 218 =====
# skip: there are no data for HARPNUM 1 at time 2012.10.08_21:04_TAI
# ===== 219 =====
# skip: there are no data for HARPNUM 2137 at time 2012.10.19_10:14_TAI
# ===== 220 =====
# skip: there are no data for HARPNUM 2137 at time 2012.10.20_12:03_TAI
# ===== 221 =====
# skip: latitude is out of range for HARPNUM 2137 at time 2012.10.21_10:51_TAI
# ===== 222 =====
# skip: latitude is out of range for HARPNUM 2137 at time 2012.10.21_19:17_TAI
# ===== 223 =====
# skip: there are no data for HARPNUM 2193 at time 2012.11.09_18:33_TAI
# ===== 224 =====
# skip: latitude is out of range for HARPNUM 2191 at time 2012.11.11_15:28_TAI
# ===== 225 =====
# skip: there are no data for HARPNUM 2191 at time 2012.11.11_18:04_TAI
# ===== 226 =====
# accept NOAA Active Region number 11613 and HARPNUM 2191 at time 2012.11.11_21:50_TAI
# ===== 227 =====
# accept NOAA Active Region number 11613 and HARPNUM 2191 at time 2012.11.12_12:54_TAI
# ===== 228 =====
# accept NOAA Active Region number 11613 and HARPNUM 2191 at time 2012.11.12_20:04_TAI
# ===== 229 =====
# skip: there are no data for HARPNUM 1 at time 2012.11.19_04:41_TAI
# ===== 230 =====
# accept NOAA Active Region number 11618 and HARPNUM 2220 at time 2012.11.19_11:28_TAI
# ===== 231 =====
# accept NOAA Active Region number 11618 and HARPNUM 2220 at time 2012.11.19_22:56_TAI
# ===== 232 =====
# accept NOAA Active Region number 11618 and HARPNUM 2220 at time 2012.11.26_07:57_TAI
# ===== 233 =====
# accept NOAA Active Region number 11620 and HARPNUM 2227 at time 2012.11.26_13:26_TAI
# ===== 234 =====
# accept NOAA Active Region number 11620 and HARPNUM 2227 at time 2012.11.27_13:36_TAI
# ===== 235 =====
# skip: there are no data for HARPNUM 2362 at time 2013.01.04_01:31_TAI
# ===== 236 =====
# accept NOAA Active Region number 11654 and HARPNUM 2372 at time 2013.01.10_01:11_TAI
# ===== 237 =====
# accept NOAA Active Region number 11654 and HARPNUM 2372 at time 2013.01.10_07:07_TAI
# ===== 238 =====
# accept NOAA Active Region number 11652 and HARPNUM 2362 at time 2013.01.11_16:50_TAI
# ===== 239 =====
# accept NOAA Active Region number 11652 and HARPNUM 2362 at time 2013.01.12_00:38_TAI
# ===== 240 =====
# accept NOAA Active Region number 11675 and HARPNUM 2491 at time 2013.02.16_07:50_TAI
# ===== 241 =====
# accept NOAA Active Region number 11686 and HARPNUM 2519 at time 2013.03.03_23:54_TAI
# ===== 242 =====
# accept NOAA Active Region number 11692 and HARPNUM 2546 at time 2013.03.20_14:04_TAI
# ===== 243 =====
# skip: there are no data for HARPNUM 2635 at time 2013.04.04_09:48_TAI
# ===== 244 =====
# accept NOAA Active Region number 11718 and HARPNUM 2636 at time 2013.04.11_12:38_TAI
# ===== 245 =====
# accept NOAA Active Region number 11726 and HARPNUM 2673 at time 2013.04.21_02:29_TAI
# ===== 246 =====
# accept NOAA Active Region number 11731 and HARPNUM 2693 at time 2013.04.30_21:10_TAI
# ===== 247 =====
# accept NOAA Active Region number 11731 and HARPNUM 2693 at time 2013.05.02_08:55_TAI
# ===== 248 =====
# skip: there are no data for HARPNUM 2716 at time 2013.05.02_09:32_TAI
# ===== 249 =====
# accept NOAA Active Region number 11739 and HARPNUM 2716 at time 2013.05.04_09:56_TAI
# ===== 250 =====
# skip: there are no data for HARPNUM 2739 at time 2013.05.08_16:57_TAI
# ===== 251 =====
# skip: there are no data for HARPNUM 2739 at time 2013.05.09_04:56_TAI
# ===== 252 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.11_12:32_TAI
# ===== 253 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.11_14:44_TAI
# ===== 254 =====
# skip: there are no data for HARPNUM 2748 at time 2013.05.12_04:03_TAI
# ===== 255 =====
# accept NOAA Active Region number 11748 and HARPNUM 2748 at time 2013.05.15_13:53_TAI
# ===== 256 =====
# accept NOAA Active Region number 11748 and HARPNUM 2748 at time 2013.05.16_00:57_TAI
# ===== 257 =====
# skip: there are no data for HARPNUM 2760 at time 2013.05.18_21:25_TAI
# ===== 258 =====
# accept NOAA Active Region number 11760 and HARPNUM 2809 at time 2013.05.30_12:00_TAI
# ===== 259 =====
# accept NOAA Active Region number 11762 and HARPNUM 2790 at time 2013.06.04_00:57_TAI
# ===== 260 =====
# skip: there are no data for HARPNUM 2878 at time 2013.06.19_19:14_TAI
# ===== 261 =====
# skip: latitude is out of range for HARPNUM 2887 at time 2013.06.22_12:56_TAI
# ===== 262 =====
# skip: latitude is out of range for HARPNUM 2920 at time 2013.07.01_23:08_TAI
# ===== 263 =====
# accept NOAA Active Region number 11817 and HARPNUM 3048 at time 2013.08.11_02:41_TAI
# ===== 264 =====
# accept NOAA Active Region number 11818 and HARPNUM 3056 at time 2013.08.16_10:24_TAI
# ===== 265 =====
# accept NOAA Active Region number 11818 and HARPNUM 3056 at time 2013.08.16_11:33_TAI
# ===== 266 =====
# skip: latitude is out of range for HARPNUM 3263 at time 2013.10.07_17:48_TAI
# ===== 267 =====
# skip: there are no data for HARPNUM 1 at time 2013.10.09_23:25_TAI
# ===== 268 =====
# accept NOAA Active Region number 11865 and HARPNUM 3263 at time 2013.10.11_16:43_TAI
# ===== 269 =====
# accept NOAA Active Region number 11865 and HARPNUM 3263 at time 2013.10.14_00:38_TAI
# ===== 270 =====
# accept NOAA Active Region number 11865 and HARPNUM 3263 at time 2013.10.14_15:36_TAI
# ===== 271 =====
# accept NOAA Active Region number 11861 and HARPNUM 3258 at time 2013.10.16_07:41_TAI
# ===== 272 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.20_16:22_TAI
# ===== 273 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.21_07:20_TAI
# ===== 274 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.22_12:53_TAI
# ===== 275 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.22_15:43_TAI
# ===== 276 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.22_16:08_TAI
# ===== 277 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.23_02:09_TAI
# ===== 278 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.23_02:33_TAI
# ===== 279 =====
# skip: there are no data for HARPNUM 3311 at time 2013.10.23_19:02_TAI
# ===== 280 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_02:12_TAI
# ===== 281 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_09:09_TAI
# ===== 282 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_11:21_TAI
# ===== 283 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_12:58_TAI
# ===== 284 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.24_22:06_TAI
# ===== 285 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.25_01:37_TAI
# ===== 286 =====
# skip: latitude is out of range for HARPNUM 3311 at time 2013.10.25_03:17_TAI
# ===== 287 =====
# accept NOAA Active Region number 11882 and HARPNUM 3311 at time 2013.10.25_11:53_TAI
# ===== 288 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.26_04:48_TAI
# ===== 289 =====
# accept NOAA Active Region number 11877 and HARPNUM 3295 at time 2013.10.27_03:53_TAI
# ===== 290 =====
# skip: there are no data for HARPNUM 3291 at time 2013.10.27_06:05_TAI
# ===== 291 =====
# accept NOAA Active Region number 11882 and HARPNUM 3311 at time 2013.10.27_07:01_TAI
# ===== 292 =====
# accept NOAA Active Region number 11882 and HARPNUM 3311 at time 2013.10.27_07:15_TAI
# ===== 293 =====
# accept NOAA Active Region number 11875 and HARPNUM 3291 at time 2013.10.27_12:57_TAI
# ===== 294 =====
# accept NOAA Active Region number 11877 and HARPNUM 3295 at time 2013.10.30_05:51_TAI
# ===== 295 =====
# accept NOAA Active Region number 11884 and HARPNUM 3321 at time 2013.10.31_11:53_TAI
# ===== 296 =====
# accept NOAA Active Region number 11884 and HARPNUM 3321 at time 2013.11.01_14:21_TAI
# ===== 297 =====
# accept NOAA Active Region number 11884 and HARPNUM 3321 at time 2013.11.01_21:22_TAI
# ===== 298 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.04_00:18_TAI
# ===== 299 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.04_10:13_TAI
# ===== 300 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.04_14:12_TAI
# ===== 301 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.05_05:46_TAI
# ===== 302 =====
# skip: there are no data for HARPNUM 1 at time 2013.11.05_16:02_TAI
# ===== 303 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.05_19:40_TAI
# ===== 304 =====
# accept NOAA Active Region number 11890 and HARPNUM 3341 at time 2013.11.06_06:25_TAI
# ===== 305 =====
# accept NOAA Active Region number 11891 and HARPNUM 3344 at time 2013.11.07_01:28_TAI
# ===== 306 =====
# skip: latitude is out of range for HARPNUM 3366 at time 2013.11.10_03:18_TAI
# ===== 307 =====
# accept NOAA Active Region number 11897 and HARPNUM 3366 at time 2013.11.12_07:20_TAI
# ===== 308 =====
# skip: latitude is out of range for HARPNUM 3376 at time 2013.11.13_18:29_TAI
# ===== 309 =====
# accept NOAA Active Region number 11900 and HARPNUM 3364 at time 2013.11.14_20:53_TAI
# ===== 310 =====
# accept NOAA Active Region number 11900 and HARPNUM 3364 at time 2013.11.14_23:49_TAI
# ===== 311 =====
# accept NOAA Active Region number 11900 and HARPNUM 3364 at time 2013.11.15_21:10_TAI
# ===== 312 =====
# skip: latitude is out of range for HARPNUM 3364 at time 2013.11.20_03:11_TAI
# ===== 313 =====
# accept NOAA Active Region number 11904 and HARPNUM 3376 at time 2013.11.21_18:32_TAI
# ===== 314 =====
# accept NOAA Active Region number 11904 and HARPNUM 3376 at time 2013.11.22_04:57_TAI
# ===== 315 =====
# accept NOAA Active Region number 11909 and HARPNUM 3437 at time 2013.12.05_23:29_TAI
# ===== 316 =====
# skip: latitude is out of range for HARPNUM 3520 at time 2013.12.18_15:19_TAI
# ===== 317 =====
# skip: latitude is out of range for HARPNUM 3520 at time 2013.12.19_03:57_TAI
# ===== 318 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.21_00:11_TAI
# ===== 319 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.21_00:37_TAI
# ===== 320 =====
# accept NOAA Active Region number 11934 and HARPNUM 3520 at time 2013.12.21_06:38_TAI
# ===== 321 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.21_07:12_TAI
# ===== 322 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.21_14:08_TAI
# ===== 323 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.21_16:03_TAI
# ===== 324 =====
# accept NOAA Active Region number 11928 and HARPNUM 3497 at time 2013.12.22_01:06_TAI
# ===== 325 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2013.12.27_23:56_TAI
# ===== 326 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2013.12.30_13:58_TAI
# ===== 327 =====
# accept NOAA Active Region number 11936 and HARPNUM 3535 at time 2013.12.31_10:52_TAI
# ===== 328 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2013.12.31_18:33_TAI
# ===== 329 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.01_14:18_TAI
# ===== 330 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.02_04:50_TAI
# ===== 331 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.02_13:14_TAI
# ===== 332 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.03_02:25_TAI
# ===== 333 =====
# skip: latitude is out of range for HARPNUM 3563 at time 2014.01.03_02:25_TAI
# ===== 334 =====
# accept NOAA Active Region number 11946 and HARPNUM 3580 at time 2014.01.05_19:53_TAI
# ===== 335 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.06_02:13_TAI
# ===== 336 =====
# accept NOAA Active Region number 11944 and HARPNUM 3563 at time 2014.01.12_13:51_TAI
# ===== 337 =====
# skip: there are no data for HARPNUM 1 at time 2014.01.25_17:22_TAI
# ===== 338 =====
# skip: there are no data for HARPNUM 1 at time 2014.01.25_18:11_TAI
# ===== 339 =====
# skip: there are no data for HARPNUM 3686 at time 2014.01.26_14:10_TAI
# ===== 340 =====
# skip: there are no data for HARPNUM 3686 at time 2014.01.26_20:09_TAI
# ===== 341 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.26_23:31_TAI
# ===== 342 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_03:38_TAI
# ===== 343 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_04:46_TAI
# ===== 344 =====
# skip: there are no data for HARPNUM 1 at time 2014.01.27_04:46_TAI
# ===== 345 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_11:40_TAI
# ===== 346 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.27_14:16_TAI
# ===== 347 =====
# skip: latitude is out of range for HARPNUM 3686 at time 2014.01.28_22:39_TAI
# ===== 348 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.01.30_07:42_TAI
# ===== 349 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.30_17:25_TAI
# ===== 350 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.01.30_23:23_TAI
# ===== 351 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.01.31_22:34_TAI
# ===== 352 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.01_00:20_TAI
# ===== 353 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.01_01:31_TAI
# ===== 354 =====
# skip: there are no data for HARPNUM 3686 at time 2014.02.01_06:06_TAI
# ===== 355 =====
# skip: there are no data for HARPNUM 1 at time 2014.02.01_08:29_TAI
# ===== 356 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.01_10:11_TAI
# ===== 357 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.01_14:04_TAI
# ===== 358 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.02.02_17:23_TAI
# ===== 359 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.02_20:00_TAI
# ===== 360 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.03_01:49_TAI
# ===== 361 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.03_08:02_TAI
# ===== 362 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.04_08:20_TAI
# ===== 363 =====
# accept NOAA Active Region number 11967 and HARPNUM 3686 at time 2014.02.05_15:05_TAI
# ===== 364 =====
# skip: there are no data for HARPNUM 3686 at time 2014.02.05_20:56_TAI
# ===== 365 =====
# accept NOAA Active Region number 11968 and HARPNUM 3688 at time 2014.02.06_02:29_TAI
# ===== 366 =====
# skip: there are no data for HARPNUM 1 at time 2014.02.08_08:17_TAI
# ===== 367 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.10_08:51_TAI
# ===== 368 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.10_20:25_TAI
# ===== 369 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.10_22:58_TAI
# ===== 370 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.11_07:51_TAI
# ===== 371 =====
# skip: there are no data for HARPNUM 1 at time 2014.02.11_17:40_TAI
# ===== 372 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.11_18:51_TAI
# ===== 373 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.11_22:07_TAI
# ===== 374 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.12_00:12_TAI
# ===== 375 =====
# skip: there are no data for HARPNUM 1 at time 2014.02.12_07:57_TAI
# ===== 376 =====
# skip: there are no data for HARPNUM 3721 at time 2014.02.12_18:57_TAI
# ===== 377 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_04:40_TAI
# ===== 378 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_05:28_TAI
# ===== 379 =====
# accept NOAA Active Region number 11974 and HARPNUM 3721 at time 2014.02.13_08:39_TAI
# ===== 380 =====
# accept NOAA Active Region number 11977 and HARPNUM 3740 at time 2014.02.15_01:26_TAI
# ===== 381 =====
# accept NOAA Active Region number 11976 and HARPNUM 3730 at time 2014.02.18_23:56_TAI
# ===== 382 =====
# skip: there are no data for HARPNUM 1 at time 2014.02.21_22:10_TAI
# ===== 383 =====
# skip: there are no data for HARPNUM 3793 at time 2014.02.23_03:17_TAI
# ===== 384 =====
# skip: there are no data for HARPNUM 3793 at time 2014.02.23_04:05_TAI
# ===== 385 =====
# accept NOAA Active Region number 11982 and HARPNUM 3766 at time 2014.02.25_07:01_TAI
# ===== 386 =====
# skip: latitude is out of range for HARPNUM 3804 at time 2014.02.26_16:48_TAI
# ===== 387 =====
# skip: latitude is out of range for HARPNUM 3766 at time 2014.02.28_05:33_TAI
# ===== 388 =====
# accept NOAA Active Region number 11986 and HARPNUM 3779 at time 2014.03.01_15:19_TAI
# ===== 389 =====
# skip: there are no data for HARPNUM 3784 at time 2014.03.02_07:58_TAI
# ===== 390 =====
# skip: there are no data for HARPNUM 3804 at time 2014.03.03_18:10_TAI
# ===== 391 =====
# skip: latitude is out of range for HARPNUM 3836 at time 2014.03.07_15:41_TAI
# ===== 392 =====
# skip: there are no data for HARPNUM 3836 at time 2014.03.08_05:58_TAI
# ===== 393 =====
# skip: latitude is out of range for HARPNUM 3836 at time 2014.03.08_12:28_TAI
# ===== 394 =====
# skip: latitude is out of range for HARPNUM 3836 at time 2014.03.08_16:26_TAI
# ===== 395 =====
# accept NOAA Active Region number 12002 and HARPNUM 3836 at time 2014.03.08_20:08_TAI
# ===== 396 =====
# skip: there are no data for HARPNUM 3836 at time 2014.03.09_07:28_TAI
# ===== 397 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.09_15:00_TAI
# ===== 398 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.09_19:50_TAI
# ===== 399 =====
# skip: latitude is out of range for HARPNUM 3804 at time 2014.03.10_04:07_TAI
# ===== 400 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.11_03:05_TAI
# ===== 401 =====
# accept NOAA Active Region number 11996 and HARPNUM 3813 at time 2014.03.11_14:34_TAI
# ===== 402 =====
# skip: latitude is out of range for HARPNUM 3813 at time 2014.03.12_11:19_TAI
# ===== 403 =====
# accept NOAA Active Region number 12010 and HARPNUM 3856 at time 2014.03.18_19:56_TAI
# ===== 404 =====
# accept NOAA Active Region number 12011 and HARPNUM 3877 at time 2014.03.20_23:02_TAI
# ===== 405 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.27_11:18_TAI
# ===== 406 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.27_15:51_TAI
# ===== 407 =====
# accept NOAA Active Region number 12017 and HARPNUM 3894 at time 2014.03.29_03:55_TAI
# ===== 408 =====
# accept NOAA Active Region number 12014 and HARPNUM 3879 at time 2014.03.30_00:07_TAI
# ===== 409 =====
# accept NOAA Active Region number 12035 and HARPNUM 4000 at time 2014.04.15_11:59_TAI
# ===== 410 =====
# accept NOAA Active Region number 12056 and HARPNUM 4097 at time 2014.05.07_02:07_TAI
# ===== 411 =====
# accept NOAA Active Region number 12065 and HARPNUM 4138 at time 2014.05.23_10:35_TAI
# ===== 412 =====
# accept NOAA Active Region number 12077 and HARPNUM 4186 at time 2014.06.01_20:09_TAI
# ===== 413 =====
# accept NOAA Active Region number 12080 and HARPNUM 4197 at time 2014.06.05_11:31_TAI
# ===== 414 =====
# accept NOAA Active Region number 12080 and HARPNUM 4197 at time 2014.06.09_21:34_TAI
# ===== 415 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_00:09_TAI
# ===== 416 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_01:06_TAI
# ===== 417 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_13:03_TAI
# ===== 418 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.10_20:21_TAI
# ===== 419 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.11_01:37_TAI
# ===== 420 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_02:21_TAI
# ===== 421 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_10:13_TAI
# ===== 422 =====
# accept NOAA Active Region number 12089 and HARPNUM 4231 at time 2014.06.11_12:03_TAI
# ===== 423 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_13:13_TAI
# ===== 424 =====
# skip: latitude is out of range for HARPNUM 4225 at time 2014.06.11_23:56_TAI
# ===== 425 =====
# skip: there are no data for HARPNUM 1 at time 2014.06.13_11:29_TAI
# ===== 426 =====
# accept NOAA Active Region number 12085 and HARPNUM 4197 at time 2014.06.14_03:39_TAI
# ===== 427 =====
# accept NOAA Active Region number 12087 and HARPNUM 4225 at time 2014.06.14_16:01_TAI
# ===== 428 =====
# skip: latitude is out of range for HARPNUM 4344 at time 2014.07.07_16:26_TAI
# ===== 429 =====
# skip: there are no data for HARPNUM 4294 at time 2014.07.09_14:34_TAI
# ===== 430 =====
# skip: latitude is out of range for HARPNUM 4396 at time 2014.07.30_03:14_TAI
# ===== 431 =====
# accept NOAA Active Region number 12130 and HARPNUM 4396 at time 2014.07.31_06:48_TAI
# ===== 432 =====
# skip: there are no matching HARPNUMs for 12149
# ===== 433 =====
# skip: there are no matching HARPNUMs for 12151
# ===== 434 =====
# skip: there are no matching HARPNUMs for 12155
# ===== 435 =====
# skip: there are no matching HARPNUMs for 12157
# ===== 436 =====
# skip: there are no matching HARPNUMs for 12158
# ===== 437 =====
# skip: there are no matching HARPNUMs for 12166
# ===== 438 =====
# skip: there are no matching HARPNUMs for 12166
# ===== 439 =====
# skip: there are no matching HARPNUMs for 12169
# ===== 440 =====
# skip: there are no data for HARPNUM 1 at time 2014.09.26_00:37_TAI
# ===== 441 =====
# skip: there are no matching HARPNUMs for 12173
# ===== 442 =====
# skip: there are no matching HARPNUMs for 12172
# ===== 443 =====
# accept NOAA Active Region number 12182 and HARPNUM 4639 at time 2014.10.07_17:43_TAI
# ===== 444 =====
# skip: there are no data for HARPNUM 4639 at time 2014.10.07_17:58_TAI
# ===== 445 =====
# accept NOAA Active Region number 12182 and HARPNUM 4639 at time 2014.10.07_22:59_TAI
# ===== 446 =====
# skip: there are no data for HARPNUM 1 at time 2014.10.13_10:37_TAI
# ===== 447 =====
# skip: there are no data for HARPNUM 1 at time 2014.10.13_13:21_TAI
# ===== 448 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.16_23:58_TAI
# ===== 449 =====
# skip: latitude is out of range for HARPNUM 4698 at time 2014.10.17_21:03_TAI
# ===== 450 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.19_01:11_TAI
# ===== 451 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.19_08:37_TAI
# ===== 452 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.19_11:02_TAI
# ===== 453 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.19_12:04_TAI
# ===== 454 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.19_14:55_TAI
# ===== 455 =====
# skip: there are no data for HARPNUM 1 at time 2014.10.20_05:38_TAI
# ===== 456 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.20_17:59_TAI
# ===== 457 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.20_21:17_TAI
# ===== 458 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.21_06:28_TAI
# ===== 459 =====
# skip: there are no data for HARPNUM 1 at time 2014.10.21_07:57_TAI
# ===== 460 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.22_01:50_TAI
# ===== 461 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.23_13:41_TAI
# ===== 462 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.24_09:08_TAI
# ===== 463 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_02:56_TAI
# ===== 464 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_09:17_TAI
# ===== 465 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_10:15_TAI
# ===== 466 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_10:49_TAI
# ===== 467 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_12:21_TAI
# ===== 468 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_16:34_TAI
# ===== 469 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.25_18:02_TAI
# ===== 470 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.25_19:41_TAI
# ===== 471 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_02:09_TAI
# ===== 472 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_06:47_TAI
# ===== 473 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_09:40_TAI
# ===== 474 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_18:42_TAI
# ===== 475 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.26_19:32_TAI
# ===== 476 =====
# skip: there are no data for HARPNUM 4698 at time 2014.10.27_06:06_TAI
# ===== 477 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_00:20_TAI
# ===== 478 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_02:01_TAI
# ===== 479 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_06:33_TAI
# ===== 480 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_08:20_TAI
# ===== 481 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_10:50_TAI
# ===== 482 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_13:22_TAI
# ===== 483 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_16:37_TAI
# ===== 484 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_17:35_TAI
# ===== 485 =====
# accept NOAA Active Region number 12192 and HARPNUM 4698 at time 2014.10.28_20:28_TAI
# ===== 486 =====
# skip: latitude is out of range for HARPNUM 4781 at time 2014.11.04_17:39_TAI
# ===== 487 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.05_14:16_TAI
# ===== 488 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.05_18:49_TAI
# ===== 489 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.06_02:22_TAI
# ===== 490 =====
# accept NOAA Active Region number 12205 and HARPNUM 4781 at time 2014.11.08_07:32_TAI
# ===== 491 =====
# skip: latitude is out of range for HARPNUM 4817 at time 2014.11.14_04:03_TAI
# ===== 492 =====
# accept NOAA Active Region number 12209 and HARPNUM 4817 at time 2014.11.15_09:48_TAI
# ===== 493 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.11.29_22:41_TAI
# ===== 494 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.03_00:10_TAI
# ===== 495 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.03_10:25_TAI
# ===== 496 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.03_11:41_TAI
# ===== 497 =====
# accept NOAA Active Region number 12222 and HARPNUM 4874 at time 2014.12.04_04:25_TAI
# ===== 498 =====
# skip: there are no data for HARPNUM 4941 at time 2014.12.11_21:20_TAI
# ===== 499 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.13_11:33_TAI
# ===== 500 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.15_17:10_TAI
# ===== 501 =====
# accept NOAA Active Region number 12241 and HARPNUM 4941 at time 2014.12.16_11:01_TAI
# ===== 502 =====
# accept NOAA Active Region number 12242 and HARPNUM 4920 at time 2014.12.18_01:44_TAI
# ===== 503 =====
# ...
# ===== 1606 =====
# accept NOAA Active Region number 13852 and HARPNUM 12032 at time 2024.10.14_13:27_TAI
# ===== 1607 =====
# accept NOAA Active Region number 13852 and HARPNUM 12032 at time 2024.10.14_14:42_TAI
# ===== 1608 =====
# accept NOAA Active Region number 13852 and HARPNUM 12032 at time 2024.10.14_15:00_TAI
# ===== 1609 =====
# accept NOAA Active Region number 13856 and HARPNUM 12055 at time 2024.10.15_02:22_TAI
# ===== 1610 =====
# accept NOAA Active Region number 13852 and HARPNUM 12032 at time 2024.10.15_05:05_TAI
# ===== 1611 =====
# skip: there are no data for HARPNUM 12032 at time 2024.10.16_17:36_TAI
# ===== 1612 =====
# skip: there are no data for HARPNUM 12032 at time 2024.10.16_19:38_TAI
# ===== 1613 =====
# accept NOAA Active Region number 13852 and HARPNUM 12032 at time 2024.10.16_23:28_TAI
# ===== 1614 =====
# accept NOAA Active Region number 13854 and HARPNUM 12032 at time 2024.10.17_14:34_TAI
# ===== 1615 =====
# skip: latitude is out of range for HARPNUM 12094 at time 2024.10.22_10:29_TAI
# ===== 1616 =====
# skip: there are no data for HARPNUM 1 at time 2024.10.24_11:50_TAI
# ===== 1617 =====
# skip: there are no data for HARPNUM 1 at time 2024.10.24_12:06_TAI
# ===== 1618 =====
# skip: there are no data for HARPNUM 1 at time 2024.10.24_14:16_TAI
# ===== 1619 =====
# skip: there are no data for HARPNUM 12160 at time 2024.10.25_23:24_TAI
# ===== 1620 =====
# skip: there are no data for HARPNUM 1 at time 2024.10.26_04:09_TAI
# ===== 1621 =====
# accept NOAA Active Region number 13869 and HARPNUM 12094 at time 2024.10.26_14:44_TAI
# ===== 1622 =====
# skip: there are no data for HARPNUM 12160 at time 2024.10.26_16:28_TAI
# ===== 1623 =====
# accept NOAA Active Region number 13873 and HARPNUM 12094 at time 2024.10.27_16:33_TAI
# ===== 1624 =====
# skip: latitude is out of range for HARPNUM 12160 at time 2024.10.28_20:53_TAI
# ===== 1625 =====
# skip: latitude is out of range for HARPNUM 12160 at time 2024.10.29_02:52_TAI
# ===== 1626 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.10.29_03:30_TAI
# ===== 1627 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.10.29_09:37_TAI
# ===== 1628 =====
# accept NOAA Active Region number 13876 and HARPNUM 12094 at time 2024.10.29_13:59_TAI
# ===== 1629 =====
# skip: there are no data for HARPNUM 12094 at time 2024.10.29_19:07_TAI
# ===== 1630 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.10.29_21:10_TAI
# ===== 1631 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.10.30_02:16_TAI
# ===== 1632 =====
# accept NOAA Active Region number 13876 and HARPNUM 12094 at time 2024.10.30_10:14_TAI
# ===== 1633 =====
# accept NOAA Active Region number 13876 and HARPNUM 12094 at time 2024.10.30_12:52_TAI
# ===== 1634 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.10.30_14:31_TAI
# ===== 1635 =====
# accept NOAA Active Region number 13869 and HARPNUM 12094 at time 2024.10.31_07:38_TAI
# ===== 1636 =====
# accept NOAA Active Region number 13876 and HARPNUM 12094 at time 2024.10.31_08:31_TAI
# ===== 1637 =====
# accept NOAA Active Region number 13869 and HARPNUM 12094 at time 2024.11.01_03:11_TAI
# ===== 1638 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.11.01_08:49_TAI
# ===== 1639 =====
# accept NOAA Active Region number 13869 and HARPNUM 12094 at time 2024.11.01_15:24_TAI
# ===== 1640 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.01_17:53_TAI
# ===== 1641 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_00:57_TAI
# ===== 1642 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_03:45_TAI
# ===== 1643 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_04:15_TAI
# ===== 1644 =====
# accept NOAA Active Region number 13878 and HARPNUM 12160 at time 2024.11.02_04:34_TAI
# ===== 1645 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_07:08_TAI
# ===== 1646 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_08:40_TAI
# ===== 1647 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_10:17_TAI
# ===== 1648 =====
# skip: latitude is out of range for HARPNUM 12174 at time 2024.11.02_15:08_TAI
# ===== 1649 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.03_09:23_TAI
# ===== 1650 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.03_13:39_TAI
# ===== 1651 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.03_14:19_TAI
# ===== 1652 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.04_02:38_TAI
# ===== 1653 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.04_03:09_TAI
# ===== 1654 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.04_08:04_TAI
# ===== 1655 =====
# accept NOAA Active Region number 13887 and HARPNUM 12160 at time 2024.11.04_08:50_TAI
# ===== 1656 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.04_12:04_TAI
# ===== 1657 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_13:02_TAI
# ===== 1658 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.04_13:40_TAI
# ===== 1659 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_14:38_TAI
# ===== 1660 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_17:18_TAI
# ===== 1661 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_18:59_TAI
# ===== 1662 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_20:42_TAI
# ===== 1663 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.04_23:05_TAI
# ===== 1664 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.05_01:27_TAI
# ===== 1665 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.05_04:20_TAI
# ===== 1666 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.05_07:26_TAI
# ===== 1667 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.05_07:43_TAI
# ===== 1668 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.05_07:54_TAI
# ===== 1669 =====
# skip: there are no data for HARPNUM 12216 at time 2024.11.05_12:02_TAI
# ===== 1670 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.05_15:06_TAI
# ===== 1671 =====
# accept NOAA Active Region number 13883 and HARPNUM 12174 at time 2024.11.06_03:01_TAI
# ===== 1672 =====
# skip: latitude is out of range for HARPNUM 12216 at time 2024.11.07_20:50_TAI
# ===== 1673 =====
# skip: latitude is out of range for HARPNUM 12216 at time 2024.11.08_00:15_TAI
# ===== 1674 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.08_20:21_TAI
# ===== 1675 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.09_05:26_TAI
# ===== 1676 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.09_05:43_TAI
# ===== 1677 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.11_00:22_TAI
# ===== 1678 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.11_17:08_TAI
# ===== 1679 =====
# skip: latitude is out of range for HARPNUM 12235 at time 2024.11.13_01:46_TAI
# ===== 1680 =====
# skip: latitude is out of range for HARPNUM 12235 at time 2024.11.13_12:18_TAI
# ===== 1681 =====
# accept NOAA Active Region number 13889 and HARPNUM 12216 at time 2024.11.14_01:37_TAI
# ===== 1682 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_05:22_TAI
# ===== 1683 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_07:32_TAI
# ===== 1684 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_07:57_TAI
# ===== 1685 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_10:58_TAI
# ===== 1686 =====
# accept NOAA Active Region number 13897 and HARPNUM 12216 at time 2024.11.16_11:27_TAI
# ===== 1687 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_12:53_TAI
# ===== 1688 =====
# skip: there are no data for HARPNUM 12261 at time 2024.11.16_17:49_TAI
# ===== 1689 =====
# skip: there are no data for HARPNUM 12216 at time 2024.10.23_23:30_TAI
# ===== 1690 =====
# skip: latitude is out of range for HARPNUM 12261 at time 2024.11.20_15:46_TAI
# ===== 1691 =====
# accept NOAA Active Region number 13901 and HARPNUM 12261 at time 2024.11.21_16:07_TAI
# ===== 1692 =====
# skip: there are no data for HARPNUM 12311 at time 2024.11.21_18:10_TAI
# ===== 1693 =====
# skip: there are no data for HARPNUM 1 at time 2024.11.22_20:22_TAI
# ===== 1694 =====
# accept NOAA Active Region number 13906 and HARPNUM 12261 at time 2024.11.23_04:53_TAI
# ===== 1695 =====
# skip: there are no data for HARPNUM 1 at time 2024.11.23_07:42_TAI
# ===== 1696 =====
# accept NOAA Active Region number 13905 and HARPNUM 12261 at time 2024.11.23_12:12_TAI
# ===== 1697 =====
# accept NOAA Active Region number 13906 and HARPNUM 12261 at time 2024.11.23_16:36_TAI
# ===== 1698 =====
# skip: latitude is out of range for HARPNUM 12311 at time 2024.11.23_17:07_TAI
# ===== 1699 =====
# accept NOAA Active Region number 13901 and HARPNUM 12261 at time 2024.11.25_12:46_TAI
# ===== 1700 =====
# skip: latitude is out of range for HARPNUM 12363 at time 2024.12.02_20:46_TAI
# ===== 1701 =====
# skip: latitude is out of range for HARPNUM 12363 at time 2024.12.02_21:05_TAI
# ===== 1702 =====
# skip: latitude is out of range for HARPNUM 12363 at time 2024.12.03_07:09_TAI
# ===== 1703 =====
# skip: latitude is out of range for HARPNUM 12261 at time 2024.12.03_08:20_TAI
# ===== 1704 =====
# skip: latitude is out of range for HARPNUM 12363 at time 2024.12.04_09:20_TAI
# ===== 1705 =====
# accept NOAA Active Region number 13917 and HARPNUM 12363 at time 2024.12.05_13:08_TAI
# ===== 1706 =====
# accept NOAA Active Region number 13917 and HARPNUM 12363 at time 2024.12.05_22:15_TAI
# ===== 1707 =====
# accept NOAA Active Region number 13912 and HARPNUM 12334 at time 2024.12.06_16:11_TAI
# ===== 1708 =====
# accept NOAA Active Region number 13912 and HARPNUM 12334 at time 2024.12.09_15:49_TAI
# ===== 1709 =====
# skip: latitude is out of range for HARPNUM 12404 at time 2024.12.10_17:43_TAI
# ===== 1710 =====
# skip: latitude is out of range for HARPNUM 12404 at time 2024.12.10_21:07_TAI
# ===== 1711 =====
# accept NOAA Active Region number 13917 and HARPNUM 12363 at time 2024.12.11_11:24_TAI
# ===== 1712 =====
# accept NOAA Active Region number 13924 and HARPNUM 12405 at time 2024.12.17_10:38_TAI
# ===== 1713 =====
# skip: latitude is out of range for HARPNUM 12456 at time 2024.12.17_15:34_TAI
# ===== 1714 =====
# skip: latitude is out of range for HARPNUM 12456 at time 2024.12.17_19:00_TAI
# ===== 1715 =====
# accept NOAA Active Region number 13924 and HARPNUM 12405 at time 2024.12.18_07:26_TAI
# ===== 1716 =====
# skip: latitude is out of range for HARPNUM 12456 at time 2024.12.18_11:18_TAI
# ===== 1717 =====
# skip: latitude is out of range for HARPNUM 12456 at time 2024.12.19_00:38_TAI
# ===== 1718 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.20_04:10_TAI
# ===== 1719 =====
# accept NOAA Active Region number 13930 and HARPNUM 12425 at time 2024.12.20_14:14_TAI
# ===== 1720 =====
# skip: there are no data for HARPNUM 1 at time 2024.12.21_02:31_TAI
# ===== 1721 =====
# accept NOAA Active Region number 13928 and HARPNUM 12456 at time 2024.12.21_06:29_TAI
# ===== 1722 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.22_14:10_TAI
# ===== 1723 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.22_16:34_TAI
# ===== 1724 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.22_18:24_TAI
# ===== 1725 =====
# skip: latitude is out of range for HARPNUM 12471 at time 2024.12.22_22:34_TAI
# ===== 1726 =====
# accept NOAA Active Region number 13938 and HARPNUM 12471 at time 2024.12.23_04:30_TAI
# ===== 1727 =====
# accept NOAA Active Region number 13938 and HARPNUM 12471 at time 2024.12.24_03:15_TAI
# ===== 1728 =====
# accept NOAA Active Region number 13928 and HARPNUM 12456 at time 2024.12.25_15:38_TAI
# ===== 1729 =====
# accept NOAA Active Region number 13938 and HARPNUM 12471 at time 2024.12.25_20:35_TAI
# ===== 1730 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.26_11:21_TAI
# ===== 1731 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.26_15:18_TAI
# ===== 1732 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.26_22:14_TAI
# ===== 1733 =====
# accept NOAA Active Region number 13929 and HARPNUM 12466 at time 2024.12.27_02:35_TAI
# ===== 1734 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_02:46_TAI
# ===== 1735 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_03:30_TAI
# ===== 1736 =====
# accept NOAA Active Region number 13940 and HARPNUM 12492 at time 2024.12.27_04:05_TAI
# ===== 1737 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.27_05:26_TAI
# ===== 1738 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.27_05:47_TAI
# ===== 1739 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_06:59_TAI
# ===== 1740 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_07:18_TAI
# ===== 1741 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_07:59_TAI
# ===== 1742 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_09:48_TAI
# ===== 1743 =====
# accept NOAA Active Region number 13938 and HARPNUM 12471 at time 2024.12.27_10:39_TAI
# ===== 1744 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_12:24_TAI
# ===== 1745 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_12:56_TAI
# ===== 1746 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_15:09_TAI
# ===== 1747 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.27_17:52_TAI
# ===== 1748 =====
# skip: there are no data for HARPNUM 12492 at time 2024.12.27_18:04_TAI
# ===== 1749 =====
# accept NOAA Active Region number 13934 and HARPNUM 12471 at time 2024.12.27_18:41_TAI
# ===== 1750 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.27_20:39_TAI
# ===== 1751 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_21:53_TAI
# ===== 1752 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.27_22:06_TAI
# ===== 1753 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.27_23:30_TAI
# ===== 1754 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.28_00:47_TAI
# ===== 1755 =====
# accept NOAA Active Region number 13940 and HARPNUM 12492 at time 2024.12.28_03:00_TAI
# ===== 1756 =====
# accept NOAA Active Region number 13932 and HARPNUM 12456 at time 2024.12.28_04:31_TAI
# ===== 1757 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_06:25_TAI
# ===== 1758 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.28_08:40_TAI
# ===== 1759 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.28_08:50_TAI
# ===== 1760 =====
# accept NOAA Active Region number 13933 and HARPNUM 12456 at time 2024.12.28_10:11_TAI
# ===== 1761 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_14:46_TAI
# ===== 1762 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_16:54_TAI
# ===== 1763 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_17:30_TAI
# ===== 1764 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_17:42_TAI
# ===== 1765 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_18:24_TAI
# ===== 1766 =====
# accept NOAA Active Region number 13936 and HARPNUM 12471 at time 2024.12.28_18:33_TAI
# ===== 1767 =====
# accept NOAA Active Region number 13939 and HARPNUM 12492 at time 2024.12.28_22:41_TAI
